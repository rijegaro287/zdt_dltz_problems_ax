# %%
# !lscpu |grep 'Model name'
# !nvidia-smi
# !pip install ax-platform
# Out:
# Model name:                      Intel(R) Xeon(R) CPU @ 2.20GHz
# Mon Mar 20 19:58:15 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0    31W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ax-platform in /usr/local/lib/python3.9/dist-packages (0.3.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.4.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.10.1)
# Requirement already satisfied: plotly>=5.12.0 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (5.13.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from ax-platform) (7.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (3.1.2)
# Requirement already satisfied: typeguard==2.13.3 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (2.13.3)
# Requirement already satisfied: botorch==0.8.3 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (0.8.3)
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.13.1+cu116)
# Requirement already satisfied: linear-operator==0.3.0 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (0.3.0)
# Requirement already satisfied: pyro-ppl>=1.8.4 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.8.4)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (0.6.0)
# Requirement already satisfied: gpytorch==1.9.1 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.9.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.12.0->ax-platform) (8.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.0.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (7.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->ax-platform) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (3.1.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (63.4.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.18.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (3.3.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (0.1.2)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (4.65.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->ax-platform) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.12->botorch==0.8.3->ax-platform) (4.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->ax-platform) (0.8.3)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.4)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.2.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.16.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.17.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.7.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ax-platform) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->ax-platform) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.1.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.9/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.23.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.9.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.2.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.16.3)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.19.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.9/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.9/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.9/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.21)

# %%
import pandas as pd
from ax import *
import torch
from torch import Tensor

import numpy as np
import math
from matplotlib import pyplot as plt
from matplotlib.cm import ScalarMappable

from ax.service.utils.report_utils import exp_to_df
from ax.runners.synthetic import SyntheticRunner
from ax.metrics.noisy_function import GenericNoisyFunctionMetric

# Analysis utilities, including a method to evaluate hypervolumes
from ax.modelbridge.modelbridge_utils import observed_hypervolume

from botorch.test_functions.multi_objective import DTLZ5

# %%
class DTLZ6(DTLZ5):
  def evaluate_true(self, X: Tensor) -> Tensor:
        X_m = X[..., -self.k :]
        X_ = X[..., : -self.k]
        g_X = X_m.pow(0.1).sum(dim=-1)
        theta = 1 / (2 * (1 + g_X.unsqueeze(-1))) * (1 + 2 * g_X.unsqueeze(-1) * X_)
        theta = torch.cat([X[..., :1], theta[..., 1:]], dim=-1)
        fs = []
        pi_over_2 = math.pi / 2
        g_X_plus1 = g_X + 1
        for i in range(self.num_objectives):
            f_i = g_X_plus1.clone()
            f_i *= torch.cos(theta[..., : theta.shape[-1] - i] * pi_over_2).prod(dim=-1)
            if i > 0:
                f_i *= torch.sin(theta[..., theta.shape[-1] - i] * pi_over_2)
            fs.append(f_i)
        return torch.stack(fs, dim=-1)

# %%
tkwargs = {
    "dtype": torch.double, 
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
}

# %%
dim = 30
problem = DTLZ6(num_objectives=2, dim=dim, negate=False).to(**tkwargs)

param_names = [f"x{i}" for i in range(dim)]

def f1(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names] # Obtiene los parámetros a evaluar
        return float(problem(torch.tensor(x_sorted, **tkwargs).clamp(0., 1.))[0]) # Evalúa los parámetros en el primer objetivo
    
def f2(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names]
        return float(problem(torch.tensor(x_sorted, **tkwargs).clamp(0., 1.))[1]) # Evalúa los parámetros en el segundo objetivo

metric_a = GenericNoisyFunctionMetric("a", f=f1, noise_sd=0.0, lower_is_better=True)
metric_b = GenericNoisyFunctionMetric("b", f=f2, noise_sd=0.0, lower_is_better=True)

# %%
search_space = SearchSpace(
    parameters=[
        RangeParameter(name=param_name, lower=0, upper=1, parameter_type=ParameterType.FLOAT)
        for param_name in param_names
        ]
)

mo = MultiObjective(
    objectives=[Objective(metric=metric_a), Objective(metric=metric_b)],
)

objective_thresholds = [
    ObjectiveThreshold(metric=metric, bound=val, relative=False)
    for metric, val in zip(mo.metrics, problem.ref_point)
]

optimization_config = MultiObjectiveOptimizationConfig(
    objective=mo,
    objective_thresholds=objective_thresholds,
)

# %%
N_INIT = 2 * (dim + 1)
N_BATCH = 10
BATCH_SIZE = 1

def build_experiment():
    experiment = Experiment(
        name="pareto_experiment",
        search_space=search_space,
        optimization_config=optimization_config,
        runner=SyntheticRunner(),
    )
    return experiment

def initialize_experiment(experiment):
    sobol = Models.SOBOL(search_space=experiment.search_space)

    for _ in range(N_INIT):
        experiment.new_trial(sobol.gen(1)).run()

    return experiment.fetch_data()

# %%
import time

executions = 10
execution_times = []
all_df = []
all_outcomes = []

for exec in range(executions):
  start_time = time.time()

  experiment = build_experiment()
  data = initialize_experiment(experiment)

  hv_list = []
  model = None
  for i in range(N_BATCH):   
      model = Models.FULLYBAYESIANMOO(
          experiment=experiment, 
          data=data,
          num_samples=16,
          warmup_steps=32,
          torch_device=tkwargs["device"],
      )
      generator_run = model.gen(BATCH_SIZE)
      trial = experiment.new_trial(generator_run=generator_run)
      trial.run()
      data = Data.from_multiple_data([data, trial.fetch_data()])
      
      exp_df = exp_to_df(experiment)
      outcomes = np.array(exp_df[['a', 'b']], dtype=np.double)
      try:
          hv = observed_hypervolume(modelbridge=model)
      except:
          hv = 0
          print("Failed to compute hv")
      hv_list.append(hv)
      print(f"Execution: {exec + 1}, Iteration: {i + 1}, HV: {hv}")

  execution_times.append(time.time() - start_time)

  all_df.append(exp_to_df(experiment).sort_values(by=["trial_index"]))
  all_outcomes.append(np.array(exp_to_df(experiment)[['a', 'b']], dtype=np.double))
# Out:
# Sample: 100%|██████████| 48/48 [00:26,  1.83it/s, step size=5.74e-01, acc. prob=0.141]
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=2.76e-01, acc. prob=0.912]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:15,  3.10it/s, step size=4.34e-01, acc. prob=0.196]
# Sample: 100%|██████████| 48/48 [00:10,  4.65it/s, step size=4.89e-01, acc. prob=0.119]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.73it/s, step size=2.76e-01, acc. prob=0.918]
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=4.38e-01, acc. prob=0.442]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:11,  4.32it/s, step size=3.29e-01, acc. prob=0.133]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=2.64e-01, acc. prob=0.841]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=4.91e-01, acc. prob=0.714]
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=1.07e-01, acc. prob=0.940]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=3.03e-01, acc. prob=0.795]
# Sample: 100%|██████████| 48/48 [00:16,  2.87it/s, step size=3.57e-01, acc. prob=0.875]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 6, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.67it/s, step size=4.72e-01, acc. prob=0.751]
# Sample: 100%|██████████| 48/48 [00:18,  2.55it/s, step size=3.17e-01, acc. prob=0.821]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 7, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:12,  3.79it/s, step size=4.76e-01, acc. prob=0.258]
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=3.75e-01, acc. prob=0.704]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 8, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.66it/s, step size=6.04e-01, acc. prob=0.230]
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=6.08e-02, acc. prob=0.953]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 9, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:11,  4.32it/s, step size=2.12e-01, acc. prob=0.086]
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=2.64e-01, acc. prob=0.802]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 10, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:11,  4.05it/s, step size=5.47e-01, acc. prob=0.105]
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=1.64e-01, acc. prob=0.872]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=4.07e-01, acc. prob=0.658]
# Sample: 100%|██████████| 48/48 [00:16,  2.87it/s, step size=4.92e-01, acc. prob=0.798]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:14,  3.23it/s, step size=5.74e-01, acc. prob=0.229]
# Sample: 100%|██████████| 48/48 [00:17,  2.69it/s, step size=2.30e-01, acc. prob=0.731]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.68it/s, step size=4.09e-01, acc. prob=0.811]
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=3.80e-01, acc. prob=0.327]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.81it/s, step size=9.67e-02, acc. prob=0.915]
# Sample: 100%|██████████| 48/48 [00:18,  2.62it/s, step size=2.57e-01, acc. prob=0.942]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.65it/s, step size=2.77e-01, acc. prob=0.876]
# Sample: 100%|██████████| 48/48 [00:15,  3.06it/s, step size=4.03e-01, acc. prob=0.078]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 6, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=3.98e-01, acc. prob=0.748]
# Sample: 100%|██████████| 48/48 [00:17,  2.81it/s, step size=2.62e-01, acc. prob=0.913]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 7, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.65it/s, step size=5.06e-01, acc. prob=0.607]
# Sample: 100%|██████████| 48/48 [00:17,  2.67it/s, step size=1.99e-01, acc. prob=0.806]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 8, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=4.93e-01, acc. prob=0.488]
# Sample: 100%|██████████| 48/48 [00:17,  2.74it/s, step size=3.62e-01, acc. prob=0.872]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 9, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=1.52e-01, acc. prob=0.978]
# Sample: 100%|██████████| 48/48 [00:17,  2.79it/s, step size=3.90e-01, acc. prob=0.228]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 10, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=7.16e-01, acc. prob=0.182]
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=3.05e-02, acc. prob=0.968]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.55it/s, step size=4.48e-01, acc. prob=0.575]
# Sample: 100%|██████████| 48/48 [00:17,  2.68it/s, step size=4.57e-01, acc. prob=0.791]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=3.51e-01, acc. prob=0.639]
# Sample: 100%|██████████| 48/48 [00:17,  2.78it/s, step size=5.17e-01, acc. prob=0.579]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=1.27e-01, acc. prob=0.711]
# Sample: 100%|██████████| 48/48 [00:15,  3.03it/s, step size=5.87e-01, acc. prob=0.227]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.60it/s, step size=3.74e-01, acc. prob=0.740]
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=5.38e-01, acc. prob=0.658]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.80it/s, step size=5.63e-01, acc. prob=0.245]
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=4.03e-01, acc. prob=0.749]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 6, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.62it/s, step size=3.23e-01, acc. prob=0.902]
# Sample: 100%|██████████| 48/48 [00:18,  2.66it/s, step size=5.08e-01, acc. prob=0.708]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 7, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=9.63e-02, acc. prob=0.957]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=4.38e-01, acc. prob=0.651]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 8, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.78it/s, step size=3.82e-01, acc. prob=0.685]
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=4.12e-01, acc. prob=0.772]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 9, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.74it/s, step size=5.56e-01, acc. prob=0.139]
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=4.23e-01, acc. prob=0.661]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 10, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.55it/s, step size=1.14e-01, acc. prob=0.951]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=3.05e-01, acc. prob=0.877]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=4.81e-01, acc. prob=0.677]
# Sample: 100%|██████████| 48/48 [00:16,  2.97it/s, step size=5.45e-01, acc. prob=0.205]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=8.07e-02, acc. prob=0.873]
# Sample: 100%|██████████| 48/48 [00:16,  2.87it/s, step size=3.57e-01, acc. prob=0.405]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.47it/s, step size=4.37e-01, acc. prob=0.857]
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=4.25e-01, acc. prob=0.832]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=3.89e-01, acc. prob=0.799]
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=3.39e-01, acc. prob=0.876]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.55it/s, step size=5.06e-01, acc. prob=0.601]
# Sample: 100%|██████████| 48/48 [00:18,  2.65it/s, step size=4.37e-01, acc. prob=0.599]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 6, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.60it/s, step size=4.24e-01, acc. prob=0.448]
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=5.64e-01, acc. prob=0.585]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 7, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=3.24e-01, acc. prob=0.911]
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=4.80e-01, acc. prob=0.657]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 8, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=2.79e-01, acc. prob=0.744]
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=3.10e-01, acc. prob=0.886]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 9, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:13,  3.52it/s, step size=3.91e-01, acc. prob=0.321]
# Sample: 100%|██████████| 48/48 [00:18,  2.59it/s, step size=3.44e-01, acc. prob=0.698]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 10, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=3.25e-01, acc. prob=0.889]
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=1.17e-01, acc. prob=0.872]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.76it/s, step size=4.68e-01, acc. prob=0.623]
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=4.44e-01, acc. prob=0.153]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:14,  3.29it/s, step size=2.07e-01, acc. prob=0.433]
# Sample: 100%|██████████| 48/48 [00:13,  3.63it/s, step size=5.68e-01, acc. prob=0.229]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=3.30e-01, acc. prob=0.857]
# Sample: 100%|██████████| 48/48 [00:16,  2.91it/s, step size=4.71e-01, acc. prob=0.256]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=5.06e-01, acc. prob=0.176]
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=2.22e-01, acc. prob=0.873]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=4.96e-01, acc. prob=0.748]
# Sample: 100%|██████████| 48/48 [00:19,  2.53it/s, step size=3.28e-01, acc. prob=0.908]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 6, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=4.00e-01, acc. prob=0.815]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=3.44e-01, acc. prob=0.854]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 7, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=4.53e-01, acc. prob=0.580]
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=1.71e-01, acc. prob=0.519]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 8, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:14,  3.43it/s, step size=6.84e-01, acc. prob=0.170]
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=2.50e-01, acc. prob=0.933]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 9, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.71it/s, step size=4.37e-01, acc. prob=0.445]
# Sample: 100%|██████████| 48/48 [00:16,  2.98it/s, step size=6.83e-01, acc. prob=0.236]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 10, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=2.76e-01, acc. prob=0.873]
# Sample: 100%|██████████| 48/48 [00:14,  3.21it/s, step size=1.47e-01, acc. prob=0.328]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=4.44e-01, acc. prob=0.685]
# Sample: 100%|██████████| 48/48 [00:19,  2.48it/s, step size=5.05e-01, acc. prob=0.490]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
# ...
#   warnings.warn(
# Execution: 9, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:16,  2.84it/s, step size=4.92e-01, acc. prob=0.812]
# Sample: 100%|██████████| 48/48 [00:17,  2.67it/s, step size=4.95e-01, acc. prob=0.760]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:13,  3.48it/s, step size=6.29e-01, acc. prob=0.055]
# Sample: 100%|██████████| 48/48 [00:17,  2.76it/s, step size=6.56e-02, acc. prob=0.915]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.60it/s, step size=4.25e-01, acc. prob=0.794]
# Sample: 100%|██████████| 48/48 [00:17,  2.67it/s, step size=5.05e-01, acc. prob=0.641]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 6, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:10,  4.51it/s, step size=6.06e-01, acc. prob=0.119]
# Sample: 100%|██████████| 48/48 [00:17,  2.68it/s, step size=4.98e-01, acc. prob=0.731]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 7, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=4.51e-01, acc. prob=0.762]
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=5.77e-01, acc. prob=0.574]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 8, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.79it/s, step size=2.19e-01, acc. prob=0.915]
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=4.62e-01, acc. prob=0.687]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 9, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=5.51e-01, acc. prob=0.606]
# Sample: 100%|██████████| 48/48 [00:09,  4.82it/s, step size=5.19e-01, acc. prob=0.201]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 10, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=5.78e-01, acc. prob=0.485]
# Sample: 100%|██████████| 48/48 [00:17,  2.71it/s, step size=1.79e-01, acc. prob=0.799]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.66it/s, step size=3.77e-01, acc. prob=0.862]
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=4.39e-01, acc. prob=0.821]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=3.91e-01, acc. prob=0.866]
# Sample: 100%|██████████| 48/48 [00:12,  3.94it/s, step size=3.79e-01, acc. prob=0.194]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:15,  3.14it/s, step size=4.78e-01, acc. prob=0.382]
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=4.80e-01, acc. prob=0.783]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=5.34e-01, acc. prob=0.332]
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=1.31e-01, acc. prob=0.809]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=3.92e-01, acc. prob=0.686]
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=4.54e-01, acc. prob=0.784]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 6, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.68it/s, step size=4.21e-01, acc. prob=0.806]
# Sample: 100%|██████████| 48/48 [00:18,  2.66it/s, step size=5.10e-01, acc. prob=0.706]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 7, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:17,  2.73it/s, step size=6.20e-01, acc. prob=0.644]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=4.95e-01, acc. prob=0.436]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 8, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:16,  2.92it/s, step size=4.92e-01, acc. prob=0.886]
# Sample: 100%|██████████| 48/48 [00:16,  2.89it/s, step size=3.98e-02, acc. prob=0.871]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 9, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.65it/s, step size=4.97e-01, acc. prob=0.824]
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=4.09e-01, acc. prob=0.684]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 10, HV: 0.0

# %%
from torch import Tensor
# %matplotlib inline

for exec in range(executions):
  fig, axes = plt.subplots(1, 1, figsize=(8,6))
  
  cm = plt.cm.get_cmap('viridis')
  batch_number = all_df[exec].trial_index.values
  sc = axes.scatter(all_outcomes[exec][:, 0], all_outcomes[exec][:,1], c=batch_number, alpha=0.8)
  axes.set_title(f'DTLZ6 Execution #{exec + 1}')
  axes.set_xlabel("Objective 1")
  axes.set_ylabel("Objective 2")
  norm = plt.Normalize(batch_number.min(), batch_number.max())
  sm =  ScalarMappable(norm=norm, cmap=cm)
  fig.subplots_adjust(right=0.9)
  cbar_ax = fig.add_axes([0.93, 0.15, 0.01, 0.7])
  cbar = fig.colorbar(sm, cax=cbar_ax)
  cbar.ax.set_title("Trial")
# Out:
# <ipython-input-26-b08fe6f2abbe>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %%
# %matplotlib inline
fig, axes = plt.subplots(1, 1)
plt.xticks(np.arange(1, executions + 1))

axes.scatter(np.arange(1, executions + 1), np.array(execution_times))
axes.grid(True)
axes.set_xlabel("Execution")
axes.set_ylabel("Time")

print("Execution times:", np.array(execution_times))
print("Average execution time:", np.array(execution_times).sum()/len(execution_times))
# Out:
# Execution times: [367.15730476 369.08419776 382.48120952 381.47077918 369.76241827
#  381.30878091 370.68906331 370.83005548 359.14919066 372.32715845]
# Average execution time: 372.42601583004

# %%
print(all_df)
# Out:
# [    trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol  14.353029  21.394969
# 1             1      1_0      RUNNING             Sobol  26.593807   9.071811
# 2             2      2_0      RUNNING             Sobol  20.295498  18.699998
# 3             3      3_0      RUNNING             Sobol   7.470847  26.650192
# 4             4      4_0      RUNNING             Sobol   3.811828  27.501773
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  26.045584  10.097293
# 68           68     68_0      RUNNING  FullyBayesianMOO   1.909034  27.173137
# 69           69     69_0      RUNNING  FullyBayesianMOO  10.993260  24.487550
# 70           70     70_0      RUNNING  FullyBayesianMOO  26.768204   8.068073
# 71           71     71_0      RUNNING  FullyBayesianMOO  17.368314  21.490720
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.623821  0.212883  0.835572  ...  0.396080  0.058156
# 1         False  0.209287  0.611646  0.393772  ...  0.801217  0.794973
# 2         False  0.473967  0.356460  0.746264  ...  0.072601  0.742694
# 3         False  0.826002  0.944021  0.055382  ...  0.730224  0.481463
# 4         False  0.912321  0.384603  0.326844  ...  0.337342  0.218448
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.235447  0.945840  0.291182  ...  0.788760  0.539188
# 68        False  0.955348  0.526138  0.151723  ...  0.059896  0.286312
# 69        False  0.731368  0.194716  0.567089  ...  0.044387  0.074671
# 70        False  0.186367  0.549591  0.073125  ...  0.881790  0.055460
# 71        False  0.567285  0.134731  0.332435  ...  0.298569  0.865499
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.090065  0.593977  0.261753  0.429751  0.087322  0.394324  0.761817
# 1   0.655199  0.485592  0.649266  0.758883  0.749706  0.607286  0.459273
# 2   0.399563  0.810278  0.079180  0.579281  0.376882  0.972808  0.569505
# 3   0.839788  0.168690  0.943134  0.218897  0.788290  0.025583  0.153803
# 4   0.335452  0.103142  0.782395  0.634348  0.253467  0.625692  0.943817
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.744482  0.463568  0.762813  0.286413  0.777484  0.457024  0.865381
# 68  0.752774  0.141249  0.522627  0.491151  0.257704  0.698312  0.306541
# 69  0.896184  0.378269  0.027079  0.324703  0.662015  0.045918  0.047470
# 70  0.179795  0.641289  0.133028  0.833720  0.929600  0.911775  0.373676
# 71  0.744835  0.195132  0.309586  0.512425  0.387730  0.863634  0.441508
#
#          x29
# 0   0.255851
# 1   0.630210
# 2   0.982878
# 3   0.108275
# 4   0.480990
# ..       ...
# 67  0.995976
# 68  0.312205
# 69  0.349130
# 70  0.037639
# 71  0.395408
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol  27.240082   0.586733
# 1             1      1_0      RUNNING             Sobol  14.300169  23.122390
# 2             2      2_0      RUNNING             Sobol   5.550446  26.745985
# 3             3      3_0      RUNNING             Sobol  20.673237  18.881259
# 4             4      4_0      RUNNING             Sobol  24.285427  11.332016
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  14.508431  22.928026
# 68           68     68_0      RUNNING  FullyBayesianMOO  25.366730   8.507134
# 69           69     69_0      RUNNING  FullyBayesianMOO  14.683489  22.969519
# 70           70     70_0      RUNNING  FullyBayesianMOO   4.369964  26.983750
# 71           71     71_0      RUNNING  FullyBayesianMOO  12.402017  24.306353
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.013710  0.494471  0.981884  ...  0.034417  0.447471
# 1         False  0.647389  0.865203  0.092625  ...  0.905205  0.611005
# 2         False  0.869735  0.206357  0.636281  ...  0.263487  0.810153
# 3         False  0.471178  0.590753  0.304836  ...  0.671996  0.130884
# 4         False  0.277940  0.084244  0.224808  ...  0.180047  0.349106
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.640835  0.719126  0.567632  ...  0.276237  0.750606
# 68        False  0.205997  0.785736  0.220715  ...  0.340339  0.287973
# 69        False  0.637898  0.471442  0.783250  ...  0.579480  0.069933
# 70        False  0.897788  0.605995  0.767850  ...  0.988176  0.436867
# 71        False  0.699640  0.328961  0.538704  ...  0.754095  0.145815
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.754855  0.928617  0.339817  0.658164  0.502881  0.550028  0.247001
# 1   0.034649  0.042052  0.533208  0.191422  0.080875  0.160979  0.608548
# 2   0.671129  0.727298  0.227846  0.312732  0.891584  0.303189  0.332961
# 3   0.383539  0.364411  0.891267  0.786916  0.438327  0.907817  0.944555
# 4   0.615332  0.483496  0.805606  0.384779  0.820617  0.038358  0.106915
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.309454  0.600358  0.732699  0.535793  0.192753  0.661179  0.263184
# 68  0.499364  0.290668  0.875790  0.101450  0.057115  0.565597  0.615375
# 69  0.514438  0.618522  0.621007  0.934181  0.360594  0.710135  0.563002
# 70  0.137165  0.396400  0.178447  0.218196  0.014964  0.327712  0.178912
# 71  0.798023  0.704368  0.669662  0.150401  0.648813  0.833318  0.563869
#
#          x29
# 0   0.227453
# 1   0.911249
# 2   0.511351
# 3   0.318758
# 4   0.113659
# ..       ...
# 67  0.460255
# 68  0.611081
# 69  0.056449
# 70  0.841713
# 71  0.131548
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol  12.819018  25.034124
# 1             1      1_0      RUNNING             Sobol  26.900999   0.309414
# 2             2      2_0      RUNNING             Sobol  23.818921  13.869473
# 3             3      3_0      RUNNING             Sobol   4.113897  26.536648
# 4             4      4_0      RUNNING             Sobol   7.197260  25.993438
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  11.833678  24.285563
# 68           68     68_0      RUNNING  FullyBayesianMOO   8.951985  25.303684
# 69           69     69_0      RUNNING  FullyBayesianMOO  25.251225  10.498384
# 70           70     70_0      RUNNING  FullyBayesianMOO   3.984357  27.231308
# 71           71     71_0      RUNNING  FullyBayesianMOO   9.941426  25.367292
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.698719  0.949692  0.680675  ...  0.961572  0.384681
# 1         False  0.007322  0.277066  0.022621  ...  0.406219  0.765187
# 2         False  0.335686  0.576254  0.766075  ...  0.607723  0.721806
# 3         False  0.902086  0.150263  0.435909  ...  0.040159  0.098898
# 4         False  0.828036  0.744773  0.188540  ...  0.813745  0.260997
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.711348  0.028959  0.110298  ...  0.292539  0.670340
# 68        False  0.783524  0.553900  0.673244  ...  0.505033  0.407889
# 69        False  0.250838  0.094629  0.218982  ...  0.295125  0.196763
# 70        False  0.907509  0.276215  0.823058  ...  0.284397  0.625389
# 71        False  0.762220  0.108116  0.103702  ...  0.942872  0.997465
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.287606  0.627411  0.683653  0.534535  0.919167  0.302348  0.212419
# 1   0.776471  0.276415  0.419124  0.263808  0.237967  0.919591  0.557582
# 2   0.062009  0.903002  0.793346  0.182727  0.622427  0.597428  0.297593
# 3   0.502831  0.005707  0.059828  0.896858  0.284954  0.246062  0.956844
# 4   0.191105  0.158275  0.212377  0.015678  0.747533  0.764580  0.035613
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.230678  0.585052  0.410625  0.757768  0.010741  0.662172  0.678508
# 68  0.998468  0.662334  0.617646  0.180820  0.777043  0.715075  0.920160
# 69  0.287007  0.605096  0.534107  0.193893  0.961335  0.409922  0.530176
# 70  0.285752  0.628409  0.605295  0.552363  0.539568  0.463245  0.042762
# 71  0.246377  0.491371  0.220390  0.388956  0.621176  0.792496  0.246357
#
#          x29
# 0   0.807233
# 1   0.365689
# 2   0.058597
# 3   0.610278
# 4   0.975718
# ..       ...
# 67  0.085809
# 68  0.107804
# 69  0.119032
# 70  0.082920
# 71  0.394649
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol  15.136898  22.784502
# 1             1      1_0      RUNNING             Sobol  24.037440  12.616699
# 2             2      2_0      RUNNING             Sobol  26.886523   1.418312
# 3             3      3_0      RUNNING             Sobol   4.317982  27.094392
# 4             4      4_0      RUNNING             Sobol   8.287557  26.151382
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  24.763005   9.343523
# 68           68     68_0      RUNNING  FullyBayesianMOO   7.413790  26.545690
# 69           69     69_0      RUNNING  FullyBayesianMOO  26.642897   7.639376
# 70           70     70_0      RUNNING  FullyBayesianMOO  18.146443  20.272730
# 71           71     71_0      RUNNING  FullyBayesianMOO  26.763288   7.758569
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.626688  0.005452  0.157020  ...  0.334819  0.094711
# 1         False  0.307711  0.666428  0.665590  ...  0.636959  0.559125
# 2         False  0.033552  0.439824  0.363154  ...  0.042043  0.757107
# 3         False  0.899389  0.857026  0.869656  ...  0.986241  0.339080
# 4         False  0.804625  0.297385  0.560658  ...  0.387445  0.225611
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.229693  0.718907  0.488205  ...  0.405218  0.683070
# 68        False  0.826620  0.633268  0.625653  ...  0.883361  0.027424
# 69        False  0.177770  0.293847  0.441262  ...  0.586061  0.778026
# 70        False  0.535197  0.675990  0.808697  ...  0.038536  0.202979
# 71        False  0.179630  0.803656  0.356728  ...  0.088069  0.810525
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.573343  0.835876  0.880431  0.726432  0.560156  0.897629  0.359556
# 1   0.053008  0.461679  0.054112  0.270666  0.146794  0.367818  0.802546
# 2   0.861655  0.513978  0.542804  0.124235  0.968059  0.000825  0.183326
# 3   0.264681  0.126456  0.399605  0.888440  0.363779  0.733709  0.748385
# 4   0.919434  0.074644  0.267673  0.207702  0.808128  0.473371  0.469276
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.746378  0.156301  0.962430  0.898655  0.086933  0.397258  0.117498
# 68  0.937557  0.259241  0.501277  0.351057  0.401690  0.872517  0.206592
# 69  0.656936  0.201777  0.548303  0.228259  0.299602  0.392996  0.093797
# 70  0.587060  0.164425  0.326679  0.283825  0.917988  0.402293  0.076954
# 71  0.607681  0.682351  0.237469  0.609803  0.185679  0.286518  0.952459
#
#          x29
# 0   0.064873
# 1   0.695484
# 2   0.928167
# 3   0.308789
# 4   0.158608
# ..       ...
# 67  0.926974
# 68  0.303813
# 69  0.936997
# 70  0.697114
# 71  0.854119
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol   3.449181  26.514930
# 1             1      1_0      RUNNING             Sobol  21.996569  15.992738
# 2             2      2_0      RUNNING             Sobol  25.220066   9.807208
# 3             3      3_0      RUNNING             Sobol  12.864224  24.403719
# 4             4      4_0      RUNNING             Sobol  15.912793  22.786267
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO   1.855994  27.345514
# 68           68     68_0      RUNNING  FullyBayesianMOO  19.083123  19.282661
# 69           69     69_0      RUNNING  FullyBayesianMOO  18.560837  19.751484
# 70           70     70_0      RUNNING  FullyBayesianMOO  13.581577  24.000437
# 71           71     71_0      RUNNING  FullyBayesianMOO  10.346883  25.313511
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.917648  0.172817  0.332364  ...  0.820156  0.048991
# 1         False  0.400214  0.847064  0.722362  ...  0.145237  0.625029
# 2         False  0.236104  0.466768  0.195296  ...  0.700210  0.791426
# 3         False  0.691160  0.514083  0.859490  ...  0.279716  0.398707
# 4         False  0.611905  0.326191  0.623064  ...  0.981778  0.161875
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.956858  0.792221  0.944950  ...  0.161139  0.507389
# 68        False  0.503311  0.041893  0.246708  ...  0.546952  0.543632
# 69        False  0.519778  0.185068  0.205522  ...  0.159362  0.572143
# 70        False  0.672166  0.772839  0.876153  ...  0.173511  0.017270
# 71        False  0.752975  0.594987  0.744318  ...  0.405513  0.162084
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.614249  0.712113  0.327100  0.889520  0.855590  0.035786  0.487534
# 1   0.252021  0.287654  0.610638  0.367919  0.323810  0.956302  0.864469
# 2   0.945672  0.908633  0.098641  0.095613  0.664038  0.532402  0.044300
# 3   0.186226  0.091591  0.838600  0.647986  0.125437  0.459762  0.667322
# 4   0.856807  0.249551  0.935955  0.163836  0.580428  0.863735  0.365864
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.205106  0.736712  0.978503  0.319513  0.012055  0.706265  0.735667
# 68  0.531139  0.208704  0.985092  0.596257  0.897429  0.362953  0.224329
# 69  0.447931  0.477301  0.504873  0.225478  0.925094  0.712086  0.181097
# 70  0.565473  0.516909  0.613454  0.068346  0.282435  0.683198  0.776298
# 71  0.488721  0.740966  0.545787  0.698546  0.744275  0.402483  0.921749
#
#          x29
# 0   0.831248
# 1   0.325986
# 2   0.130155
# 3   0.652079
# 4   0.952871
# ..       ...
# 67  0.086279
# 68  0.336185
# 69  0.433527
# 70  0.377985
# 71  0.565659
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol  19.577677  19.498549
# 1             1      1_0      RUNNING             Sobol  12.291397  24.197537
# 2             2      2_0      RUNNING             Sobol   6.034918  25.898993
# 3             3      3_0      RUNNING             Sobol  27.689396   3.844572
# 4             4      4_0      RUNNING             Sobol  26.408045   7.969566
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  25.343892  10.004428
# 68           68     68_0      RUNNING  FullyBayesianMOO  25.302392  10.414367
# 69           69     69_0      RUNNING  FullyBayesianMOO  10.980177  25.636417
# 70           70     70_0      RUNNING  FullyBayesianMOO  21.185435  18.068042
# 71           71     71_0      RUNNING  FullyBayesianMOO  27.829541   4.819606
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.498711  0.784330  0.108958  ...  0.884162  0.103926
# 1         False  0.700791  0.001352  0.699852  ...  0.355967  0.753110
# 2         False  0.854257  0.669280  0.367028  ...  0.584929  0.549472
# 3         False  0.087831  0.389720  0.957897  ...  0.174884  0.339768
# 4         False  0.186589  0.595417  0.503387  ...  0.763866  0.243200
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.239350  0.240364  0.183607  ...  0.124062  0.041825
# 68        False  0.248576  0.862873  0.113405  ...  0.897594  0.007148
# 69        False  0.742382  0.570576  0.604036  ...  0.824733  0.121310
# 70        False  0.449547  0.614529  0.500200  ...  0.274672  0.718915
# 71        False  0.109169  0.696015  0.256234  ...  0.605155  0.283284
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.913358  0.748688  0.231839  0.885463  0.047164  0.926865  0.375993
# 1   0.300029  0.017551  0.648146  0.403415  0.656026  0.254895  0.700850
# 2   0.586346  0.856279  0.367690  0.104932  0.403951  0.225758  0.116025
# 3   0.199305  0.378436  0.752286  0.621938  0.798996  0.585159  0.807010
# 4   0.727921  0.321636  0.930067  0.167606  0.286347  0.389049  0.327722
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.646333  0.365889  0.325391  0.639811  0.766805  0.883555  0.495392
# 68  0.088866  0.906285  0.518392  0.944878  0.510797  0.635597  0.123673
# 69  0.847074  0.876238  0.599862  0.080828  0.833045  0.479650  0.958404
# 70  0.751311  0.098194  0.821062  0.579735  0.714910  0.669462  0.817878
# 71  0.575701  0.859558  0.726780  0.688208  0.794204  0.538417  0.359282
#
#          x29
# 0   0.539831
# 1   0.161534
# 2   0.256066
# 3   0.886316
# 4   0.705608
# ..       ...
# 67  0.490079
# 68  0.289477
# 69  0.495980
# 70  0.574396
# 71  0.074090
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol  24.230462  12.784291
# 1             1      1_0      RUNNING             Sobol   0.258632  26.786001
# 2             2      2_0      RUNNING             Sobol  13.743927  23.397645
# 3             3      3_0      RUNNING             Sobol  27.473833   4.077400
# 4             4      4_0      RUNNING             Sobol  25.542377  10.317842
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  19.861318  18.598530
# 68           68     68_0      RUNNING  FullyBayesianMOO   2.159455  27.389717
# 69           69     69_0      RUNNING  FullyBayesianMOO  19.214498  19.756446
# 70           70     70_0      RUNNING  FullyBayesianMOO  27.292823   1.683482
# 71           71     71_0      RUNNING  FullyBayesianMOO   4.638304  27.423773
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.309074  0.242714  0.260865  ...  0.135834  0.660185
# 1         False  0.993853  0.663228  0.620925  ...  0.735399  0.499069
# 2         False  0.661886  0.437524  0.179244  ...  0.426045  0.153701
# 3         False  0.093796  0.905924  0.944795  ...  0.951482  0.943757
# 4         False  0.244403  0.272352  0.644319  ...  0.052090  0.530894
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.479105  0.804753  0.969584  ...  0.159853  0.771918
# 68        False  0.949911  0.690772  0.921666  ...  0.653625  0.090814
# 69        False  0.508853  0.347442  0.637826  ...  0.544382  0.345192
# 70        False  0.039218  0.590061  0.345805  ...  0.179602  0.081573
# 71        False  0.893335  0.666428  0.878455  ...  0.139605  0.343335
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.510804  0.780484  0.023285  0.682816  0.498498  0.303933  0.216649
# 1   0.009624  0.055618  0.894589  0.338299  0.877471  0.540017  0.501379
# 2   0.783613  0.654221  0.408226  0.035882  0.104968  0.935602  0.492836
# 3   0.281867  0.431796  0.533070  0.943241  0.523000  0.158014  0.785256
# 4   0.989850  0.341836  0.633082  0.144458  0.189210  0.698751  0.051141
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.977606  0.289887  0.488535  0.061846  0.976410  0.085187  0.766552
# 68  0.876677  0.983664  0.117102  0.690316  0.723318  0.417710  0.217284
# 69  0.956250  0.502333  0.239807  0.909612  0.273329  0.731052  0.318362
# 70  0.223551  0.160161  0.948679  0.546348  0.609129  0.750924  0.136521
# 71  0.808189  0.362305  0.587506  0.254978  0.740121  0.034880  0.711184
#
#          x29
# 0   0.440248
# 1   0.522829
# 2   0.908460
# 3   0.117140
# 4   0.323643
# ..       ...
# 67  0.281544
# 68  0.965768
# 69  0.943683
# 70  0.732880
# 71  0.359907
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol   4.501479  25.467356
# 1             1      1_0      RUNNING             Sobol  26.945542   8.379271
# 2             2      2_0      RUNNING             Sobol  22.163550  16.034224
# 3             3      3_0      RUNNING             Sobol  12.350709  24.653624
# 4             4      4_0      RUNNING             Sobol  17.983113  21.437716
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  12.475896  24.174737
# 68           68     68_0      RUNNING  FullyBayesianMOO  16.885814  21.204854
# 69           69     69_0      RUNNING  FullyBayesianMOO  26.601890   6.752039
# 70           70     70_0      RUNNING  FullyBayesianMOO  20.352670  18.288140
# 71           71     71_0      RUNNING  FullyBayesianMOO  16.392233  22.296664
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.888625  0.446134  0.300996  ...  0.721359  0.918078
# 1         False  0.191935  0.916888  0.732811  ...  0.273872  0.349348
# 2         False  0.398710  0.051284  0.160557  ...  0.953476  0.077166
# 3         False  0.704339  0.584656  0.873256  ...  0.041511  0.631482
# 4         False  0.555647  0.151866  0.564974  ...  0.610957  0.862711
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.696700  0.344730  0.206229  ...  0.439237  0.326779
# 68        False  0.571878  0.468871  0.143452  ...  0.994821  0.547464
# 69        False  0.158244  0.904433  0.415228  ...  0.803035  0.158877
# 70        False  0.466019  0.832910  0.459779  ...  0.701001  0.582669
# 71        False  0.596413  0.693550  0.972501  ...  0.187440  0.615006
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.479822  0.161501  0.662038  0.220035  0.057378  0.131496  0.464173
# 1   0.820993  0.866297  0.246535  0.895133  0.725964  0.624503  0.578299
# 2   0.082811  0.283189  0.855670  0.644927  0.442977  0.928736  0.124063
# 3   0.741365  0.737833  0.302406  0.470378  0.773659  0.327018  0.988738
# 4   0.130642  0.591617  0.460195  0.510159  0.299807  0.647352  0.363881
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.447984  0.915605  0.822942  0.157960  0.228921  0.826005  0.660346
# 68  0.068269  0.094617  0.975106  0.202866  0.474365  0.273564  0.965641
# 69  0.001028  0.695461  0.694838  0.083072  0.919148  0.455500  0.815277
# 70  0.814340  0.526816  0.234654  0.890293  0.034814  0.846499  0.736104
# 71  0.277448  0.718382  0.449737  0.699470  0.205660  0.713973  0.826106
#
#          x29
# 0   0.281345
# 1   0.652917
# 2   0.851980
# 3   0.207901
# 4   0.440685
# ..       ...
# 67  0.684026
# 68  0.147858
# 69  0.230098
# 70  0.031636
# 71  0.373922
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol  12.039441  24.928725
# 1             1      1_0      RUNNING             Sobol  27.171701   2.681812
# 2             2      2_0      RUNNING             Sobol  22.386196  15.884783
# 3             3      3_0      RUNNING             Sobol  10.266429  25.771058
# 4             4      4_0      RUNNING             Sobol   1.424184  27.427054
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  21.452489  16.231056
# 68           68     68_0      RUNNING  FullyBayesianMOO   5.140148  27.316975
# 69           69     69_0      RUNNING  FullyBayesianMOO  17.756308  20.922031
# 70           70     70_0      RUNNING  FullyBayesianMOO  15.441101  21.833644
# 71           71     71_0      RUNNING  FullyBayesianMOO  22.245703  15.471664
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.713573  0.606509  0.589642  ...  0.952470  0.582590
# 1         False  0.062631  0.487596  0.146490  ...  0.415061  0.195477
# 2         False  0.392875  0.890868  0.755430  ...  0.741987  0.443829
# 3         False  0.758657  0.014050  0.445579  ...  0.142193  0.838633
# 4         False  0.966972  0.864513  0.048354  ...  0.848604  0.678671
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.412348  0.571344  0.349097  ...  0.133610  0.309169
# 68        False  0.881594  0.351334  0.056167  ...  0.845682  0.330801
# 69        False  0.551990  0.070900  0.304038  ...  0.639792  0.547956
# 70        False  0.608127  0.710301  0.719262  ...  0.837615  0.127497
# 71        False  0.386869  0.899406  0.892222  ...  0.150012  0.136622
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.969875  0.761472  0.338024  0.532026  0.495859  0.633433  0.831714
# 1   0.192868  0.233474  0.684726  0.490474  0.644419  0.096308  0.113260
# 2   0.740034  0.712297  0.104615  0.226291  0.161740  0.453810  0.625108
# 3   0.454661  0.310337  0.886885  0.798147  0.950924  0.807189  0.406536
# 4   0.578783  0.465801  0.762467  0.004430  0.050772  0.217506  0.993875
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.208666  0.043525  0.834891  0.060166  0.291330  0.417733  0.158755
# 68  0.389797  0.938376  0.967335  0.865657  0.891365  0.209712  0.388980
# 69  0.088957  0.937295  0.881625  0.727434  0.588688  0.567054  0.803923
# 70  0.280841  0.988641  0.549291  0.701592  0.712003  0.184128  0.339909
# 71  0.476808  0.692266  0.439142  0.605159  0.508586  0.404548  0.661137
#
#          x29
# 0   0.882420
# 1   0.472295
# 2   0.023858
# 3   0.621423
# 4   0.793786
# ..       ...
# 67  0.454950
# 68  0.311147
# 69  0.692922
# 70  0.408896
# 71  0.243151
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method          a          b  \
# 0             0      0_0      RUNNING             Sobol  23.631799  12.261091
# 1             1      1_0      RUNNING             Sobol  15.319131  23.122023
# 2             2      2_0      RUNNING             Sobol   9.061390  25.746811
# 3             3      3_0      RUNNING             Sobol  26.995286   6.494671
# 4             4      4_0      RUNNING             Sobol  27.432421   0.933741
# ..          ...      ...          ...               ...        ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  22.187236  15.548106
# 68           68     68_0      RUNNING  FullyBayesianMOO  25.109151  10.436131
# 69           69     69_0      RUNNING  FullyBayesianMOO  17.808168  20.353893
# 70           70     70_0      RUNNING  FullyBayesianMOO  26.152486   8.514510
# 71           71     71_0      RUNNING  FullyBayesianMOO  27.090943   4.303191
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0         False  0.304689  0.213049  0.407592  ...  0.460516  0.596304
# 1         False  0.627491  0.536947  0.875634  ...  0.533972  0.175619
# 2         False  0.784565  0.416919  0.187714  ...  0.060034  0.444157
# 3         False  0.150305  0.833069  0.720466  ...  0.945441  0.773045
# 4         False  0.021661  0.266339  0.826339  ...  0.334447  0.631875
# ..          ...       ...       ...       ...  ...       ...       ...
# 67        False  0.389128  0.423053  0.197621  ...  0.955009  0.603290
# 68        False  0.250770  0.338918  0.169901  ...  0.231931  0.177449
# 69        False  0.542405  0.546232  0.363202  ...  0.511020  0.474484
# 70        False  0.200375  0.620138  0.173470  ...  0.425019  0.116803
# 71        False  0.100284  0.688140  0.442893  ...  0.950482  0.521040
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.790754  0.846534  0.252693  0.555994  0.494270  0.031547  0.552894
# 1   0.364998  0.341935  0.922079  0.260176  0.813522  0.981676  0.161953
# 2   0.734160  0.506467  0.224997  0.005122  0.120993  0.603728  0.798267
# 3   0.175530  0.057018  0.582588  0.802747  0.688292  0.413354  0.408761
# 4   0.567058  0.146894  0.688960  0.172840  0.166774  0.825965  0.638243
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.580757  0.689409  0.494511  0.870065  0.098542  0.621864  0.291588
# 68  0.510165  0.407672  0.693100  0.013027  0.821618  0.443764  0.290697
# 69  0.601378  0.024543  0.540026  0.540844  0.181750  0.744348  0.181035
# 70  0.185474  0.611512  0.482715  0.900752  0.851656  0.479017  0.633473
# 71  0.214221  0.651136  0.141874  0.113044  0.217845  0.219667  0.790106
#
#          x29
# 0   0.152259
# 1   0.768735
# 2   0.729304
# 3   0.345734
# 4   0.022112
# ..       ...
# 67  0.599812
# 68  0.477262
# 69  0.639801
# 70  0.952939
# 71  0.283053
#
# [72 rows x 37 columns]]
