# %%
# !lscpu |grep 'Model name'
# !nvidia-smi
# !pip install ax-platform 
# !pip install bitarray
# Out:
# Model name:                      Intel(R) Xeon(R) CPU @ 2.30GHz
# Mon Mar 20 02:56:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0    21W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ax-platform in /usr/local/lib/python3.9/dist-packages (0.3.1)
# Requirement already satisfied: typeguard==2.13.3 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (2.13.3)
# Requirement already satisfied: botorch==0.8.3 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (0.8.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.10.1)
# Requirement already satisfied: plotly>=5.12.0 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (5.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.4.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.2.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from ax-platform) (7.7.1)
# Requirement already satisfied: pyro-ppl>=1.8.4 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.8.4)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (0.6.0)
# Requirement already satisfied: linear-operator==0.3.0 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (0.3.0)
# Requirement already satisfied: gpytorch==1.9.1 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.9.1)
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.13.1+cu116)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.12.0->ax-platform) (8.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (7.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.6.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->ax-platform) (2.1.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (1.1.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.1.12)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.6.1)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.18.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (63.4.3)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (0.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (3.3.0)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (4.65.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->ax-platform) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.12->botorch==0.8.3->ax-platform) (4.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->ax-platform) (0.8.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.2.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.4)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.16.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.17.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.7.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ax-platform) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->ax-platform) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.1.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.2.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.9.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.16.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (22.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.21)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bitarray in /usr/local/lib/python3.9/dist-packages (2.7.3)

# %%
import pandas as pd
from ax import *
import torch
from torch import Tensor

import numpy as np
import math
from bitarray import util as ba

from matplotlib import pyplot as plt
from matplotlib.cm import ScalarMappable

from ax.service.utils.report_utils import exp_to_df
from ax.runners.synthetic import SyntheticRunner
from ax.metrics.noisy_function import GenericNoisyFunctionMetric

# Analysis utilities, including a method to evaluate hypervolumes
from ax.modelbridge.modelbridge_utils import observed_hypervolume

from botorch.test_functions.multi_objective import ZDT

# %%
class ZDT5(ZDT):
    def u(self, x_i, length):
      return ba.int2ba(int(x_i), length=int(length)).count()


    def v(self, u_i):
      return (2 + u_i)*(u_i < 5) + 1*(u_i == 5)


    def evaluate_true(self, X: Tensor):
        bits_per_variable = [30]
        for i in range(1, self.dim):
            bits_per_variable.append(5)

        u_x = Tensor([self.u(X[..., i].item(), bits_per_variable[i]) for i in range(self.dim)])
        v_x = Tensor([self.v(u_x[..., i].item()) for i in range(1, self.dim)])
        g = v_x.sum()
        
        f_0 = 1 + u_x[..., 0]
        f_1 = g * (1/f_0)

        return torch.stack([f_0, f_1], dim=-1)


    def gen_pareto_front(self, n: int, normalize=True):
          f_0 = []
          f_1 = []
          for u in range(31):
              g = self.dim - 1
              f_0_n = 1 + u
              f_0.append(f_0_n)
              f_1.append(g * (1/f_0_n))
              
          f_0 = Tensor(f_0)
          f_1 = Tensor(f_1)

          if (normalize):
              f_0 = (Tensor(f_0) - 1) / (31 - 1)
              f_1 = (Tensor(f_1) - (10/31)) / (10 - (10/31))

          f_X = torch.stack([f_0, f_1], dim=1)

          if self.negate:
            f_X *= -1

          return f_X

# %%
tkwargs = {
    "dtype": torch.double, 
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
}

# %%
dim = 30
problem = ZDT5(num_objectives=2, dim=dim, negate=False).to(**tkwargs)

param_names = [f"x{i}" for i in range(dim)]

def f1(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names] # Obtiene los parámetros a evaluar
        return float(problem(torch.tensor(x_sorted, **tkwargs))[0]) # Evalúa los parámetros en el primer objetivo
    
def f2(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names]
        return float(problem(torch.tensor(x_sorted, **tkwargs))[1]) # Evalúa los parámetros en el segundo objetivo

metric_a = GenericNoisyFunctionMetric("a", f=f1, noise_sd=0.0, lower_is_better=True)
metric_b = GenericNoisyFunctionMetric("b", f=f2, noise_sd=0.0, lower_is_better=True)

# %%
parameters = [RangeParameter(name=param_names[0], lower=0, upper=(2**30)-1, parameter_type=ParameterType.INT)]
for param_name in param_names[1:]:
  parameters.append(RangeParameter(name=param_name, lower=0, upper=(2**5)-1, parameter_type=ParameterType.INT))

search_space = SearchSpace(
    parameters=parameters
)

mo = MultiObjective(
    objectives=[Objective(metric=metric_a), Objective(metric=metric_b)],
)

objective_thresholds = [
    ObjectiveThreshold(metric=metric, bound=val, relative=False)
    for metric, val in zip(mo.metrics, problem.ref_point)
]

optimization_config = MultiObjectiveOptimizationConfig(
    objective=mo,
    objective_thresholds=objective_thresholds,
)

# %%
N_INIT = 2 * (dim + 1)
N_BATCH = 5
BATCH_SIZE = 1

def build_experiment():
    experiment = Experiment(
        name="pareto_experiment",
        search_space=search_space,
        optimization_config=optimization_config,
        runner=SyntheticRunner(),
    )
    return experiment

def initialize_experiment(experiment):
    sobol = Models.SOBOL(search_space=experiment.search_space)

    for _ in range(N_INIT):
        experiment.new_trial(sobol.gen(1)).run()

    return experiment.fetch_data()

# %%
import time

executions = 10
execution_times = []
all_df = []
all_outcomes = []

for exec in range(executions):
  start_time = time.time()

  experiment = build_experiment()
  data = initialize_experiment(experiment)

  hv_list = []
  model = None
  for i in range(N_BATCH):   
      model = Models.FULLYBAYESIANMOO(
          experiment=experiment, 
          data=data,
          num_samples=16,
          warmup_steps=32,
          torch_dtype=tkwargs["dtype"],
          torch_device=tkwargs["device"],
      )
      generator_run = model.gen(BATCH_SIZE)
      trial = experiment.new_trial(generator_run=generator_run)
      trial.run()
      data = Data.from_multiple_data([data, trial.fetch_data()])
      
      exp_df = exp_to_df(experiment)
      outcomes = np.array(exp_df[['a', 'b']], dtype=np.double)
      try:
          hv = observed_hypervolume(modelbridge=model)
      except:
          hv = 0
          print("Failed to compute hv")
      hv_list.append(hv)
      print(f"Execution: {exec + 1}, Iteration: {i + 1}, HV: {hv}")

  execution_times.append(time.time() - start_time)

  all_df.append(exp_to_df(experiment).sort_values(by=["trial_index"]))
  all_outcomes.append(np.array(exp_to_df(experiment)[['a', 'b']], dtype=np.double))
# Out:
# Sample: 100%|██████████| 48/48 [00:28,  1.66it/s, step size=1.88e-01, acc. prob=0.948]
# Sample: 100%|██████████| 48/48 [00:21,  2.19it/s, step size=4.35e-01, acc. prob=0.682]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:12,  3.82it/s, step size=6.19e-01, acc. prob=0.036]
# Sample: 100%|██████████| 48/48 [00:21,  2.24it/s, step size=7.01e-02, acc. prob=0.433]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.62it/s, step size=3.63e-01, acc. prob=0.206]
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=2.90e-01, acc. prob=0.784]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.55it/s, step size=4.68e-01, acc. prob=0.139]
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=4.87e-01, acc. prob=0.437]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:15,  3.17it/s, step size=4.97e-01, acc. prob=0.229]
# Sample: 100%|██████████| 48/48 [00:20,  2.33it/s, step size=3.80e-01, acc. prob=0.638]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.24it/s, step size=2.85e-01, acc. prob=0.520]
# Sample: 100%|██████████| 48/48 [00:21,  2.22it/s, step size=3.14e-01, acc. prob=0.781]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.24it/s, step size=2.53e-01, acc. prob=0.774]
# Sample: 100%|██████████| 48/48 [00:21,  2.25it/s, step size=1.70e-01, acc. prob=0.790]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.37it/s, step size=4.96e-01, acc. prob=0.093]
# Sample: 100%|██████████| 48/48 [00:21,  2.25it/s, step size=1.99e-01, acc. prob=0.866]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.31it/s, step size=3.35e-01, acc. prob=0.293]
# Sample: 100%|██████████| 48/48 [00:21,  2.24it/s, step size=1.14e-01, acc. prob=0.983]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:22,  2.12it/s, step size=5.78e-01, acc. prob=0.192]
# Sample: 100%|██████████| 48/48 [00:21,  2.20it/s, step size=5.00e-01, acc. prob=0.639]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.27it/s, step size=3.02e-01, acc. prob=0.844]
# Sample: 100%|██████████| 48/48 [00:20,  2.36it/s, step size=3.46e-01, acc. prob=0.591]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.27it/s, step size=5.89e-01, acc. prob=0.213]
# Sample: 100%|██████████| 48/48 [00:20,  2.35it/s, step size=4.68e-01, acc. prob=0.347]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.25it/s, step size=4.43e-01, acc. prob=0.543]
# Sample: 100%|██████████| 48/48 [00:21,  2.24it/s, step size=5.00e-01, acc. prob=0.189]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.35it/s, step size=6.04e-01, acc. prob=0.143]
# Sample: 100%|██████████| 48/48 [00:20,  2.32it/s, step size=3.73e-01, acc. prob=0.487]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.19it/s, step size=3.71e-01, acc. prob=0.791]
# Sample: 100%|██████████| 48/48 [00:21,  2.28it/s, step size=3.35e-01, acc. prob=0.738]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.22it/s, step size=2.56e-01, acc. prob=0.464]
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=2.55e-01, acc. prob=0.554]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.22it/s, step size=4.02e-01, acc. prob=0.575]
# Sample: 100%|██████████| 48/48 [00:20,  2.38it/s, step size=5.20e-01, acc. prob=0.339]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.31it/s, step size=3.03e-01, acc. prob=0.795]
# Sample: 100%|██████████| 48/48 [00:21,  2.27it/s, step size=8.35e-02, acc. prob=0.946]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=6.26e-01, acc. prob=0.137]
# Sample: 100%|██████████| 48/48 [00:22,  2.12it/s, step size=1.17e-01, acc. prob=0.914]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.23it/s, step size=3.56e-01, acc. prob=0.624]
# Sample: 100%|██████████| 48/48 [00:22,  2.11it/s, step size=1.40e-01, acc. prob=0.395]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.23it/s, step size=3.48e-01, acc. prob=0.760]
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=2.67e-01, acc. prob=0.383]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 1, HV: 0.19999980926513672
# Sample: 100%|██████████| 48/48 [00:20,  2.34it/s, step size=2.77e-01, acc. prob=0.881]
# Sample: 100%|██████████| 48/48 [00:22,  2.18it/s, step size=2.31e-01, acc. prob=0.626]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 2, HV: 0.19999980926513672
# Sample: 100%|██████████| 48/48 [00:20,  2.30it/s, step size=1.84e-01, acc. prob=0.941]
# Sample: 100%|██████████| 48/48 [00:21,  2.26it/s, step size=4.90e-01, acc. prob=0.693]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 3, HV: 0.19999980926513672
# Sample: 100%|██████████| 48/48 [00:21,  2.27it/s, step size=4.49e-01, acc. prob=0.531]
# Sample: 100%|██████████| 48/48 [00:22,  2.16it/s, step size=1.76e-01, acc. prob=0.854]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 4, HV: 0.19999980926513672
# Sample: 100%|██████████| 48/48 [00:21,  2.26it/s, step size=3.37e-01, acc. prob=0.858]
# Sample: 100%|██████████| 48/48 [00:22,  2.16it/s, step size=3.59e-01, acc. prob=0.695]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 5, HV: 0.19999980926513672
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=1.82e-01, acc. prob=0.951]
# Sample: 100%|██████████| 48/48 [00:11,  4.35it/s, step size=6.86e-01, acc. prob=0.057]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=5.73e-01, acc. prob=0.170]
# Sample: 100%|██████████| 48/48 [00:19,  2.43it/s, step size=5.14e-01, acc. prob=0.498]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=4.33e-01, acc. prob=0.746]
# Sample: 100%|██████████| 48/48 [00:21,  2.27it/s, step size=4.80e-01, acc. prob=0.691]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.42it/s, step size=5.04e-01, acc. prob=0.202]
# Sample: 100%|██████████| 48/48 [00:21,  2.24it/s, step size=1.33e-01, acc. prob=0.918]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.25it/s, step size=4.40e-01, acc. prob=0.746]
# Sample: 100%|██████████| 48/48 [00:21,  2.23it/s, step size=3.77e-01, acc. prob=0.675]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=3.25e-01, acc. prob=0.866]
# Sample: 100%|██████████| 48/48 [00:18,  2.62it/s, step size=4.38e-01, acc. prob=0.773]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.31it/s, step size=2.33e-01, acc. prob=0.454]
# Sample: 100%|██████████| 48/48 [00:21,  2.24it/s, step size=2.48e-01, acc. prob=0.816]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=3.89e-01, acc. prob=0.350]
# Sample: 100%|██████████| 48/48 [00:21,  2.28it/s, step size=2.44e-01, acc. prob=0.919]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.26it/s, step size=3.77e-01, acc. prob=0.719]
# Sample: 100%|██████████| 48/48 [00:20,  2.30it/s, step size=3.36e-01, acc. prob=0.770]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.40it/s, step size=6.24e-01, acc. prob=0.082]
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=6.34e-01, acc. prob=0.038]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.40it/s, step size=2.49e-01, acc. prob=0.793]
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=2.57e-01, acc. prob=0.932]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.37it/s, step size=2.46e-01, acc. prob=0.926]
# Sample: 100%|██████████| 48/48 [00:21,  2.26it/s, step size=3.23e-01, acc. prob=0.887]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:15,  3.11it/s, step size=8.24e-01, acc. prob=0.032]
# Sample: 100%|██████████| 48/48 [00:20,  2.29it/s, step size=1.75e-01, acc. prob=0.934]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:22,  2.18it/s, step size=3.90e-01, acc. prob=0.676]
# Sample: 100%|██████████| 48/48 [00:21,  2.28it/s, step size=4.82e-01, acc. prob=0.499]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.26it/s, step size=5.59e-01, acc. prob=0.415]
# Sample: 100%|██████████| 48/48 [00:20,  2.33it/s, step size=5.10e-01, acc. prob=0.565]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.33it/s, step size=3.57e-01, acc. prob=0.422]
# Sample: 100%|██████████| 48/48 [00:15,  3.05it/s, step size=2.55e-01, acc. prob=0.112]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=9.67e-02, acc. prob=0.977]
# Sample: 100%|██████████| 48/48 [00:19,  2.47it/s, step size=3.33e-01, acc. prob=0.226]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:18,  2.59it/s, step size=3.15e-01, acc. prob=0.760]
# Sample: 100%|██████████| 48/48 [00:21,  2.18it/s, step size=1.36e-01, acc. prob=0.911]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.37it/s, step size=2.39e-01, acc. prob=0.902]
# Sample: 100%|██████████| 48/48 [00:23,  2.08it/s, step size=1.45e-01, acc. prob=0.917]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.20it/s, step size=4.22e-01, acc. prob=0.572]
# Sample: 100%|██████████| 48/48 [00:16,  2.86it/s, step size=5.80e-01, acc. prob=0.110]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 5, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:15,  3.08it/s, step size=5.63e-01, acc. prob=0.222]
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=3.19e-01, acc. prob=0.750]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 1, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:16,  2.90it/s, step size=5.09e-01, acc. prob=0.193]
# Sample: 100%|██████████| 48/48 [00:14,  3.36it/s, step size=4.46e-01, acc. prob=0.291]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 2, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:20,  2.33it/s, step size=1.96e-01, acc. prob=0.738]
# Sample: 100%|██████████| 48/48 [00:17,  2.69it/s, step size=8.73e-02, acc. prob=0.412]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 3, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.26it/s, step size=3.56e-01, acc. prob=0.826]
# Sample: 100%|██████████| 48/48 [00:22,  2.17it/s, step size=1.97e-01, acc. prob=0.772]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 4, HV: 0.0
# Sample: 100%|██████████| 48/48 [00:21,  2.26it/s, step size=2.55e-01, acc. prob=0.895]
# Sample: 100%|██████████| 48/48 [00:22,  2.09it/s, step size=2.25e-01, acc. prob=0.939]
# Execution: 10, Iteration: 5, HV: 0.0
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(

# %%
# %matplotlib inline

for exec in range(executions):
  fig, axes = plt.subplots(1, 1, figsize=(8,6))

  pareto_front = Tensor.cpu(problem.gen_pareto_front(50, normalize=False))
  axes.scatter(pareto_front[:, 0], pareto_front[:, 1], color='b')


  cm = plt.cm.get_cmap('viridis')
  batch_number = all_df[exec].trial_index.values
  sc = axes.scatter(all_outcomes[exec][:, 0], all_outcomes[exec][:,1], c=batch_number, alpha=0.8)
  axes.set_title(f'ZDT5 Execution #{exec + 1}')
  axes.set_xlabel("Objective 1")
  axes.set_ylabel("Objective 2")
  norm = plt.Normalize(batch_number.min(), batch_number.max())
  sm =  ScalarMappable(norm=norm, cmap=cm)
  fig.subplots_adjust(right=0.9)
  cbar_ax = fig.add_axes([0.93, 0.15, 0.01, 0.7])
  cbar = fig.colorbar(sm, cax=cbar_ax)
  cbar.ax.set_title("Trial")
# Out:
# <ipython-input-9-8995f359783d>:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %%
# %matplotlib inline
fig, axes = plt.subplots(1, 1)
plt.xticks(np.arange(1, executions + 1))

axes.scatter(np.arange(1, executions + 1), np.array(execution_times))
axes.grid(True)
axes.set_xlabel("Execution")
axes.set_ylabel("Time")

print("Execution times:", np.array(execution_times))
print("Average execution time:", np.array(execution_times).sum()/len(execution_times))
# Out:
# Execution times: [250.91241431 404.44324994 316.57604384 262.91937518 294.58003497
#  239.30617762 325.83081198 310.96421456 276.84763312 252.92322254]
# Average execution time: 293.53031780719755

# %%
print(all_df)
# Out:
# [    trial_index arm_name trial_status generation_method     a         b  \
# 0             0      0_0      RUNNING             Sobol  19.0  6.894737
# 1             1      1_0      RUNNING             Sobol  16.0  7.937500
# 2             2      2_0      RUNNING             Sobol  17.0  6.882353
# 3             3      3_0      RUNNING             Sobol  20.0  6.350000
# 4             4      4_0      RUNNING             Sobol  18.0  6.277778
# ..          ...      ...          ...               ...   ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  13.0  8.923078
# 63           63     63_0      RUNNING  FullyBayesianMOO  16.0  7.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO  15.0  6.866667
# 65           65     65_0      RUNNING  FullyBayesianMOO  14.0  7.500000
# 66           66     66_0      RUNNING  FullyBayesianMOO  20.0  6.000000
#
#     is_feasible         x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False  258440928  15  24  ...   22   19    7   31    2   18   20
# 1         False  736215466  30   0  ...    8    3   27   13   17   10    5
# 2         False  979743433   2  22  ...   24   10   12   21   13    2   30
# 3         False  518196671  19  14  ...    6   26   16    7   30   26   15
# 4         False  288869607   5   6  ...   19   20   10    0   27    4   24
# ..          ...        ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False   44527657  31   8  ...    8   15   25   16   18   22   13
# 63        False  108806511  31   5  ...   31    4    7   12   10   27   31
# 64        False  120163891   8  31  ...   31   19   21   11    0   18   31
# 65        False  239212387   0  16  ...   16   31   16   12   14    0    0
# 66        False   66810334   7   0  ...    9   22   25   12   20    4    4
#
#     x27  x28  x29
# 0    26   25   18
# 1     5   12    0
# 2    10   16   12
# 3    21    5   30
# 4     0   31   23
# ..  ...  ...  ...
# 62   15   16   17
# 63   18   15    6
# 64   13    0    1
# 65   12   26    0
# 66   13   17    1
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a          b  \
# 0             0      0_0      RUNNING             Sobol  11.0  11.090909
# 1             1      1_0      RUNNING             Sobol  19.0   6.578948
# 2             2      2_0      RUNNING             Sobol  18.0   7.055556
# 3             3      3_0      RUNNING             Sobol  15.0   8.266667
# 4             4      4_0      RUNNING             Sobol  15.0   7.600000
# ..          ...      ...          ...               ...   ...        ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  22.0   5.590909
# 63           63     63_0      RUNNING  FullyBayesianMOO  19.0   6.052632
# 64           64     64_0      RUNNING  FullyBayesianMOO  16.0   8.000000
# 65           65     65_0      RUNNING  FullyBayesianMOO  18.0   7.000000
# 66           66     66_0      RUNNING  FullyBayesianMOO  14.0   9.285715
#
#     is_feasible         x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False    5445142   0   2  ...   21   26   13   25   24   31   14
# 1         False  625403894  20  31  ...    0    1   20    2   15   15   24
# 2         False  836058329   8   8  ...   28   14    4   17   18    7    7
# 3         False  348179771  28  21  ...    9   21   29   10    5   23   17
# 4         False  420326640  15  27  ...   16   31    2   13    1    3    0
# ..          ...        ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False  920091123   1   8  ...   25   24    6   28   16   27   29
# 63        False   97681085   0   0  ...   29   23   15   23   16   25   21
# 64        False  297092939   4  10  ...   22   28    8   24   16   27   27
# 65        False   90438584  12  15  ...    7   10   22    1   26   26    8
# 66        False  151460653   2   8  ...   25   26    6   28   16   26   29
#
#     x27  x28  x29
# 0    22   14   12
# 1     2   23   20
# 2     8    6   25
# 3    28   31    1
# 4     5   11   10
# ..  ...  ...  ...
# 62   26   20    3
# 63   30    0    0
# 64   21   21    4
# 65   11    9    2
# 66   25   20    0
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a          b  \
# 0             0      0_0      RUNNING             Sobol  19.0   6.210526
# 1             1      1_0      RUNNING             Sobol   9.0  13.888889
# 2             2      2_0      RUNNING             Sobol  13.0   9.538462
# 3             3      3_0      RUNNING             Sobol  18.0   7.166667
# 4             4      4_0      RUNNING             Sobol  16.0   8.062500
# ..          ...      ...          ...               ...   ...        ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  19.0   6.263158
# 63           63     63_0      RUNNING  FullyBayesianMOO  14.0   8.857143
# 64           64     64_0      RUNNING  FullyBayesianMOO  12.0  10.500000
# 65           65     65_0      RUNNING  FullyBayesianMOO  14.0   8.928572
# 66           66     66_0      RUNNING  FullyBayesianMOO  13.0   9.769231
#
#     is_feasible          x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False   599199039   9  16  ...   20    7    5   12   23   24   24
# 1         False   147104264  25   6  ...   14   18   17   24   11    3    8
# 2         False   403149575   0  30  ...   29   24    8    7   31   14   22
# 3         False   863255645  16   8  ...    7   13   28   19    3   21    6
# 4         False  1028875782   6   3  ...   17    1   15   22    6   10   18
# ..          ...         ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False   159108835  25   6  ...   11   18   17   24    8    3    8
# 63        False   128340250  25   6  ...   15   18   17   24   12    3    8
# 64        False    60332163  18  15  ...    9    3   19    0    5    0   27
# 65        False   115259400  25   6  ...   14   18   17   24   11    3    7
# 66        False   146837226  25   6  ...   14   18   17   24   11    3    8
#
#     x27  x28  x29
# 0    27   29   11
# 1    13   12   28
# 2     2   20   16
# 3    20    5    7
# 4     9   24   13
# ..  ...  ...  ...
# 62   13   12   28
# 63   12   11   28
# 64   12   26    2
# 65   13   12   28
# 66   13   13   28
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a           b  \
# 0             0      0_0      RUNNING             Sobol  22.0    5.772727
# 1             1      1_0      RUNNING             Sobol  14.0    9.428572
# 2             2      2_0      RUNNING             Sobol  19.0    6.736842
# 3             3      3_0      RUNNING             Sobol  20.0    6.350000
# 4             4      4_0      RUNNING             Sobol  19.0    7.000000
# ..          ...      ...          ...               ...   ...         ...
# 62           62     62_0      RUNNING  FullyBayesianMOO   1.0  119.000000
# 63           63     63_0      RUNNING  FullyBayesianMOO   1.0  110.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO   1.0  119.000000
# 65           65     65_0      RUNNING  FullyBayesianMOO  15.0    7.533334
# 66           66     66_0      RUNNING  FullyBayesianMOO   1.0  114.000000
#
#     is_feasible         x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False  989449023   7  15  ...    5    6    5   30   28    5    9
# 1         False  388007758  25  30  ...   24   16   25    5    1   16   19
# 2         False   91160453  13   5  ...   10   31   10   23   17   25    1
# 3         False  683127790  19  20  ...   23    9   22   12   12   12   27
# 4         False  562871743   9  27  ...    1    1   15   10    9   29    7
# ..          ...        ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False          0   0  17  ...   11   20   11    4    6    3   15
# 63        False          0   0  17  ...   12   22   12    4    7    0   14
# 64        False          0   0  17  ...   11   21   11    2    7    0   17
# 65        False  417650465   0  19  ...    9   23    9    0    4    7   13
# 66        False          0   0  16  ...   11   22   11    6    6    1   13
#
#     x27  x28  x29
# 0    27   16   27
# 1    10   12   15
# 2     6   30    6
# 3    23    2   18
# 4    12   20   30
# ..  ...  ...  ...
# 62   22    9    5
# 63   23    8    6
# 64   22    8    5
# 65   19    4    1
# 66   22    8    0
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a           b  \
# 0             0      0_0      RUNNING             Sobol  18.0    7.555556
# 1             1      1_0      RUNNING             Sobol  16.0    7.937500
# 2             2      2_0      RUNNING             Sobol  11.0   11.636364
# 3             3      3_0      RUNNING             Sobol  13.0    9.923078
# 4             4      4_0      RUNNING             Sobol  13.0    9.000000
# ..          ...      ...          ...               ...   ...         ...
# 62           62     62_0      RUNNING  FullyBayesianMOO   1.0  119.000000
# 63           63     63_0      RUNNING  FullyBayesianMOO   1.0   79.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO   1.0   78.000000
# 65           65     65_0      RUNNING  FullyBayesianMOO   1.0   68.000000
# 66           66     66_0      RUNNING  FullyBayesianMOO   1.0   88.000000
#
#     is_feasible         x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False  610685439   6   6  ...   13    5   10   16   19   26   22
# 1         False  356274082  24  21  ...   18   27   28    8   15    9    5
# 2         False   37932864  14   8  ...    7   19    7   31   27    4   24
# 3         False  857264390  16  27  ...   24   13   17    7    7   23   11
# 4         False  991995154   9  17  ...   10    1    0    0    1    3   30
# ..          ...        ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False          0  17   7  ...   16    7   12   26   22    2   27
# 63        False          0   0   0  ...    0   18    3   31   31    0    0
# 64        False          0  31   0  ...    0   18    5   17   22    2   17
# 65        False          0   0   0  ...   31    0    0   20   22    9   23
# 66        False          0   1   7  ...    0    0    0    0   22    6    8
#
#     x27  x28  x29
# 0     5   12   30
# 1    16   29    3
# 2    25    5    9
# 3    12   20   20
# 4    23    9   24
# ..  ...  ...  ...
# 62   28    0   16
# 63   31    8   12
# 64   22    0   31
# 65   31    1    0
# 66    3    0   31
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a          b  \
# 0             0      0_0      RUNNING             Sobol  15.0   8.266667
# 1             1      1_0      RUNNING             Sobol  17.0   7.000000
# 2             2      2_0      RUNNING             Sobol  21.0   6.095238
# 3             3      3_0      RUNNING             Sobol  15.0   7.800000
# 4             4      4_0      RUNNING             Sobol  14.0   9.857143
# ..          ...      ...          ...               ...   ...        ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  17.0   5.764706
# 63           63     63_0      RUNNING  FullyBayesianMOO   1.0  74.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO   1.0  79.000000
# 65           65     65_0      RUNNING  FullyBayesianMOO   1.0  98.000000
# 66           66     66_0      RUNNING  FullyBayesianMOO  13.0   4.846154
#
#     is_feasible         x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False  120634728  10   8  ...   11    9   28   30   12   22   30
# 1         False  663070550  16  23  ...   31   28   10    5   23    5   10
# 2         False  933652413   4   0  ...    3   19   18   21    1   10   20
# 3         False  387153280  30  31  ...   23    6    4   14   26   25    0
# 4         False  507756621   0  19  ...   12   12   22   11   28   13   19
# ..          ...        ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False  355809189  28  27  ...    0    8   20   31   28    7   20
# 63        False          0  31  15  ...   31    1   20   31   31   15    0
# 64        False          0  11  31  ...   31   31   26   31   31    0    0
# 65        False          0   0  31  ...   29    0   13   31   28    4    0
# 66        False  208799029  31  31  ...   31   26   31    0   31   25   15
#
#     x27  x28  x29
# 0    16   18    6
# 1    13    3   31
# 2     4   27   23
# 3    25   10   14
# 4    11   21    3
# ..  ...  ...  ...
# 62   26   31    7
# 63    0   11    8
# 64    0   17    0
# 65    0    0    5
# 66    0    0    0
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a         b  \
# 0             0      0_0      RUNNING             Sobol  17.0  7.470588
# 1             1      1_0      RUNNING             Sobol  20.0  6.400000
# 2             2      2_0      RUNNING             Sobol  13.0  9.692308
# 3             3      3_0      RUNNING             Sobol  16.0  7.937500
# 4             4      4_0      RUNNING             Sobol  17.0  7.058824
# ..          ...      ...          ...               ...   ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  16.0  7.437500
# 63           63     63_0      RUNNING  FullyBayesianMOO  17.0  6.529412
# 64           64     64_0      RUNNING  FullyBayesianMOO  15.0  7.666667
# 65           65     65_0      RUNNING  FullyBayesianMOO  23.0  5.869565
# 66           66     66_0      RUNNING  FullyBayesianMOO  17.0  7.117647
#
#     is_feasible         x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False  259369696   0  25  ...   14   25   10    7   20    7   30
# 1         False  930944921  31   8  ...   25   13   17   27    7   29    9
# 2         False  552995940  10  21  ...    4    4    1    8   25   21   22
# 3         False  419344673  21   4  ...   19   16   26   20   10   15    1
# 4         False  337610399  14  14  ...    9   31    5   18   14   18   17
# ..          ...        ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False  526139705  26   9  ...    0   12   12   23    4   15   15
# 63        False  564654452  31  31  ...    0   17   31   21    0    6   19
# 64        False  526823560  30  31  ...    4   18   31   20    0    5   19
# 65        False  533712239  26  23  ...    3   14    2   21    4   11   16
# 66        False  511509275   0   6  ...   14   20   18   10   29   18   18
#
#     x27  x28  x29
# 0    23    0    7
# 1    10   26   16
# 2     3   11   27
# 3    30   17   12
# 4    14    6    0
# ..  ...  ...  ...
# 62    6    9   17
# 63   11    0   23
# 64   12    0   23
# 65   13    7   19
# 66    9   10   17
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a          b  \
# 0             0      0_0      RUNNING             Sobol  15.0   8.733334
# 1             1      1_0      RUNNING             Sobol  18.0   6.722222
# 2             2      2_0      RUNNING             Sobol  15.0   7.666667
# 3             3      3_0      RUNNING             Sobol  18.0   7.388889
# 4             4      4_0      RUNNING             Sobol  17.0   7.705883
# ..          ...      ...          ...               ...   ...        ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  16.0   7.000000
# 63           63     63_0      RUNNING  FullyBayesianMOO  15.0   8.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO  16.0   7.875000
# 65           65     65_0      RUNNING  FullyBayesianMOO  10.0  12.200000
# 66           66     66_0      RUNNING  FullyBayesianMOO  13.0   9.692308
#
#     is_feasible          x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False   579873599   7  21  ...   18   16   29   12   30   23   14
# 1         False   104721132  17   7  ...    3   15    5   31   10   13   28
# 2         False   292849871  14  31  ...   25    0   19    6   21    3    5
# 3         False   903432572  24  13  ...    8   31   11   21    1   25   23
# 4         False  1043794769  11   1  ...   20   21   23   18    6    5    3
# ..          ...         ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False   589191529   0  12  ...   15   31   12    3   12   22   14
# 63        False   612559093   1  12  ...   15   29   12    5   13   21   14
# 64        False   345310971   1  16  ...   12   20    9   22    0    4    2
# 65        False   617679136   1  12  ...   15   28   12    6   13   21   14
# 66        False   341984851   1  16  ...   12   20    9   22   21    4    2
#
#     x27  x28  x29
# 0    29    0   17
# 1     4   29    6
# 2    14    8   12
# 3    23   21   27
# 4     0    7   21
# ..  ...  ...  ...
# 62    6    1    6
# 63    7    2    8
# 64   30   13    4
# 65    7    2   13
# 66   30   13    4
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a          b  \
# 0             0      0_0      RUNNING             Sobol  14.0   8.571429
# 1             1      1_0      RUNNING             Sobol  16.0   8.250000
# 2             2      2_0      RUNNING             Sobol  20.0   6.750000
# 3             3      3_0      RUNNING             Sobol  17.0   7.588235
# 4             4      4_0      RUNNING             Sobol  16.0   8.187500
# ..          ...      ...          ...               ...   ...        ...
# 62           62     62_0      RUNNING  FullyBayesianMOO   1.0  79.000000
# 63           63     63_0      RUNNING  FullyBayesianMOO  11.0   8.545455
# 64           64     64_0      RUNNING  FullyBayesianMOO   1.0  85.000000
# 65           65     65_0      RUNNING  FullyBayesianMOO   1.0  88.000000
# 66           66     66_0      RUNNING  FullyBayesianMOO   1.0  70.000000
#
#     is_feasible         x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False  212072544   0  19  ...    0   26    5   20   26    6    8
# 1         False  947006310  29   7  ...   26    9   24    7   13   19   30
# 2         False  804539819  13  25  ...    9    7   10   24   16   30    1
# 3         False  455450275  16  13  ...   19   20   23   11    7   11   23
# 4         False  282819718  10   1  ...    5   28   15   12    3   25    7
# ..          ...        ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62        False          0  14   0  ...   31    0   16   31    0    0   30
# 63         True    1970644  15   0  ...   31    1   20   31    0    0    0
# 64        False          0   3   0  ...   31   14    5   31    0    0   20
# 65        False          0  16   9  ...   18    7   29   31   31    0   31
# 66        False          0  11   0  ...   26    0    0   31    0    0   14
#
#     x27  x28  x29
# 0    15   31    8
# 1    26   11   20
# 2    18   18   29
# 3     7    6    1
# 4    29   26   13
# ..  ...  ...  ...
# 62   31    8   18
# 63   31    7   18
# 64   31   31   20
# 65   31   10   20
# 66   31    0   20
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method     a           b  \
# 0             0      0_0      RUNNING             Sobol  17.0    7.647059
# 1             1      1_0      RUNNING             Sobol  14.0    9.214286
# 2             2      2_0      RUNNING             Sobol  19.0    6.526316
# 3             3      3_0      RUNNING             Sobol  14.0    7.642858
# 4             4      4_0      RUNNING             Sobol  16.0    7.187500
# ..          ...      ...          ...               ...   ...         ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  11.0    9.727273
# 63           63     63_0      RUNNING  FullyBayesianMOO  18.0    6.611111
# 64           64     64_0      RUNNING  FullyBayesianMOO   1.0  117.000000
# 65           65     65_0      RUNNING  FullyBayesianMOO   1.0   97.000000
# 66           66     66_0      RUNNING  FullyBayesianMOO   1.0   93.000000
#
#     is_feasible          x0  x1  x2  ...  x20  x21  x22  x23  x24  x25  x26  \
# 0         False  1025648767  13  10  ...   29    0   24   12   23    7   11
# 1         False   338595356  23  22  ...   10   30   10   22   13   24   20
# 2         False   165597078   5   3  ...   17   20   20    1   28   17    5
# 3         False   550660580  31  31  ...    6   10    6   27    6   14   26
# 4         False   791888792   1  18  ...   24    4   16   29    0   22    3
# ..          ...         ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 62         True    98648368  20  26  ...   21    0    0   31   15    0   30
# 63        False   477307893  27  24  ...   16   18   11    9    6   10   29
# 64        False           0  26  30  ...   19    9   31   13   11   14   27
# 65        False           0  21  31  ...   22    5   31   21   21   18   31
# 66        False           0  27  31  ...   19    4   31   17   13   24   31
#
#     x27  x28  x29
# 0    11   16    6
# 1    27    8   31
# 2    19   29   16
# 3     3    5    9
# 4    28   21    0
# ..  ...  ...  ...
# 62   31    3    0
# 63   31   15    9
# 64   31   13   11
# 65   31    5    8
# 66   31    3    3
#
# [67 rows x 37 columns]]
