# %%
# !lscpu |grep 'Model name'
# !nvidia-smi
# !pip install ax-platform
# Out:
# Model name:                      Intel(R) Xeon(R) CPU @ 2.30GHz
# Sat Mar 18 22:49:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ax-platform
#   Using cached ax_platform-0.3.1-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (3.1.2)
# Collecting botorch==0.8.3
#   Using cached botorch-0.8.3-py3-none-any.whl (521 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.4.4)
# Requirement already satisfied: typeguard==2.13.3 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (2.13.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.10.1)
# Collecting plotly>=5.12.0
#   Using cached plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from ax-platform) (7.7.1)
# Collecting linear-operator==0.3.0
#   Using cached linear_operator-0.3.0-py3-none-any.whl (155 kB)
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.13.1+cu116)
# Collecting pyro-ppl>=1.8.4
#   Using cached pyro_ppl-1.8.4-py3-none-any.whl (730 kB)
# Collecting gpytorch==1.9.1
#   Using cached gpytorch-1.9.1-py3-none-any.whl (250 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (0.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.12.0->ax-platform) (8.2.2)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.6.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.3.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.0.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (7.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->ax-platform) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (1.22.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (3.1.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.1.12)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (63.4.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.8.0)
# Collecting jedi>=0.10
#   Using cached jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (0.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (3.3.0)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (4.65.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->ax-platform) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.12->botorch==0.8.3->ax-platform) (4.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->ax-platform) (0.8.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.8.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.2.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.4)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.2.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.7.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.16.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ax-platform) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->ax-platform) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.1.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.2.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.9.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.2.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.11.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.21)
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# Installing collected packages: plotly, jedi, pyro-ppl, linear-operator, gpytorch, botorch, ax-platform
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# WARNING: Ignoring invalid distribution -lotly (/usr/local/lib/python3.9/dist-packages)
# Successfully installed ax-platform-0.3.1 botorch-0.8.3 gpytorch-1.9.1 jedi-0.18.2 linear-operator-0.3.0 plotly-5.13.1 pyro-ppl-1.8.4

# %%
import pandas as pd
from ax import *
import torch

import numpy as np
from matplotlib import pyplot as plt
from matplotlib.cm import ScalarMappable

from ax.service.utils.report_utils import exp_to_df
from ax.runners.synthetic import SyntheticRunner
from ax.metrics.noisy_function import GenericNoisyFunctionMetric

# Analysis utilities, including a method to evaluate hypervolumes
from ax.modelbridge.modelbridge_utils import observed_hypervolume

from botorch.test_functions.multi_objective import ZDT3

# %%
tkwargs = {
    "dtype": torch.double, 
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
}

# %%
dim = 30
problem = ZDT3(num_objectives=2, dim=dim, negate=False).to(**tkwargs)

param_names = [f"x{i}" for i in range(dim)]

def f1(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names] # Obtiene los parámetros a evaluar
        return float(problem(torch.tensor(x_sorted, **tkwargs).clamp(0., 1.))[0]) # Evalúa los parámetros en el primer objetivo
    
def f2(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names]
        return float(problem(torch.tensor(x_sorted, **tkwargs).clamp(0., 1.))[1]) # Evalúa los parámetros en el segundo objetivo

metric_a = GenericNoisyFunctionMetric("a", f=f1, noise_sd=0.0, lower_is_better=True)
metric_b = GenericNoisyFunctionMetric("b", f=f2, noise_sd=0.0, lower_is_better=True)

# %%
search_space = SearchSpace(
    parameters=[
        RangeParameter(name=param_name, lower=0, upper=1, parameter_type=ParameterType.FLOAT)
        for param_name in param_names
        ]
)

mo = MultiObjective(
    objectives=[Objective(metric=metric_a), Objective(metric=metric_b)],
)

objective_thresholds = [
    ObjectiveThreshold(metric=metric, bound=val, relative=False)
    for metric, val in zip(mo.metrics, problem.ref_point)
]

optimization_config = MultiObjectiveOptimizationConfig(
    objective=mo,
    objective_thresholds=objective_thresholds,
)

# %%
N_INIT = 2 * (dim + 1)
N_BATCH = 5
BATCH_SIZE = 1

def build_experiment():
    experiment = Experiment(
        name="pareto_experiment",
        search_space=search_space,
        optimization_config=optimization_config,
        runner=SyntheticRunner(),
    )
    return experiment

def initialize_experiment(experiment):
    sobol = Models.SOBOL(search_space=experiment.search_space)

    for _ in range(N_INIT):
        experiment.new_trial(sobol.gen(1)).run()

    return experiment.fetch_data()

# %%
import time

executions = 10
execution_times = []
all_df = []
all_outcomes = []

for exec in range(executions):
  start_time = time.time()

  experiment = build_experiment()
  data = initialize_experiment(experiment)

  hv_list = []
  model = None
  for i in range(N_BATCH):   
      model = Models.FULLYBAYESIANMOO(
          experiment=experiment, 
          data=data,
          num_samples=16,
          warmup_steps=32,
          torch_device=tkwargs["device"],
      )
      generator_run = model.gen(BATCH_SIZE)
      trial = experiment.new_trial(generator_run=generator_run)
      trial.run()
      data = Data.from_multiple_data([data, trial.fetch_data()])
      
      exp_df = exp_to_df(experiment)
      outcomes = np.array(exp_df[['a', 'b']], dtype=np.double)
      try:
          hv = observed_hypervolume(modelbridge=model)
      except:
          hv = 0
          print("Failed to compute hv")
      hv_list.append(hv)
      print(f"Execution: {exec + 1}, Iteration: {i + 1}, HV: {hv}")

  execution_times.append(time.time() - start_time)

  all_df.append(exp_to_df(experiment).sort_values(by=["trial_index"]))
  all_outcomes.append(np.array(exp_to_df(experiment)[['a', 'b']], dtype=np.double))
# Out:
# Sample: 100%|██████████| 48/48 [00:25,  1.88it/s, step size=4.08e-01, acc. prob=0.709]
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=3.13e-01, acc. prob=0.919]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 1, HV: 115.94414985103806
# Sample: 100%|██████████| 48/48 [00:19,  2.43it/s, step size=1.70e-01, acc. prob=0.438]
# Sample: 100%|██████████| 48/48 [00:17,  2.82it/s, step size=2.16e-01, acc. prob=0.295]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 2, HV: 115.94414985103806
# Sample: 100%|██████████| 48/48 [00:24,  2.00it/s, step size=1.96e-01, acc. prob=0.956]
# Sample: 100%|██████████| 48/48 [00:20,  2.34it/s, step size=5.82e-01, acc. prob=0.473]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 3, HV: 116.50784637000845
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=3.65e-01, acc. prob=0.830]
# Sample: 100%|██████████| 48/48 [00:23,  2.08it/s, step size=3.80e-01, acc. prob=0.652]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 4, HV: 116.59688020278202
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=4.50e-01, acc. prob=0.454]
# Sample: 100%|██████████| 48/48 [00:20,  2.36it/s, step size=3.11e-01, acc. prob=0.876]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 5, HV: 116.65023030761374
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=4.48e-01, acc. prob=0.545]
# Sample: 100%|██████████| 48/48 [00:21,  2.20it/s, step size=3.38e-01, acc. prob=0.859]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 1, HV: 115.50523090579578
# Sample: 100%|██████████| 48/48 [00:17,  2.69it/s, step size=6.31e-01, acc. prob=0.046]
# Sample: 100%|██████████| 48/48 [00:20,  2.32it/s, step size=3.90e-01, acc. prob=0.845]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 2, HV: 117.65237054123133
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=4.20e-01, acc. prob=0.229]
# Sample: 100%|██████████| 48/48 [00:20,  2.29it/s, step size=1.29e-01, acc. prob=0.341]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/optimize.py:350: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL_TERMINATION_IN_LNSRCH.')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /usr/local/lib/python3.9/dist-packages/botorch/optim/optimize.py:374: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 3, HV: 117.75999406619519
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=2.72e-01, acc. prob=0.883]
# Sample: 100%|██████████| 48/48 [00:21,  2.21it/s, step size=2.86e-01, acc. prob=0.812]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 4, HV: 117.80610977740837
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=4.40e-01, acc. prob=0.724]
# Sample: 100%|██████████| 48/48 [00:21,  2.27it/s, step size=1.68e-01, acc. prob=0.753]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 5, HV: 119.30294893171201
# Sample: 100%|██████████| 48/48 [00:10,  4.76it/s, step size=5.14e-01, acc. prob=0.158]
# Sample: 100%|██████████| 48/48 [00:21,  2.21it/s, step size=1.98e-01, acc. prob=0.902]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration:

# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 1, HV: 115.68234510519484
# Sample: 100%|██████████| 48/48 [00:21,  2.24it/s, step size=4.31e-01, acc. prob=0.792]
# Sample: 100%|██████████| 48/48 [00:22,  2.10it/s, step size=4.71e-01, acc. prob=0.650]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 2, HV: 115.8367077148048
# Sample: 100%|██████████| 48/48 [00:19,  2.40it/s, step size=2.59e-01, acc. prob=0.944]
# Sample: 100%|██████████| 48/48 [00:20,  2.39it/s, step size=1.87e-01, acc. prob=0.892]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 3, HV: 116.99145274279368
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=4.01e-01, acc. prob=0.791]
# Sample: 100%|██████████| 48/48 [00:22,  2.18it/s, step size=1.03e-01, acc. prob=0.799]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 4, HV: 117.00129569405095
# Sample: 100%|██████████| 48/48 [00:19,  2.45it/s, step size=4.84e-01, acc. prob=0.422]
# Sample: 100%|██████████| 48/48 [00:22,  2.15it/s, step size=7.31e-02, acc. prob=0.946]
# Execution: 10, Iteration: 5, HV: 117.00152002241207
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(

# %%
from torch import Tensor
# %matplotlib inline

for exec in range(executions):
  fig, axes = plt.subplots(1, 1, figsize=(8,6))

  pareto_front = Tensor.cpu(problem.gen_pareto_front(50))
  axes.scatter(pareto_front[:, 0], pareto_front[:, 1], color='b')


  cm = plt.cm.get_cmap('viridis')
  batch_number = all_df[exec].trial_index.values
  sc = axes.scatter(all_outcomes[exec][:, 0], all_outcomes[exec][:,1], c=batch_number, alpha=0.8)
  axes.set_title(f'ZDT3 Execution #{exec + 1}')
  axes.set_xlabel("Objective 1")
  axes.set_ylabel("Objective 2")
  norm = plt.Normalize(batch_number.min(), batch_number.max())
  sm =  ScalarMappable(norm=norm, cmap=cm)
  fig.subplots_adjust(right=0.9)
  cbar_ax = fig.add_axes([0.93, 0.15, 0.01, 0.7])
  cbar = fig.colorbar(sm, cax=cbar_ax)
  cbar.ax.set_title("Trial")
# Out:
# <ipython-input-10-cdd9ed3176cb>:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %%
# %matplotlib inline
fig, axes = plt.subplots(1, 1)
plt.xticks(np.arange(1, executions + 1))

axes.scatter(np.arange(1, executions + 1), np.array(execution_times))
axes.grid(True)
axes.set_xlabel("Execution")
axes.set_ylabel("Time")

print("Execution times:", np.array(execution_times))
print("Average execution time:", np.array(execution_times).sum()/len(execution_times))
# Out:
# Execution times: [281.69667125 296.66132712 267.75769186 310.94275522 314.61507702
#  271.13234806 283.53767514 264.50182271 272.42594147 291.78663826]

# %%
print(all_df)
# Out:
# [    trial_index arm_name trial_status generation_method         a         b  \
# 0             0      0_0      RUNNING             Sobol  0.246995  0.735655
# 1             1      1_0      RUNNING             Sobol  0.634139  0.574711
# 2             2      2_0      RUNNING             Sobol  0.968273  0.722648
# 3             3      3_0      RUNNING             Sobol  0.416218  0.701604
# 4             4      4_0      RUNNING             Sobol  0.355972  0.809045
# ..          ...      ...          ...               ...       ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  1.000000  0.513971
# 63           63     63_0      RUNNING  FullyBayesianMOO  0.850335  0.375420
# 64           64     64_0      RUNNING  FullyBayesianMOO  0.000000  1.000000
# 65           65     65_0      RUNNING  FullyBayesianMOO  0.449093  0.447031
# 66           66     66_0      RUNNING  FullyBayesianMOO  0.413670  0.529867
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.246995  0.180074  0.927831  ...  0.158998  0.324156
# 1          True  0.634139  0.635837  0.047476  ...  0.792153  0.715811
# 2          True  0.968273  0.416602  0.747736  ...  0.250359  0.811460
# 3          True  0.416218  0.900285  0.370280  ...  0.634415  0.166006
# 4          True  0.355972  0.275843  0.179667  ...  0.088715  0.459375
# ..          ...       ...       ...       ...  ...       ...       ...
# 62         True  1.000000  0.000000  0.470456  ...  0.000000  1.000000
# 63         True  0.850335  0.000000  0.000000  ...  0.118033  0.000000
# 64         True  0.000000  1.000000  1.000000  ...  1.000000  1.000000
# 65         True  0.449093  0.000000  1.000000  ...  1.000000  0.000000
# 66         True  0.413670  0.000000  1.000000  ...  1.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0
...  0.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.599441  0.039017  0.111356  0.106998  0.035368  0.526849  0.148131
# 1   0.357094  0.502500  0.593785  0.584219  0.624004  0.022860  0.790800
# 2   0.977689  0.463348  0.358396  0.771090  0.410972  0.364020  0.467806
# 3   0.220088  0.999067  0.872014  0.295128  0.998139  0.868009  0.595094
# 4   0.780465  0.874642  0.928065  0.916805  0.331080  0.168986  0.116350
# ..       ...       ...       ...       ...       ...       ...       ...
# 62  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 63  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 64  0.405518  0.000000  0.000000  0.000000  0.000000  0.000000  0.319182
# 65  0.000000  1.000000  0.000000  0.000000  0.000000  1.000000  0.000000
# 66  1.000000  0.000000  0.000000  0.000000  1.000000  1.000000  1.000000
#
#          x29
# 0   0.215858
# 1   0.626733
# 2   0.808959
# 3   0.344300
# 4   0.096650
# ..       ...
# 62  0.996586
# 63  0.000000
# 64  0.993147
# 65  0.000000
# 66  0.000000
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method         a         b  \
# 0             0      0_0      RUNNING             Sobol  0.272902  0.754974
# 1             1      1_0      RUNNING             Sobol  0.744658  0.765336
# 2             2      2_0      RUNNING             Sobol  0.795495  0.637746
# 3             3      3_0      RUNNING             Sobol  0.190804  0.818126
# 4             4      4_0      RUNNING             Sobol  0.009522  0.956866
# ..          ...      ...          ...               ...       ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  0.860376  0.354224
# 63           63     63_0      RUNNING  FullyBayesianMOO  0.000000  1.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO  0.450479  0.481190
# 65           65     65_0      RUNNING  FullyBayesianMOO  0.853500  0.301989
# 66           66     66_0      RUNNING  FullyBayesianMOO  0.848198  0.369766
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.272902  0.572365  0.785152  ...  0.415954  0.223366
# 1          True  0.744658  0.214041  0.310587  ...  0.680624  0.721867
# 2          True  0.795495  0.868598  0.509252  ...  0.023482  0.760529
# 3          True  0.190804  0.476831  0.020073  ...  0.758858  0.262951
# 4          True  0.009522  0.942742  0.389291  ...  0.258972  0.002812
# ..          ...       ...       ...       ...  ...       ...       ...
# 62         True  0.860376  0.000000  1.000000  ...  0.009860  0.000000
# 63         True  0.000000  0.000000  0.000000  ...  1.000000  0.000000
# 64         True  0.450479  0.000000  0.000000  ...  0.000000  0.000000
# 65         True  0.853500  0.000000  1.000000  ...  0.000000  0.000000
# 66         True  0.848198  1.000000  1.000000  ...  0.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.873758  0.403280  0.918356  0.184523  0.938059  0.939716  0.373570
# 1   0.118772  0.941176  0.118904  0.703229  0.453147  0.436970  0.985614
# 2   0.589448  0.144017  0.642463  0.880733  0.721011  0.212342  0.230999
# 3   0.340567  0.699523  0.316672  0.477745  0.237091  0.660401  0.596950
# 4   0.748995  0.552505  0.454980  0.805852  0.537523  0.278764  0.462088
# ..       ...       ...       ...       ...       ...       ...       ...
# 62  1.000000  1.000000  0.000000  0.000000  0.000000  0.000000  1.000000
# 63  1.000000  0.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 64  1.000000  0.000000  0.000000  1.000000  0.000000  1.000000  0.000000
# 65  1.000000  1.000000  0.000000  0.000000  0.000000  0.000000  1.000000
# 66  1.000000  1.000000  0.000000  1.000000  0.000000  0.000000  1.000000
#
#          x29
# 0   0.311766
# 1   0.939188
# 2   0.591345
# 3   0.159227
# 4   0.383689
# ..       ...
# 62  1.000000
# 63  1.000000
# 64  1.000000
# 65  1.000000
# 66  1.000000
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method         a         b  \
# 0             0      0_0      RUNNING             Sobol  0.686993  0.614647
# 1             1      1_0      RUNNING             Sobol  0.331538  0.799555
# 2             2      2_0      RUNNING             Sobol  0.208814  0.801502
# 3             3      3_0      RUNNING             Sobol  0.806486  0.580471
# 4             4      4_0      RUNNING             Sobol  0.892791  0.550528
# ..          ...      ...          ...               ...       ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  0.853268  0.357545
# 63           63     63_0      RUNNING  FullyBayesianMOO  0.000000  1.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO  0.851059  0.419896
# 65           65     65_0      RUNNING  FullyBayesianMOO  0.851527  0.213804
# 66           66     66_0      RUNNING  FullyBayesianMOO  0.262313  0.612380
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.686993  0.883758  0.899949  ...  0.835335  0.202120
# 1          True  0.331538  0.076520  0.275087  ...  0.203468  0.616848
# 2          True  0.208814  0.608317  0.582597  ...  0.733344  0.963069
# 3          True  0.806486  0.414330  0.207676  ...  0.353311  0.347110
# 4          True  0.892791  0.645438  0.447614  ...  0.927498  0.077761
# ..          ...       ...       ...       ...  ...       ...       ...
# 62         True  0.853268  0.000000  0.000000  ...  1.000000  0.000000
# 63         True  0.000000  0.000000  0.000000  ...  1.000000  0.000000
# 64         True  0.851059  0.000000  0.000000  ...  1.000000  0.000000
# 65         True  0.851527  0.000000  0.000000  ...  0.000000  0.000000
# 66         True  0.262313  1.000000  1.000000  ...  0.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.523561  0.380277  0.180491  0.665594  0.046284  0.920072  0.651957
# 1   0.343886  0.903635  0.991218  0.415229  0.923554  0.193389  0.325042
# 2   0.901720  0.061392  0.423731  0.102592  0.457848  0.382046  0.940147
# 3   0.222046  0.537995  0.748252  0.853200  0.572308  0.733489  0.021455
# 4   0.872311  0.714969  0.547100  0.161829  0.254291  0.070298  0.557327
# ..       ...       ...       ...       ...       ...       ...       ...
# 62  0.000000  0.686687  0.000000  1.000000  0.000000  1.000000  1.000000
# 63  1.000000  1.000000  0.000000  1.000000  0.000000  1.000000  1.000000
# 64  0.000000  1.000000  0.000000  1.000000  0.000000  1.000000  1.000000
# 65  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000  1.000000
# 66  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000  1.000000
#
#          x29
# 0   0.073470
# 1   0.679118
# 2   0.797312
# 3   0.449354
# 4   0.133563
# ..       ...
# 62  0.000000
# 63  1.000000
# 64  0.000000
# 65  0.000000
# 66  0.000000
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method         a         b  \
# 0             0      0_0      RUNNING             Sobol  0.762773  0.761887
# 1             1      1_0      RUNNING             Sobol  0.030041  0.919240
# 2             2      2_0      RUNNING             Sobol  0.430259  0.662467
# 3             3      3_0      RUNNING             Sobol  0.667247  0.513664
# 4             4      4_0      RUNNING             Sobol  0.624609  0.552987
# ..          ...      ...          ...               ...       ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  0.000000  1.000000
# 63           63     63_0      RUNNING  FullyBayesianMOO  0.850176  0.253866
# 64           64     64_0      RUNNING  FullyBayesianMOO  0.454358  0.451277
# 65           65     65_0      RUNNING  FullyBayesianMOO  0.845771  0.219413
# 66           66     66_0      RUNNING  FullyBayesianMOO  0.416198  0.547813
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.762773  0.608075  0.253141  ...  0.597851  0.408233
# 1          True  0.030041  0.205725  0.813611  ...  0.099950  0.654112
# 2          True  0.430259  0.753367  0.213627  ...  0.786590  0.772710
# 3          True  0.667247  0.436952  0.649248  ...  0.288193  0.039588
# 4          True  0.624609  0.897167  0.936558  ...  0.693332  0.266025
# ..          ...       ...       ...       ...  ...       ...       ...
# 62         True  0.000000  1.000000  0.000000  ...  1.000000  0.000000
# 63         True  0.850176  0.000000  1.000000  ...  0.000000  0.000000
# 64         True  0.454358  0.000000  0.000000  ...  0.000000  1.000000
# 65         True  0.845771  1.000000  0.000000  ...  0.000000  0.000000
# 66         True  0.416198  0.000000  0.000000  ...  0.000000  1.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.540213  0.463012  0.942354  0.057965  0.664110  0.672062  0.761371
# 1   0.270947  0.854848  0.402687  0.583065  0.484746  0.385663  0.473976
# 2   0.829810  0.088866  0.515175  0.872590  0.978300  0.180397  0.647706
# 3   0.107328  0.730214  0.085115  0.269394  0.173502  0.877320  0.118891
# 4   0.962800  0.500155  0.131268  0.951856  0.766624  0.292058  0.910188
# ..       ...       ...       ...       ...       ...       ...       ...
# 62  0.000000  0.000000  1.000000  0.000000  0.014055  1.000000  1.000000
# 63  0.000000  0.000000  0.000000  1.000000  1.000000  0.000000  0.000000
# 64  0.000000  0.000000  0.000000  0.000000  0.478048  0.000000  0.000000
# 65  0.000000  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000
# 66  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000
#
#          x29
# 0   0.746928
# 1   0.331592
# 2   0.022828
# 3   0.929894
# 4   0.559079
# ..       ...
# 62  1.000000
# 63  0.000000
# 64  0.000000
# 65  0.000000
# 66  0.000000
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method         a         b  \
# 0             0      0_0      RUNNING             Sobol  0.306566  0.767713
# 1             1      1_0      RUNNING             Sobol  0.851103  0.485997
# 2             2      2_0      RUNNING             Sobol  0.525803  0.758419
# 3             3      3_0      RUNNING             Sobol  0.066436  0.876823
# 4             4      4_0      RUNNING             Sobol  0.165679  0.859617
# ..          ...      ...          ...               ...       ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  0.847242  0.369456
# 63           63     63_0      RUNNING  FullyBayesianMOO  0.000000  1.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO  0.449286  0.446853
# 65           65     65_0      RUNNING  FullyBayesianMOO  0.853683  0.261429
# 66           66     66_0      RUNNING  FullyBayesianMOO  0.853321  0.301951
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.306566  0.850721  0.330642  ...  0.041352  0.425360
# 1          True  0.851103  0.311181  0.784875  ...  0.701279  0.921048
# 2          True  0.525803  0.672063  0.194111  ...  0.345330  0.634722
# 3          True  0.066436  0.228226  0.679569  ...  0.880730  0.145760
# 4          True  0.165679  0.506330  0.996069  ...  0.163427  0.286363
# ..          ...       ...       ...       ...  ...       ...       ...
# 62         True  0.847242  0.000000  0.000000  ...  1.000000  0.000000
# 63         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 64         True  0.449286  0.000000  0.000000  ...  0.000000  0.000000
# 65         True  0.853683  0.000000  0.000000  ...  1.000000  0.000000
# 66         True  0.853321  0.000000  1.000000  ...  1.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.666737  0.143111  0.421051  0.470905  0.857326  0.225133  0.168833
# 1   0.239279  0.560832  0.541532  0.745330  0.293166  0.693117  0.746575
# 2   0.774238  0.340711  0.032950  0.923772  0.624334  0.796738  0.428763
# 3   0.319739  0.984505  0.910267  0.164986  0.061053  0.262288  0.976142
# 4   0.950477  0.858899  0.758947  0.762465  0.744956  0.539390  0.027099
# ..       ...       ...       ...       ...       ...       ...       ...
# 62  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.871910
# 63  0.000000  1.000000  0.000000  0.000000  1.000000  0.000000  0.000000
# 64  1.000000  0.000000  0.000000  0.000000  1.000000  1.000000  0.000000
# 65  1.000000  0.000000  0.000000  0.000000  0.000000  1.000000  0.000000
# 66  1.000000  0.000000  0.000000  0.000000  0.000000  1.000000  0.000000
#
#          x29
# 0   0.483835
# 1   0.794682
# 2   0.626965
# 3   0.063173
# 4   0.308354
# ..       ...
# 62  0.000000
# 63  0.000000
# 64  0.000000
# 65  0.000000
# 66  0.000000
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method         a         b  \
# 0             0      0_0      RUNNING             Sobol  0.685768  0.617665
# 1             1      1_0      RUNNING             Sobol  0.255698  0.721614
# 2             2      2_0      RUNNING             Sobol  0.208108  0.788501
# 3             3      3_0      RUNNING             Sobol  0.858359  0.461349
# 4             4      4_0      RUNNING             Sobol  0.918783  0.688881
# ..          ...      ...          ...               ...       ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  0.851811  0.157315
# 63           63     63_0      RUNNING  FullyBayesianMOO  0.000000  1.000000
# 64           64     64_0      RUNNING  FullyBayesianMOO  0.828191  0.238007
# 65           65     65_0      RUNNING  FullyBayesianMOO  0.459185  0.510501
# 66           66     66_0      RUNNING  FullyBayesianMOO  0.265556  0.727893
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.685768  0.348476  0.973564  ...  0.694897  0.598048
# 1          True  0.255698  0.856438  0.249114  ...  0.125564  0.465462
# 2          True  0.208108  0.111376  0.731749  ...  0.921013  0.039372
# 3          True  0.858359  0.619279  0.490930  ...  0.476674  0.891196
# 4          True  0.918783  0.199680  0.056640  ...  0.585464  0.722204
# ..          ...       ...       ...       ...  ...       ...       ...
# 62         True  0.851811  0.000000  0.000000  ...  0.000000  0.000000
# 63         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 64         True  0.828191  0.000000  0.000000  ...  0.000000  0.000000
# 65         True  0.459185  0.000000  0.000000  ...  0.000000  1.000000
# 66         True  0.265556  0.000000  0.000000  ...  0.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.859737  0.267532  0.809900  0.978695  0.978286  0.341431  0.983881
# 1   0.249434  0.760241  0.013852  0.256092  0.280870  0.753226  0.126847
# 2   0.531370  0.024980  0.738669  0.230022  0.643017  0.672567  0.638177
# 3   0.421059  0.502056  0.444446  0.507419  0.097827  0.232760  0.472550
# 4   0.748319  0.728054  0.342917  0.065053  0.615591  0.970848  0.751404
# ..       ...       ...       ...       ...       ...       ...       ...
# 62  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000
# 63  1.000000  0.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 64  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000
# 65  0.000000  0.000000  0.000000  1.000000  1.000000  1.000000  0.000000
# 66  1.000000  0.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#          x29
# 0   0.409558
# 1   0.601743
# 2   0.919291
# 3   0.099695
# 4   0.362820
# ..       ...
# 62  0.000000
# 63  0.000000
# 64  0.000000
# 65  0.000000
# 66  0.000000
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method         a         b  \
# 0             0      0_0      RUNNING             Sobol  0.331688  0.807810
# 1             1      1_0      RUNNING             Sobol  0.774161  0.728394
# 2             2      2_0      RUNNING             Sobol  0.624342  0.581243
# 3             3      3_0      RUNNING             Sobol  0.051067  0.890777
# 4             4      4_0      RUNNING             Sobol  0.243664  0.744706
# ..          ...      ...          ...               ...       ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  0.848368  0.303705
# 63           63     63_0      RUNNING  FullyBayesianMOO  0.805576  0.547599
# 64           64     64_0      RUNNING  FullyBayesianMOO  0.986765  0.594748
# 65           65     65_0      RUNNING  FullyBayesianMOO  0.000000  1.000000
# 66           66     66_0      RUNNING  FullyBayesianMOO  0.649954  0.411588
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.331688  0.518227  0.768639  ...  0.878176  0.400476
# 1          True  0.774161  0.386041  0.149913  ...  0.488173  0.509494
# 2          True  0.624342  0.902880  0.724386  ...  0.659783  0.857787
# 3          True  0.051067  0.005283  0.358711  ...  0.206288  0.247990
# 4          True  0.243664  0.770865  0.051561  ...  0.762042  0.252409
# ..          ...       ...       ...       ...  ...       ...       ...
# 62         True  0.848368  0.000000  1.000000  ...  0.000000  1.000000
# 63         True  0.805576  0.000000  1.000000  ...  0.000000  1.000000
# 64         True  0.986765  0.284260  0.350927  ...  0.000000  1.000000
# 65         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 66         True  0.649954  1.000000  0.000000  ...  0.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.311042  0.921721  0.477688  0.534732  0.962260  0.066680  0.332878
# 1   0.983468  0.364527  0.558230  0.189085  0.222211  0.922278  0.941651
# 2   0.160040  0.606264  0.199616  0.351869  0.538168  0.673346  0.067419
# 3   0.611765  0.177986  0.780206  0.885131  0.279069  0.318054  0.708575
# 4   0.098850  0.096717  0.996337  0.439767  0.654721  0.870681  0.453823
# ..       ...       ...       ...       ...       ...       ...       ...
# 62  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000
# 63  0.332584  0.300278  0.213800  0.001942  0.000000  0.000000  0.422917
# 64  0.000000  0.160110  1.000000  0.210951  0.000000  0.000000  0.036066
# 65  1.000000  0.000000  0.000000  1.000000  1.000000  1.000000  0.000000
# 66  1.000000  0.000000  1.000000  0.000000  0.900086  0.000000  1.000000
#
#          x29
# 0   0.818707
# 1   0.250061
# 2   0.098573
# 3   0.533918
# 4   0.979391
# ..       ...
# 62  0.000000
# 63  0.000000
# 64  0.000000
# 65  1.000000
# 66  0.000000
#
# [67 rows x 37 columns],     trial_index arm_name trial_status generation_method         a         b  \
# 0             0      0_0      RUNNING             Sobol  0.354701  0.812673
# 1             1      1_0      RUNNING             Sobol  0.817847  0.544423
# 2             2      2_0      RUNNING             Sobol  0.735489  0.757333
# 3             3      3_0      RUNNING             Sobol  0.218188  0.768793
# 4             4      4_0      RUNNING             Sobol  0.015436  0.948789
# ..          ...      ...          ...               ...       ...       ...
# 62           62     62_0      RUNNING  FullyBayesianMOO  0.000000  1.000000
# 63           63     63_0      RUNNING  FullyBayesianMOO  0.855769  0.338195
# 64           64     64_0      RUNNING  FullyBayesianMOO  0.253022  0.657449
# 65           65     65_0      RUNNING  FullyBayesianMOO  0.853385  0.395355
# 66           66     66_0      RUNNING  FullyBayesianMOO  0.454321  0.535240
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.354701  0.699149  0.787715  ...  0.815795  0.791946
# 1          True  0.817847  0.172923  0.082291  ...  0.138245  0.361736
# 2          True  0.735489  0.973463  0.529234  ...  0.518225  0.155454
# 3          True  0.218188  0.404467  0.358602  ...  0.465233  0.695031
# 4          True  0.015436  0.843929  0.211353  ...  0.997994  0.992329
# ..          ...       ...       ...       ...  ...       ...       ...
# 62         True  0.000000  0.000000  0.000000  ...  1.000000  0.000000
# 63         True  0.855769  0.000000  0.000000  ...  1.000000  0.000000
# 64         True  0.253022  0.000000  1.000000  ...  0.000000  0.000000
# 65         True  0.853385  0.000000  0.000000  ...  1.000000  0.000000
# 66         True  0.454321  0.000000  0.000000  ...  1.000000  1.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.591490  0.079347  0.280353  0.985139  0.927020  0.379185  0.536581
# 1   0.192949  0.712583  0.560110  0.044936  0.485184  0.967643  0.303735
# 2   0.993640  0.362556  0.186540  0.253541  0.509117  0.509034  0.982104
# 3   0.345001  0.995784  0.903919  0.716231  0.074972  0.081865  0.249875
# 4   0.848248  0.799100  0.848069  0.467500  0.743150  0.805223  0.731880
# ..       ...       ...       ...       ...       ...       ...       ...
# 62  1.000000  0.000000  1.000000  1.000000  0.000000  0.000000  0.000000
# 63  1.000000  0.000000  0.000000  0.000000  1.000000  0.000000  1.000000
# 64  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 65  1.000000  1.000000  0.000000  1.000000  1.000000  0.000000  0.000000
# 66  1.000000  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          x29
# 0   0.584246
# 1   0.049884
# 2   0.358364
# 3   0.761377
# 4   0.630382
# ..       ...
# 62  0.000000
# 63  0.000000
# 64  0.000000
# 65  1.000000
# 66  0.000000
#
# [67 rows x 37 columns]]
