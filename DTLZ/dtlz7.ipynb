# %%
# !lscpu |grep 'Model name'
# !nvidia-smi
# !pip install ax-platform
# Out:
# Model name:                      Intel(R) Xeon(R) CPU @ 2.30GHz
# Mon Mar 20 21:11:22 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    22W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ax-platform
#   Downloading ax_platform-0.3.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from ax-platform) (7.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.2.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (3.1.2)
# Collecting typeguard==2.13.3
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting botorch==0.8.3
#   Downloading botorch-0.8.3-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.8/521.8 KB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=5.12.0 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (5.13.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.4.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.10.1)
# Collecting gpytorch==1.9.1
#   Downloading gpytorch-1.9.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 KB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.13.1+cu116)
# Collecting linear-operator==0.3.0
#   Downloading linear_operator-0.3.0-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (0.6.0)
# Collecting pyro-ppl>=1.8.4
#   Downloading pyro_ppl-1.8.4-py3-none-any.whl (730 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.7/730.7 KB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.12.0->ax-platform) (8.2.2)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (7.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.6.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->ax-platform) (2.1.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (3.1.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (63.4.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.7 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (3.3.0)
# Collecting pyro-api>=0.1.1
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (4.65.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->ax-platform) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.12->botorch==0.8.3->ax-platform) (4.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->ax-platform) (0.8.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.7.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.6)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.16.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.17.1)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.8.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ax-platform) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->ax-platform) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.1.1)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.9/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.23.6)
# Requirement already satisfied: notebook-shim>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.11.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.3.3)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.19.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.6.2)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.9/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.9/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.9/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.21)
# Installing collected packages: pyro-api, typeguard, jedi, pyro-ppl, linear-operator, gpytorch, botorch, ax-platform
# Successfully installed ax-platform-0.3.1 botorch-0.8.3 gpytorch-1.9.1 jedi-0.18.2 linear-operator-0.3.0 pyro-api-0.1.2 pyro-ppl-1.8.4 typeguard-2.13.3

# %%
import pandas as pd
from ax import *
import torch

import numpy as np
from matplotlib import pyplot as plt
from matplotlib.cm import ScalarMappable

from ax.service.utils.report_utils import exp_to_df
from ax.runners.synthetic import SyntheticRunner
from ax.metrics.noisy_function import GenericNoisyFunctionMetric

# Analysis utilities, including a method to evaluate hypervolumes
from ax.modelbridge.modelbridge_utils import observed_hypervolume

from botorch.test_functions.multi_objective import DTLZ7

# %%
tkwargs = {
    "dtype": torch.double, 
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
}

# %%
dim = 30
problem = DTLZ7(num_objectives=2, dim=dim, negate=False).to(**tkwargs)

param_names = [f"x{i}" for i in range(dim)]

def f1(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names] # Obtiene los parámetros a evaluar
        return float(problem(torch.tensor(x_sorted, **tkwargs).clamp(0., 1.))[0]) # Evalúa los parámetros en el primer objetivo
    
def f2(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names]
        return float(problem(torch.tensor(x_sorted, **tkwargs).clamp(0., 1.))[1]) # Evalúa los parámetros en el segundo objetivo

metric_a = GenericNoisyFunctionMetric("a", f=f1, noise_sd=0.0, lower_is_better=True)
metric_b = GenericNoisyFunctionMetric("b", f=f2, noise_sd=0.0, lower_is_better=True)

# %%
search_space = SearchSpace(
    parameters=[
        RangeParameter(name=param_name, lower=0, upper=1, parameter_type=ParameterType.FLOAT)
        for param_name in param_names
        ]
)

mo = MultiObjective(
    objectives=[Objective(metric=metric_a), Objective(metric=metric_b)],
)

objective_thresholds = [
    ObjectiveThreshold(metric=metric, bound=val, relative=False)
    for metric, val in zip(mo.metrics, problem.ref_point)
]

optimization_config = MultiObjectiveOptimizationConfig(
    objective=mo,
    objective_thresholds=objective_thresholds,
)

# %%
N_INIT = 2 * (dim + 1)
N_BATCH = 10
BATCH_SIZE = 1

def build_experiment():
    experiment = Experiment(
        name="pareto_experiment",
        search_space=search_space,
        optimization_config=optimization_config,
        runner=SyntheticRunner(),
    )
    return experiment

def initialize_experiment(experiment):
    sobol = Models.SOBOL(search_space=experiment.search_space)

    for _ in range(N_INIT):
        experiment.new_trial(sobol.gen(1)).run()

    return experiment.fetch_data()

# %%
import time

executions = 10
execution_times = []
all_df = []
all_outcomes = []

for exec in range(executions):
  start_time = time.time()

  experiment = build_experiment()
  data = initialize_experiment(experiment)

  hv_list = []
  model = None
  for i in range(N_BATCH):   
      model = Models.FULLYBAYESIANMOO(
          experiment=experiment, 
          data=data,
          num_samples=16,
          warmup_steps=32,
          torch_device=tkwargs["device"],
      )
      generator_run = model.gen(BATCH_SIZE)
      trial = experiment.new_trial(generator_run=generator_run)
      trial.run()
      data = Data.from_multiple_data([data, trial.fetch_data()])
      
      exp_df = exp_to_df(experiment)
      outcomes = np.array(exp_df[['a', 'b']], dtype=np.double)
      try:
          hv = observed_hypervolume(modelbridge=model)
      except:
          hv = 0
          print("Failed to compute hv")
      hv_list.append(hv)
      print(f"Execution: {exec + 1}, Iteration: {i + 1}, HV: {hv}")

  execution_times.append(time.time() - start_time)

  all_df.append(exp_to_df(experiment).sort_values(by=["trial_index"]))
  all_outcomes.append(np.array(exp_to_df(experiment)[['a', 'b']], dtype=np.double))
# Out:
# Sample: 100%|██████████| 48/48 [00:22,  2.13it/s, step size=4.07e-01, acc. prob=0.776]
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=3.57e-01, acc. prob=0.761]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 1, HV: 77.10368296698088
# Sample: 100%|██████████| 48/48 [00:16,  2.97it/s, step size=4.88e-01, acc. prob=0.428]
# Sample: 100%|██████████| 48/48 [00:16,  2.82it/s, step size=4.95e-01, acc. prob=0.632]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 2, HV: 180.83889337135966
# Sample: 100%|██████████| 48/48 [00:16,  2.84it/s, step size=4.71e-01, acc. prob=0.504]
# Sample: 100%|██████████| 48/48 [00:17,  2.80it/s, step size=4.46e-01, acc. prob=0.676]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 3, HV: 186.37747398096056
# Sample: 100%|██████████| 48/48 [00:17,  2.82it/s, step size=2.50e-01, acc. prob=0.830]
# Sample: 100%|██████████| 48/48 [00:16,  2.89it/s, step size=6.31e-01, acc. prob=0.244]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 4, HV: 186.37747398096056
# Sample: 100%|██████████| 48/48 [00:17,  2.78it/s, step size=2.06e-01, acc. prob=0.756]
# Sample: 100%|██████████| 48/48 [00:17,  2.78it/s, step size=3.41e-01, acc. prob=0.867]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 5, HV: 186.37747398096056
# Sample: 100%|██████████| 48/48 [00:12,  3.73it/s, step size=2.60e-01, acc. prob=0.352]
# Sample: 100%|██████████| 48/48 [00:16,  2.84it/s, step size=4.91e-01, acc. prob=0.812]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 6, HV: 186.37747398096056
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=4.93e-01, acc. prob=0.726]
# Sample: 100%|██████████| 48/48 [00:16,  2.94it/s, step size=3.10e-01, acc. prob=0.915]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 7, HV: 186.37747398096056
# Sample: 100%|██████████| 48/48 [00:13,  3.63it/s, step size=4.00e-01, acc. prob=0.239]
# Sample: 100%|██████████| 48/48 [00:18,  2.66it/s, step size=2.89e-01, acc. prob=0.932]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 8, HV: 186.37747398096056
# Sample: 100%|██████████| 48/48 [00:15,  3.02it/s, step size=3.54e-01, acc. prob=0.769]
# Sample: 100%|██████████| 48/48 [00:17,  2.80it/s, step size=3.13e-01, acc. prob=0.883]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 9, HV: 186.37747398096056
# Sample: 100%|██████████| 48/48 [00:17,  2.81it/s, step size=4.43e-01, acc. prob=0.727]
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=3.19e-01, acc. prob=0.944]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 10, HV: 186.37747398096056
# Sample: 100%|██████████| 48/48 [00:16,  2.94it/s, step size=3.78e-01, acc. prob=0.846]
# Sample: 100%|██████████| 48/48 [00:13,  3.50it/s, step size=5.92e-01, acc. prob=0.064]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 1, HV: 91.28024271227487
# Sample: 100%|██████████| 48/48 [00:16,  2.97it/s, step size=7.70e-02, acc. prob=0.826]
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=6.50e-01, acc. prob=0.070]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 2, HV: 172.20251349607267
# Sample: 100%|██████████| 48/48 [00:15,  3.10it/s, step size=3.88e-01, acc. prob=0.860]
# Sample: 100%|██████████| 48/48 [00:16,  2.95it/s, step size=2.27e-01, acc. prob=0.887]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 3, HV: 178.79161373383695
# Sample: 100%|██████████| 48/48 [00:16,  2.92it/s, step size=5.92e-01, acc. prob=0.525]
# Sample: 100%|██████████| 48/48 [00:17,  2.67it/s, step size=4.39e-01, acc. prob=0.791]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 4, HV: 178.79161373383695
# Sample: 100%|██████████| 48/48 [00:08,  5.44it/s, step size=7.40e-01, acc. prob=0.126]
# Sample: 100%|██████████| 48/48 [00:16,  2.96it/s, step size=4.14e-01, acc. prob=0.873]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 5, HV: 178.79161373383695
# Sample: 100%|██████████| 48/48 [00:14,  3.31it/s, step size=5.31e-01, acc. prob=0.229]
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=5.59e-01, acc. prob=0.735]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 6, HV: 178.79161373383695
# Sample: 100%|██████████| 48/48 [00:16,  2.86it/s, step size=4.29e-02, acc. prob=0.951]
# Sample: 100%|██████████| 48/48 [00:17,  2.79it/s, step size=4.01e-01, acc. prob=0.349]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 7, HV: 178.79161373383695
# Sample: 100%|██████████| 48/48 [00:15,  3.12it/s, step size=4.04e-01, acc. prob=0.831]
# Sample: 100%|██████████| 48/48 [00:17,  2.78it/s, step size=5.20e-01, acc. prob=0.644]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 8, HV: 178.79161373383695
# Sample: 100%|██████████| 48/48 [00:14,  3.38it/s, step size=4.35e-01, acc. prob=0.430]
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=4.54e-01, acc. prob=0.803]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 9, HV: 178.79161373383695
# Sample: 100%|██████████| 48/48 [00:16,  2.94it/s, step size=2.79e-01, acc. prob=0.877]
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=2.59e-01, acc. prob=0.847]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 10, HV: 178.79161373383695
# Sample: 100%|██████████| 48/48 [00:16,  2.92it/s, step size=3.78e-01, acc. prob=0.878]
# Sample: 100%|██████████| 48/48 [00:17,  2.68it/s, step size=3.77e-01, acc. prob=0.831]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 1, HV: 89.132506011499
# Sample: 100%|██████████| 48/48 [00:16,  2.89it/s, step size=3.93e-01, acc. prob=0.881]
# Sample: 100%|██████████| 48/48 [00:18,  2.65it/s, step size=3.39e-01, acc. prob=0.861]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 2, HV: 160.7014973635434
# Sample: 100%|██████████| 48/48 [00:17,  2.80it/s, step size=2.98e-01, acc. prob=0.952]
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=4.43e-01, acc. prob=0.726]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 3, HV: 166.2213595082151
# Sample: 100%|██████████| 48/48 [00:10,  4.41it/s, step size=4.50e-01, acc. prob=0.241]
# Sample: 100%|██████████| 48/48 [00:16,  2.83it/s, step size=3.80e-01, acc. prob=0.498]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 4, HV: 167.46273881855993
# Sample: 100%|██████████| 48/48 [00:16,  2.98it/s, step size=5.16e-01, acc. prob=0.485]
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=2.57e-01, acc. prob=0.841]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 5, HV: 167.46273881855993
# Sample: 100%|██████████| 48/48 [00:17,  2.67it/s, step size=5.07e-02, acc. prob=0.941]
# Sample: 100%|██████████| 48/48 [00:16,  2.88it/s, step size=4.17e-01, acc. prob=0.567]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 6, HV: 167.46273881855993
# Sample: 100%|██████████| 48/48 [00:15,  3.05it/s, step size=4.29e-01, acc. prob=0.623]
# Sample: 100%|██████████| 48/48 [00:16,  2.86it/s, step size=5.68e-01, acc. prob=0.373]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 7, HV: 167.46273881855993
# Sample: 100%|██████████| 48/48 [00:16,  2.90it/s, step size=2.43e-01, acc. prob=0.888]
# Sample: 100%|██████████| 48/48 [00:17,  2.73it/s, step size=4.13e-01, acc. prob=0.802]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 8, HV: 167.46273881855993
# Sample: 100%|██████████| 48/48 [00:16,  2.86it/s, step size=3.92e-01, acc. prob=0.750]
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=3.94e-01, acc. prob=0.557]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 9, HV: 167.46273881855993
# Sample: 100%|██████████| 48/48 [00:15,  3.10it/s, step size=2.48e-01, acc. prob=0.916]
# Sample: 100%|██████████| 48/48 [00:15,  3.02it/s, step size=6.31e-01, acc. prob=0.074]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 10, HV: 167.46273881855993
# Sample: 100%|██████████| 48/48 [00:14,  3.35it/s, step size=2.53e-01, acc. prob=0.610]
# Sample: 100%|██████████| 48/48 [00:16,  2.87it/s, step size=6.88e-01, acc. prob=0.103]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 1, HV: 75.62842698358831
# Sample: 100%|██████████| 48/48 [00:14,  3.28it/s, step size=2.80e-01, acc. prob=0.567]
# Sample: 100%|██████████| 48/48 [00:11,  4.25it/s, step size=3.90e-01, acc. prob=0.191]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 2, HV: 160.32706473620155
# Sample: 100%|██████████| 48/48 [00:10,  4.77it/s, step size=2.29e-01, acc. prob=0.095]
# Sample: 100%|██████████| 48/48 [00:15,  3.03it/s, step size=5.70e-01, acc. prob=0.332]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 3, HV: 166.49846186906584
# Sample: 100%|██████████| 48/48 [00:17,  2.73it/s, step size=4.06e-01, acc. prob=0.822]
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=3.60e-01, acc. prob=0.643]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 4, HV: 166.49846186906584
# Sample: 100%|██████████| 48/48 [00:17,  2.73it/s, step size=1.93e-01, acc. prob=0.867]
# Sample: 100%|██████████| 48/48 [00:17,  2.76it/s, step size=4.53e-01, acc. prob=0.745]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 5, HV: 166.49846186906584
# Sample: 100%|██████████| 48/48 [00:14,  3.25it/s, step size=3.71e-01, acc. prob=0.492]
# Sample: 100%|██████████| 48/48 [00:15,  3.18it/s, step size=5.41e-01, acc. prob=0.168]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 6, HV: 166.49846186906584
# Sample: 100%|██████████| 48/48 [00:16,  2.98it/s, step size=4.08e-01, acc. prob=0.828]
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=4.04e-01, acc. prob=0.859]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 7, HV: 166.49846186906584
# Sample: 100%|██████████| 48/48 [00:16,  2.85it/s, step size=3.65e-01, acc. prob=0.813]
# Sample: 100%|██████████| 48/48 [00:17,  2.68it/s, step size=4.61e-01, acc. prob=0.812]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 8, HV: 166.49846186906584
# Sample: 100%|██████████| 48/48 [00:15,  3.04it/s, step size=2.15e-01, acc. prob=0.949]
# Sample: 100%|██████████| 48/48 [00:17,  2.78it/s, step size=5.12e-01, acc. prob=0.682]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 9, HV: 166.49846186906584
# Sample: 100%|██████████| 48/48 [00:11,  4.03it/s, step size=5.04e-02, acc. prob=0.175]
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=4.08e-01, acc. prob=0.738]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 10, HV: 166.49846186906584
# Sample: 100%|██████████| 48/48 [00:16,  2.83it/s, step size=4.96e-01, acc. prob=0.581]
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=4.82e-01, acc. prob=0.504]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 1, HV: 87.40752646496668
# Sample: 100%|██████████| 48/48 [00:14,  3.36it/s, step size=3.85e-01, acc. prob=0.365]
# Sample: 100%|██████████| 48/48 [00:16,  2.86it/s, step size=3.09e-01, acc. prob=0.908]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 2, HV: 173.33912578132185
# Sample: 100%|██████████| 48/48 [00:16,  2.90it/s, step size=3.78e-01, acc. prob=0.623]
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=2.23e-01, acc. prob=0.955]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 3, HV: 179.12899254781544
# Sample: 100%|██████████| 48/48 [00:16,  2.96it/s, step size=2.72e-01, acc. prob=0.777]
# Sample: 100%|██████████| 48/48 [00:16,  2.91it/s, step size=5.10e-01, acc. prob=0.351]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 4, HV: 179.12899254781544
# Sample: 100%|██████████| 48/48 [00:16,  2.87it/s, step size=2.28e-01, acc. prob=0.576]
# Sample: 100%|██████████| 48/48 [00:17,  2.76it/s, step size=3.29e-01, acc. prob=0.872]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 5, HV: 179.12899254781544
# Sample: 100%|██████████| 48/48 [00:16,  2.88it/s, step size=2.76e-01, acc. prob=0.869]
# Sample: 100%|██████████| 48/48 [00:16,  2.86it/s, step size=2.71e-01, acc. prob=0.929]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 6, HV: 179.12899254781544
# Sample: 100%|██████████| 48/48 [00:15,  3.01it/s, step size=5.33e-01, acc. prob=0.584]
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=2.70e-01, acc. prob=0.662]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 7, HV: 179.63364426544044
# Sample: 100%|██████████| 48/48 [00:15,  3.01it/s, step size=1.96e-01, acc. prob=0.904]
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=3.54e-01, acc. prob=0.893]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 8, HV: 179.63364426544044
# Sample: 100%|██████████| 48/48 [00:11,  4.18it/s, step size=4.30e-01, acc. prob=0.204]
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=4.45e-01, acc. prob=0.802]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 9, HV: 179.63364426544044
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=5.31e-01, acc. prob=0.074]
# Sample: 100%|██████████| 48/48 [00:17,  2.81it/s, step size=3.25e-01, acc. prob=0.827]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 10, HV: 179.63364426544044
# Sample: 100%|██████████| 48/48 [00:15,  3.07it/s, step size=5.15e-01, acc. prob=0.214]
# Sample: 100%|██████████| 48/48 [00:12,  3.94it/s, step size=3.73e-01, acc. prob=0.227]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 1, HV: 82.49692201977717
# Sample: 100%|██████████| 48/48 [00:16,  2.92it/s, step size=4.91e-01, acc. prob=0.772]
# Sample: 100%|██████████| 48/48 [00:17,  2.82it/s, step size=3.51e-01, acc. prob=0.889]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 2, HV: 159.26156254549107
# Sample: 100%|██████████| 48/48 [00:16,  2.84it/s, step size=4.09e-01, acc. prob=0.778]
# Sample: 100%|██████████| 48/48 [00:16,  2.86it/s, step size=5.41e-01, acc. prob=0.544]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 3, HV: 164.9523560306439
# Sample: 100%|██████████| 48/48 [00:16,  2.90it/s, step size=5.35e-01, acc. prob=0.138]
# Sample: 100%|██████████| 48/48 [00:16,  2.97it/s, step size=5.58e-01, acc. prob=0.300]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 4, HV: 164.9523560306439
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=4.24e-01, acc. prob=0.755]
# Sample: 100%|██████████| 48/48 [00:17,  2.68it/s, step size=5.14e-01, acc. prob=0.629]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 5, HV: 164.9523560306439
# Sample: 100%|██████████| 48/48 [00:18,  2.62it/s, step size=3.50e-01, acc. prob=0.854]
# Sample: 100%|██████████| 48/48 [00:17,  2.81it/s, step size=5.83e-01, acc. prob=0.637]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 6, HV: 164.9523560306439
# Sample: 100%|██████████| 48/48 [00:15,  3.06it/s, step size=2.98e-01, acc. prob=0.738]
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=4.29e-01, acc. prob=0.691]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 7, HV: 164.9523560306439
# Sample: 100%|██████████| 48/48 [00:16,  2.83it/s, step size=6.39e-01, acc. prob=0.240]
# Sample: 100%|██████████| 48/48 [00:17,  2.81it/s, step size=4.62e-01, acc. prob=0.716]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 8, HV: 164.9523560306439
# Sample: 100%|██████████| 48/48 [00:15,  3.03it/s, step size=4.17e-01, acc. prob=0.860]
# Sample: 100%|██████████| 48/48 [00:17,  2.74it/s, step size=2.42e-01, acc. prob=0.869]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 9, HV: 164.9523560306439
# Sample: 100%|██████████| 48/48 [00:09,  5.06it/s, step size=3.68e-01, acc. prob=0.108]
# Sample: 100%|██████████| 48/48 [00:16,  2.89it/s, step size=3.21e-01, acc. prob=0.845]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 10, HV: 164.9523560306439
# Sample: 100%|██████████| 48/48 [00:16,  2.82it/s, step size=4.11e-01, acc. prob=0.507]
# Sample: 100%|██████████| 48/48 [00:17,  2.79it/s, step size=4.36e-01, acc. prob=0.767]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 1, HV: 86.18189232783001
# Sample: 100%|██████████| 48/48 [00:18,  2.65it/s, step size=4.02e-01, acc. prob=0.710]
# Sample: 100%|██████████| 48/48 [00:18,  2.67it/s, step size=5.14e-01, acc. prob=0.576]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 2, HV: 157.23311686124143
# Sample: 100%|██████████| 48/48 [00:16,  2.83it/s, step size=3.59e-01, acc. prob=0.787]
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=4.68e-01, acc. prob=0.726]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 3, HV: 163.34158596352003
# Sample: 100%|██████████| 48/48 [00:16,  2.88it/s, step size=3.43e-01, acc. prob=0.890]
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=2.90e-01, acc. prob=0.857]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 4, HV: 163.34158596352003
# Sample: 100%|██████████| 48/48 [00:17,  2.82it/s, step size=2.13e-01, acc. prob=0.952]
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=3.14e-01, acc. prob=0.931]
# ...
#   warnings.warn(
# Execution: 8, Iteration: 8, HV: 173.98168515093062
# Sample: 100%|██████████| 48/48 [00:17,  2.80it/s, step size=5.61e-01, acc. prob=0.339]
# Sample: 100%|██████████| 48/48 [00:17,  2.82it/s, step size=6.11e-01, acc. prob=0.545]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 9, HV: 173.98168515093062
# Sample: 100%|██████████| 48/48 [00:16,  2.88it/s, step size=3.55e-01, acc. prob=0.792]
# Sample: 100%|██████████| 48/48 [00:17,  2.71it/s, step size=4.87e-01, acc. prob=0.789]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 10, HV: 173.98168515093062
# Sample: 100%|██████████| 48/48 [00:17,  2.79it/s, step size=5.61e-01, acc. prob=0.186]
# Sample: 100%|██████████| 48/48 [00:16,  2.94it/s, step size=4.42e-01, acc. prob=0.749]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 1, HV: 75.77868699209249
# Sample: 100%|██████████| 48/48 [00:13,  3.57it/s, step size=2.79e-01, acc. prob=0.287]
# Sample: 100%|██████████| 48/48 [00:18,  2.66it/s, step size=5.08e-01, acc. prob=0.737]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 2, HV: 168.40149161068405
# Sample: 100%|██████████| 48/48 [00:16,  2.91it/s, step size=4.98e-01, acc. prob=0.656]
# Sample: 100%|██████████| 48/48 [00:17,  2.76it/s, step size=2.76e-01, acc. prob=0.844]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 3, HV: 175.5393473685701
# Sample: 100%|██████████| 48/48 [00:16,  2.83it/s, step size=9.55e-02, acc. prob=0.863]
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=4.84e-01, acc. prob=0.820]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 4, HV: 175.5393473685701
# Sample: 100%|██████████| 48/48 [00:16,  2.83it/s, step size=2.75e-01, acc. prob=0.770]
# Sample: 100%|██████████| 48/48 [00:17,  2.76it/s, step size=3.31e-01, acc. prob=0.797]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 5, HV: 175.5393473685701
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=3.71e-01, acc. prob=0.742]
# Sample: 100%|██████████| 48/48 [00:18,  2.55it/s, step size=3.48e-01, acc. prob=0.922]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 6, HV: 175.5393473685701
# Sample: 100%|██████████| 48/48 [00:14,  3.21it/s, step size=2.86e-01, acc. prob=0.820]
# Sample: 100%|██████████| 48/48 [00:17,  2.71it/s, step size=3.63e-01, acc. prob=0.881]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 7, HV: 175.5393473685701
# Sample: 100%|██████████| 48/48 [00:16,  2.89it/s, step size=1.22e-01, acc. prob=0.925]
# Sample: 100%|██████████| 48/48 [00:17,  2.73it/s, step size=4.57e-01, acc. prob=0.754]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 8, HV: 175.5393473685701
# Sample: 100%|██████████| 48/48 [00:15,  3.04it/s, step size=4.09e-01, acc. prob=0.741]
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=3.64e-01, acc. prob=0.887]
# /usr/local/lib/python3.9/dist-packages/botorch/optim/initializers.py:224: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 9, HV: 175.5393473685701
# Sample: 100%|██████████| 48/48 [00:17,  2.79it/s, step size=2.45e-01, acc. prob=0.923]
# Sample: 100%|██████████| 48/48 [00:17,  2.74it/s, step size=4.01e-01, acc. prob=0.857]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 10, HV: 175.5393473685701
# Sample: 100%|██████████| 48/48 [00:16,  2.88it/s, step size=5.22e-01, acc. prob=0.446]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=3.44e-01, acc. prob=0.721]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 1, HV: 74.15549746306675
# Sample: 100%|██████████| 48/48 [00:15,  3.02it/s, step size=4.01e-01, acc. prob=0.749]
# Sample: 100%|██████████| 48/48 [00:16,  2.84it/s, step size=3.78e-01, acc. prob=0.807]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 2, HV: 171.94793805917567
# Sample: 100%|██████████| 48/48 [00:16,  2.84it/s, step size=9.70e-02, acc. prob=0.961]
# Sample: 100%|██████████| 48/48 [00:16,  2.99it/s, step size=4.25e-01, acc. prob=0.500]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 3, HV: 179.0
# Sample: 100%|██████████| 48/48 [00:09,  4.81it/s, step size=2.54e-01, acc. prob=0.331]
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=4.20e-01, acc. prob=0.543]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 4, HV: 179.0
# Sample: 100%|██████████| 48/48 [00:16,  2.99it/s, step size=1.77e-01, acc. prob=0.842]
# Sample: 100%|██████████| 48/48 [00:16,  2.88it/s, step size=5.71e-01, acc. prob=0.253]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 5, HV: 179.0
# Sample: 100%|██████████| 48/48 [00:17,  2.76it/s, step size=3.48e-01, acc. prob=0.700]
# Sample: 100%|██████████| 48/48 [00:18,  2.66it/s, step size=4.44e-01, acc. prob=0.864]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 6, HV: 179.0
# Sample: 100%|██████████| 48/48 [00:15,  3.03it/s, step size=1.78e-01, acc. prob=0.457]
# Sample: 100%|██████████| 48/48 [00:17,  2.82it/s, step size=2.46e-01, acc. prob=0.908]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 7, HV: 179.0
# Sample: 100%|██████████| 48/48 [00:11,  4.14it/s, step size=2.64e-01, acc. prob=0.173]
# Sample: 100%|██████████| 48/48 [00:17,  2.77it/s, step size=4.44e-01, acc. prob=0.457]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 8, HV: 179.0
# Sample: 100%|██████████| 48/48 [00:16,  2.87it/s, step size=1.69e-01, acc. prob=0.771]
# Sample: 100%|██████████| 48/48 [00:16,  2.88it/s, step size=3.81e-01, acc. prob=0.890]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 9, HV: 179.0
# Sample: 100%|██████████| 48/48 [00:17,  2.78it/s, step size=1.83e-01, acc. prob=0.962]
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=3.01e-01, acc. prob=0.851]
# Execution: 10, Iteration: 10, HV: 179.0
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(

# %%
from torch import Tensor
# %matplotlib inline

for exec in range(executions):
  fig, axes = plt.subplots(1, 1, figsize=(8,6))

  cm = plt.cm.get_cmap('viridis')
  batch_number = all_df[exec].trial_index.values
  sc = axes.scatter(all_outcomes[exec][:, 0], all_outcomes[exec][:,1], c=batch_number, alpha=0.8)
  axes.set_title(f'DTLZ7 Execution #{exec + 1}')
  axes.set_xlabel("Objective 1")
  axes.set_ylabel("Objective 2")
  norm = plt.Normalize(batch_number.min(), batch_number.max())
  sm =  ScalarMappable(norm=norm, cmap=cm)
  fig.subplots_adjust(right=0.9)
  cbar_ax = fig.add_axes([0.93, 0.15, 0.01, 0.7])
  cbar = fig.colorbar(sm, cax=cbar_ax)
  cbar.ax.set_title("Trial")
# Out:
# <ipython-input-9-4a4fa20fb444>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %%
# %matplotlib inline
fig, axes = plt.subplots(1, 1)
plt.xticks(np.arange(1, executions + 1))

axes.scatter(np.arange(1, executions + 1), np.array(execution_times))
axes.grid(True)
axes.set_xlabel("Execution")
axes.set_ylabel("Time")

print("Execution times:", np.array(execution_times))
print("Average execution time:", np.array(execution_times).sum()/len(execution_times))
# Out:
# Execution times: [366.64509773 347.43125367 359.62638831 338.38807845 361.10566211
#  344.30314994 368.63199282 350.80033875 362.93406582 358.84753323]
# Average execution time: 355.8713560819626

# %%
print(all_df)
# Out:
# [    trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.705857  11.016972
# 1             1      1_0      RUNNING             Sobol  0.215949  12.197103
# 2             2      2_0      RUNNING             Sobol  0.404500  13.137515
# 3             3      3_0      RUNNING             Sobol  0.892429  12.138653
# 4             4      4_0      RUNNING             Sobol  0.871673   9.790751
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.304990  11.637849
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000   6.806257
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.958877  12.515299
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.363339  12.164952
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000   7.724138
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.705857  0.203466  0.036160  ...  0.322099  0.053077
# 1          True  0.215949  0.530140  0.863739  ...  0.617939  0.603938
# 2          True  0.404500  0.279582  0.295536  ...  0.161355  0.871811
# 3          True  0.892429  0.953913  0.624818  ...  0.894695  0.281787
# 4          True  0.871673  0.375643  0.892718  ...  0.391935  0.174833
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.304990  0.586571  0.843283  ...  0.728493  0.382802
# 68         True  0.000000  0.000000  0.000000  ...  0.000000  0.521191
# 69         True  0.958877  0.481350  0.937256  ...  0.268581  0.736728
# 70         True  0.363339  0.210601  0.052502  ...  0.792496  0.616706
# 71         True  0.000000  1.000000  0.000000  ...  0.000000  1.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.297476  0.972734  0.349395  0.665592  0.839346  0.649925  0.023820
# 1   0.565346  0.032904  0.673958  0.127687  0.319398  0.004145  0.501342
# 2   0.128252  0.595887  0.156173  0.483958  0.672731  0.368846  0.394864
# 3   0.985486  0.413657  0.820367  0.942154  0.168510  0.972696  0.888111
# 4   0.048049  0.255026  0.972213  0.250066  0.530442  0.230623  0.169742
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.220843  0.172093  0.873925  0.046453  0.542614  0.891501  0.262174
# 68  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 69  0.903643  0.280041  0.674827  0.057195  0.080274  0.249591  0.163437
# 70  0.257111  0.572235  0.752279  0.501730  0.351527  0.524763  0.220028
# 71  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000  0.000000
#
#          x29
# 0   0.316861
# 1   0.886138
# 2   0.616749
# 3   0.180288
# 4   0.480632
# ..       ...
# 67  0.008846
# 68  0.000000
# 69  0.355226
# 70  0.442142
# 71  1.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.286538  14.769911
# 1             1      1_0      RUNNING             Sobol  0.841945   8.780162
# 2             2      2_0      RUNNING             Sobol  0.579679  13.625380
# 3             3      3_0      RUNNING             Sobol  0.041854  12.796617
# 4             4      4_0      RUNNING             Sobol  0.169418  14.292239
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000   5.241379
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000  10.181577
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000  12.865223
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.000000   8.344828
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000   7.724138
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.286538  0.576833  0.475366  ...  0.927636  0.555629
# 1          True  0.841945  0.466911  0.547597  ...  0.460809  0.110020
# 2          True  0.579679  0.906988  0.091974  ...  0.610331  0.478775
# 3          True  0.041854  0.047309  0.883138  ...  0.018321  0.908310
# 4          True  0.169418  0.780391  0.735493  ...  0.795979  0.717741
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 68         True  0.000000  0.665084  0.000000  ...  0.515161  0.693107
# 69         True  0.000000  0.096899  0.866145  ...  0.031156  0.000000
# 70         True  0.000000  1.000000  0.000000  ...  0.000000  0.000000
# 71         True  0.000000  0.000000  0.000000  ...  0.000000  1.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.453149  0.786020  0.966680  0.357881  0.767146  0.184369  0.920049
# 1   0.845151  0.242378  0.180833  0.729422  0.109453  0.965044  0.078016
# 2   0.102345  0.710019  0.601899  0.795237  0.552532  0.579920  0.500793
# 3   0.712540  0.261585  0.262289  0.166777  0.332343  0.298008  0.469779
# 4   0.138791  0.378554  0.487207  0.876754  0.684573  0.840014  0.770066
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000
# 68  0.348378  0.380615  0.093608  0.065150  0.510058  0.292824  0.466978
# 69  0.573552  0.399225  0.932274  0.896912  0.323650  0.699262  0.177048
# 70  0.000000  0.000000  1.000000  1.000000  0.000000  0.000000  1.000000
# 71  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#              x29
# 0   3.643225e-01
# 1   5.459668e-01
# 2   7.738020e-01
# 3   6.481395e-02
# 4   4.612593e-01
# ..           ...
# 67  0.000000e+00
# 68  5.170618e-02
# 69  4.671127e-01
# 70  0.000000e+00
# 71  2.775558e-17
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.556141  13.402583
# 1             1      1_0      RUNNING             Sobol  0.275969  13.223617
# 2             2      2_0      RUNNING             Sobol  0.188981  12.448201
# 3             3      3_0      RUNNING             Sobol  0.971124  11.459464
# 4             4      4_0      RUNNING             Sobol  0.854116  12.404151
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000   7.542062
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000   5.241379
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000  13.313723
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.360423  13.087874
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000   7.103448
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.556141  0.077890  0.228717  ...  0.921278  0.793921
# 1          True  0.275969  0.829609  0.659401  ...  0.199761  0.421775
# 2          True  0.188981  0.360323  0.331136  ...  0.571460  0.115483
# 3          True  0.971124  0.608151  0.775496  ...  0.291754  0.739613
# 4          True  0.854116  0.493767  0.557864  ...  0.791107  0.995934
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.000000  1.000000  0.000000  ...  1.000000  1.000000
# 68         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 69         True  0.000000  0.765672  0.972082  ...  0.400809  0.596965
# 70         True  0.360423  0.961463  0.514609  ...  0.431751  0.786886
# 71         True  0.000000  0.000000  0.000000  ...  1.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.056232  0.065730  0.481436  0.143355  0.569846  0.073996  0.949294
# 1   0.864377  0.834250  0.580413  0.905141  0.053320  0.500655  0.383210
# 2   0.377808  0.431592  0.083067  0.609606  0.858870  0.820074  0.641220
# 3   0.701583  0.668916  0.980123  0.371255  0.279693  0.262389  0.207888
# 4   0.306909  0.577937  0.772617  0.659472  0.966502  0.687106  0.767150
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.000000  0.000000  0.000000  0.000000  0.000000  0.783016  0.000000
# 68  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 69  0.496690  0.125214  0.676009  0.179858  1.000000  0.868076  0.248066
# 70  0.453695  0.230489  0.999414  0.009981  0.997890  0.502354  0.427943
# 71  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000
#
#          x29
# 0   0.985553
# 1   0.422458
# 2   0.165655
# 3   0.726613
# 4   0.801666
# ..       ...
# 67  0.000000
# 68  0.000000
# 69  0.839392
# 70  0.565198
# 71  0.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.222553  12.444029
# 1             1      1_0      RUNNING             Sobol  0.583432  13.057587
# 2             2      2_0      RUNNING             Sobol  0.922778   9.898535
# 3             3      3_0      RUNNING             Sobol  0.256252  13.599218
# 4             4      4_0      RUNNING             Sobol  0.421398  12.587917
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000   6.732032
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000   9.240958
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000  11.890324
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.000000   7.103448
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000   8.915850
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.222553  0.387158  0.284795  ...  0.743675  0.701841
# 1          True  0.583432  0.788670  0.877081  ...  0.097529  0.365444
# 2          True  0.922778  0.059619  0.054308  ...  0.983198  0.005476
# 3          True  0.256252  0.647366  0.646592  ...  0.363845  0.934578
# 4          True  0.421398  0.171702  0.816692  ...  0.546971  0.597656
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 68         True  0.000000  0.000000  1.000000  ...  0.000000  0.000000
# 69         True  0.000000  0.531390  0.801154  ...  0.234177  0.576782
# 70         True  0.000000  0.000000  0.000000  ...  0.000000  1.000000
# 71         True  0.000000  0.000000  0.000000  ...  0.919980  1.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.170734  0.973302  0.183839  0.702839  0.342675  0.346060  0.764084
# 1   0.501277  0.252197  0.594012  0.477669  0.768084  0.850647  0.247683
# 2   0.264284  0.684589  0.314772  0.214664  0.022128  0.509971  0.531845
# 3   0.907448  0.089425  0.904631  0.997338  0.588662  0.015109  0.456388
# 4   0.468733  0.237553  0.801095  0.037636  0.162224  0.921477  0.912789
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.000000  0.000000  0.000000  0.000000  1.000000  0.000000  1.000000
# 68  1.000000  1.000000  0.000000  1.000000  0.000000  0.000000  0.000000
# 69  0.592836  0.120379  0.166218  0.000000  0.538040  0.817185  0.160372
# 70  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 71  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000
#
#          x29
# 0   0.607809
# 1   0.384114
# 2   0.059412
# 3   0.964746
# 4   0.648020
# ..       ...
# 67  0.000000
# 68  0.000000
# 69  0.756358
# 70  1.000000
# 71  0.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.565125  12.403207
# 1             1      1_0      RUNNING             Sobol  0.026015  14.145576
# 2             2      2_0      RUNNING             Sobol  0.494339  11.845316
# 3             3      3_0      RUNNING             Sobol  0.908354  12.407770
# 4             4      4_0      RUNNING             Sobol  0.801842  12.144860
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000   4.000000
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000   5.862069
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000   9.211104
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.000000   9.570606
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000   7.103448
#
#     is_feasible        x0        x1        x2  ...       x20           x21  \
# 0          True  0.565125  0.086668  0.069321  ...  0.624219  2.932545e-01
# 1          True  0.026015  0.996183  0.902443  ...  0.106957  9.509227e-01
# 2          True  0.494339  0.404666  0.298284  ...  0.989940  6.609607e-01
# 3          True  0.908354  0.557405  0.730059  ...  0.475616  6.753054e-02
# 4          True  0.801842  0.328280  0.863563  ...  0.635294  4.408877e-01
# ..          ...       ...       ...       ...  ...       ...           ...
# 67         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000e+00
# 68         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000e+00
# 69         True  0.000000  0.000000  0.000000  ...  0.000000  2.775558e-17
# 70         True  0.000000  1.000000  0.000000  ...  0.000000  0.000000e+00
# 71         True  0.000000  0.000000  1.000000  ...  0.000000  1.000000e+00
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.959364  0.187147  0.474553  0.446318  0.598771  0.788160  0.261470
# 1   0.319428  0.807622  0.713864  0.501409  0.281161  0.334026  0.554363
# 2   0.719867  0.485730  0.209045  0.829512  0.868111  0.094052  0.016079
# 3   0.109739  0.614995  0.977545  0.149526  0.002188  0.516932  0.793346
# 4   0.506040  0.644611  0.763644  0.926723  0.907656  0.409932  0.498378
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 68  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000  1.000000
# 69  0.000000  0.545484  0.635203  0.644829  1.000000  0.000000  1.000000
# 70  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000  0.000000
# 71  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          x29
# 0   0.549727
# 1   0.423410
# 2   0.085667
# 3   0.957767
# 4   0.629102
# ..       ...
# 67  0.000000
# 68  0.000000
# 69  1.000000
# 70  1.000000
# 71  0.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.900039  11.499759
# 1             1      1_0      RUNNING             Sobol  0.411412  13.215798
# 2             2      2_0      RUNNING             Sobol  0.161478  11.340038
# 3             3      3_0      RUNNING             Sobol  0.650087  13.650489
# 4             4      4_0      RUNNING             Sobol  0.576784  14.054017
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000  10.027150
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.501628  13.714418
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000   7.103448
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.861947  10.812782
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.980040  12.747250
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.900039  0.212195  0.114420  ...  0.717714  0.900830
# 1          True  0.411412  0.748347  0.843482  ...  0.052001  0.217696
# 2          True  0.161478  0.376399  0.331382  ...  0.944921  0.254122
# 3          True  0.650087  0.912513  0.618923  ...  0.293299  0.563112
# 4          True  0.576784  0.343667  0.897816  ...  0.549282  0.851251
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.000000  0.000000  0.313855  ...  0.543126  0.000000
# 68         True  0.501628  0.215015  0.542869  ...  0.482751  0.599977
# 69         True  0.000000  1.000000  0.000000  ...  0.000000  0.000000
# 70         True  0.861947  0.505395  0.433447  ...  0.092614  0.141249
# 71         True  0.980040  0.516334  0.690705  ...  0.939980  0.338733
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.068454  0.889866  0.547536  0.228951  0.883779  0.570235  0.452827
# 1   0.973383  0.018864  0.196289  0.975541  0.490342  0.275951  0.624822
# 2   0.327616  0.687338  0.880901  0.682452  0.552698  0.203040  0.239076
# 3   0.732285  0.284899  0.374663  0.428049  0.073334  0.893131  0.817081
# 4   0.437625  0.399723  0.422519  0.602149  0.717238  0.453095  0.313712
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.000000  0.507193  0.000000  0.314034  0.958795  0.501969  0.410250
# 68  0.436632  0.280198  0.015467  0.934761  0.960275  0.603257  0.115966
# 69  0.000000  0.000000  0.000000  0.000000  1.000000  1.000000  0.000000
# 70  0.869487  0.445992  0.607211  0.402933  0.042667  0.029688  0.845082
# 71  0.789355  0.038464  0.123590  0.174340  0.383315  0.914351  0.958689
#
#          x29
# 0   0.501147
# 1   0.448086
# 2   0.128433
# 3   0.820799
# 4   0.626404
# ..       ...
# 67  0.568535
# 68  0.416113
# 69  0.000000
# 70  0.746882
# 71  0.990810
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.841518  10.871116
# 1             1      1_0      RUNNING             Sobol  0.011896  12.564382
# 2             2      2_0      RUNNING             Sobol  0.431248  12.939992
# 3             3      3_0      RUNNING             Sobol  0.726565  12.119158
# 4             4      4_0      RUNNING             Sobol  0.526522  12.277175
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000  12.701110
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000  10.349643
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000   5.862069
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.000000   7.621069
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000  13.120218
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.841518  0.919760  0.861012  ...  0.779740  0.851105
# 1          True  0.011896  0.181869  0.084287  ...  0.406577  0.005305
# 2          True  0.431248  0.569084  0.583790  ...  0.587596  0.371640
# 3          True  0.726565  0.329420  0.361508  ...  0.226147  0.529701
# 4          True  0.526522  0.628047  0.232643  ...  0.883956  0.894063
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.000000  0.096537  0.542516  ...  0.617318  0.714538
# 68         True  0.000000  0.000000  0.601973  ...  0.000000  0.083398
# 69         True  0.000000  1.000000  0.000000  ...  0.000000  0.000000
# 70         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 71         True  0.000000  0.528699  0.617922  ...  0.718367  0.886503
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.377026  0.522722  0.862115  0.553596  0.543840  0.083974  0.747659
# 1   0.569987  0.061201  0.294612  0.480019  0.125400  0.576563  0.246639
# 2   0.248817  0.815471  0.745764  0.044802  0.914684  0.843783  0.889972
# 3   0.808045  0.354390  0.160925  0.984906  0.254083  0.370678  0.388916
# 4   0.080158  0.481673  0.079521  0.137686  0.872951  0.691604  0.566446
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.736758  0.723566  0.547159  0.887067  0.135003  0.935510  0.366058
# 68  0.432653  0.216819  0.055741  0.675610  0.054185  0.794424  0.185278
# 69  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 70  0.000000  1.000000  0.000000  0.000000  0.833945  1.000000  0.000000
# 71  0.597862  0.070732  0.053760  0.636417  0.767141  0.000000  0.713931
#
#          x29
# 0   0.270637
# 1   0.824761
# 2   0.506625
# 3   0.093168
# 4   0.410325
# ..       ...
# 67  0.849469
# 68  0.000000
# 69  0.000000
# 70  0.000000
# 71  0.294740
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.983332  10.936179
# 1             1      1_0      RUNNING             Sobol  0.260857  13.004843
# 2             2      2_0      RUNNING             Sobol  0.183796  13.492433
# 3             3      3_0      RUNNING             Sobol  0.587663  12.149961
# 4             4      4_0      RUNNING             Sobol  0.711255  10.365112
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000   8.095977
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000   8.850953
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000   8.738442
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.000000  10.325879
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000  11.381402
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.983332  0.018352  0.954299  ...  0.576233  0.063507
# 1          True  0.260857  0.726144  0.482334  ...  0.004193  0.920421
# 2          True  0.183796  0.436668  0.733809  ...  0.802200  0.716237
# 3          True  0.587663  0.822743  0.206730  ...  0.374210  0.299713
# 4          True  0.711255  0.289113  0.323928  ...  0.731859  0.146051
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.000000  0.000000  0.000000  ...  0.000000  1.000000
# 68         True  0.000000  0.000000  1.000000  ...  0.815424  0.000000
# 69         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 70         True  0.000000  0.000000  1.000000  ...  0.000000  0.000000
# 71         True  0.000000  0.449135  0.605215  ...  0.417066  0.523090
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.826106  0.991053  0.585974  0.624258  0.235121  0.000338  0.137224
# 1   0.124175  0.122879  0.113009  0.213220  0.607891  0.776156  0.822330
# 2   0.619593  0.641398  0.777684  0.355560  0.369055  0.746241  0.375643
# 3   0.321044  0.277160  0.304596  0.946763  0.975895  0.475306  0.568591
# 4   0.629381  0.428226  0.446021  0.484405  0.416212  0.973674  0.109125
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000
# 68  0.000000  0.000000  1.000000  0.000000  0.000000  1.000000  0.000000
# 69  1.000000  1.000000  0.000000  0.816669  0.000000  1.000000  0.690285
# 70  1.000000  0.000000  0.000000  0.597245  0.000000  0.000000  1.000000
# 71  0.130607  0.101098  0.431733  0.918230  0.304041  0.263171  0.159106
#
#          x29
# 0   0.632696
# 1   0.103462
# 2   0.468130
# 3   0.798149
# 4   0.524114
# ..       ...
# 67  0.000000
# 68  1.000000
# 69  0.226327
# 70  0.000000
# 71  0.466268
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.003658  14.719930
# 1             1      1_0      RUNNING             Sobol  0.671902  11.018411
# 2             2      2_0      RUNNING             Sobol  0.963265  12.319019
# 3             3      3_0      RUNNING             Sobol  0.353378  12.055032
# 4             4      4_0      RUNNING             Sobol  0.458896  13.805528
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000  12.007642
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000   7.642955
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000   6.482759
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.191555  11.810205
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000  10.104760
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.003658  0.825650  0.475846  ...  0.094111  0.961587
# 1          True  0.671902  0.046481  0.600015  ...  0.607565  0.191580
# 2          True  0.963265  0.733391  0.102008  ...  0.490628  0.336384
# 3          True  0.353378  0.386786  0.977885  ...  0.992297  0.567333
# 4          True  0.458896  0.507066  0.749823  ...  0.165074  0.776177
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.000000  0.527004  0.805103  ...  0.877562  0.000000
# 68         True  0.000000  0.000000  0.000000  ...  1.000000  0.000000
# 69         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 70         True  0.191555  0.779655  0.593402  ...  0.014620  0.180311
# 71         True  0.000000  0.000000  0.509670  ...  0.000000  0.000000
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.744407  0.030414  0.724877  0.222632  0.620619  0.267611  0.631268
# 1   0.121903  0.695948  0.421147  0.999272  0.120886  0.944397  0.425202
# 2   0.880503  0.395806  0.839754  0.573679  0.792524  0.618793  0.842561
# 3   0.253126  0.815232  0.018491  0.335733  0.292730  0.168687  0.105268
# 4   0.862165  0.908319  0.179359  0.642049  0.976083  0.779835  0.619199
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.855243  0.000000  1.000000  0.863396  0.315261  0.047071  0.449865
# 68  0.869205  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 69  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 70  0.707681  0.846317  0.220694  0.462055  0.810597  0.280187  0.319938
# 71  0.684118  0.414781  0.632119  1.000000  0.000000  0.537096  0.000000
#
#          x29
# 0   0.990628
# 1   0.010924
# 2   0.370237
# 3   0.631193
# 4   0.824266
# ..       ...
# 67  0.863517
# 68  0.000000
# 69  0.000000
# 70  0.274822
# 71  0.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method         a          b  \
# 0             0      0_0      RUNNING             Sobol  0.494784  14.238507
# 1             1      1_0      RUNNING             Sobol  0.842380  10.461936
# 2             2      2_0      RUNNING             Sobol  0.606109  11.761154
# 3             3      3_0      RUNNING             Sobol  0.195891  13.380704
# 4             4      4_0      RUNNING             Sobol  0.038628  12.076818
# ..          ...      ...          ...               ...       ...        ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  0.000000   7.724138
# 68           68     68_0      RUNNING  FullyBayesianMOO  0.000000   7.724138
# 69           69     69_0      RUNNING  FullyBayesianMOO  0.000000   5.862069
# 70           70     70_0      RUNNING  FullyBayesianMOO  0.000000   9.586207
# 71           71     71_0      RUNNING  FullyBayesianMOO  0.000000  10.504812
#
#     is_feasible        x0        x1        x2  ...       x20       x21  \
# 0          True  0.494784  0.905740  0.968397  ...  0.153277  0.104916
# 1          True  0.842380  0.102975  0.330992  ...  0.671039  0.555419
# 2          True  0.606109  0.723664  0.636117  ...  0.351118  0.812675
# 3          True  0.195891  0.268555  0.006037  ...  0.832379  0.269520
# 4          True  0.038628  0.508308  0.409056  ...  0.006197  0.140227
# ..          ...       ...       ...       ...  ...       ...       ...
# 67         True  0.000000  1.000000  0.000000  ...  0.000000  0.000000
# 68         True  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 69         True  0.000000  0.000000  0.000000  ...  0.000000  1.000000
# 70         True  0.000000  0.000000  0.000000  ...  0.000000  1.000000
# 71         True  0.000000  0.000000  1.000000  ...  0.000000  0.921603
#
#          x22       x23       x24       x25       x26       x27       x28  \
# 0   0.436085  0.308636  0.998132  0.725899  0.340076  0.480885  0.830481
# 1   0.605537  0.825851  0.209109  0.216229  0.725794  0.954935  0.019419
# 2   0.188888  0.115117  0.615246  0.478664  0.197359  0.520095  0.554498
# 3   0.769497  0.504157  0.341995  0.953247  0.860420  0.040181  0.365501
# 4   0.063933  0.721516  0.412210  0.267763  0.107662  0.759820  0.920755
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.000000  1.000000  0.000000  0.000000  1.000000  0.000000  0.000000
# 68  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000  0.000000
# 69  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 70  1.000000  0.000000  1.000000  0.000000  1.000000  0.000000  0.000000
# 71  0.456991  0.000000  0.000000  0.000000  1.000000  0.000000  0.000000
#
#          x29
# 0   0.462216
# 1   0.861452
# 2   0.636561
# 3   0.031959
# 4   0.280322
# ..       ...
# 67  0.000000
# 68  1.000000
# 69  0.000000
# 70  1.000000
# 71  0.000000
#
# [72 rows x 37 columns]]
