# %%
# !lscpu |grep 'Model name'
# !nvidia-smi
# !pip install ax-platform
# Out:
# Model name:                      Intel(R) Xeon(R) CPU @ 2.30GHz
# Mon Mar 20 18:09:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P0    26W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ax-platform
#   Downloading ax_platform-0.3.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=5.12.0 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (5.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from ax-platform) (3.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.2.2)
# Collecting typeguard==2.13.3
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting botorch==0.8.3
#   Downloading botorch-0.8.3-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.8/521.8 KB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.4.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from ax-platform) (7.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from ax-platform) (1.10.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (0.6.0)
# Collecting gpytorch==1.9.1
#   Downloading gpytorch-1.9.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 KB 23.4 MB/s eta 0:00:00
# Collecting pyro-ppl>=1.8.4
#   Downloading pyro_ppl-1.8.4-py3-none-any.whl (730 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.7/730.7 KB 33.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.9/dist-packages (from botorch==0.8.3->ax-platform) (1.13.1+cu116)
# Collecting linear-operator==0.3.0
#   Downloading linear_operator-0.3.0-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 KB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.12.0->ax-platform) (8.2.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.3.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (7.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (3.6.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->ax-platform) (2.1.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ax-platform) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->ax-platform) (3.1.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.1.12)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (63.4.3)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.2.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.6 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.4.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (3.3.0)
# Collecting pyro-api>=0.1.1
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.9/dist-packages (from pyro-ppl>=1.8.4->botorch==0.8.3->ax-platform) (4.65.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->ax-platform) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.12->botorch==0.8.3->ax-platform) (4.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->ax-platform) (0.8.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.16.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.6)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.17.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.2.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.3.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.7.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ax-platform) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->ax-platform) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.1.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.9/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.23.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.4)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.11.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.3.3)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (22.2.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.9/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.9/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.9/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.21)
# Installing collected packages: pyro-api, typeguard, jedi, pyro-ppl, linear-operator, gpytorch, botorch, ax-platform
# Successfully installed ax-platform-0.3.1 botorch-0.8.3 gpytorch-1.9.1 jedi-0.18.2 linear-operator-0.3.0 pyro-api-0.1.2 pyro-ppl-1.8.4 typeguard-2.13.3

# %%
import pandas as pd
from ax import *
import torch

import numpy as np
from matplotlib import pyplot as plt
from matplotlib.cm import ScalarMappable

from ax.service.utils.report_utils import exp_to_df
from ax.runners.synthetic import SyntheticRunner
from ax.metrics.noisy_function import GenericNoisyFunctionMetric

# Analysis utilities, including a method to evaluate hypervolumes
from ax.modelbridge.modelbridge_utils import observed_hypervolume

from botorch.test_functions.multi_objective import DTLZ5

# %%
tkwargs = {
    "dtype": torch.double, 
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
}

# %%
dim = 30
problem = DTLZ5(num_objectives=2, dim=dim, negate=False).to(**tkwargs)

param_names = [f"x{i}" for i in range(dim)]

def f1(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names] # Obtiene los parámetros a evaluar
        return float(problem(torch.tensor(x_sorted, **tkwargs).clamp(0., 1.))[0]) # Evalúa los parámetros en el primer objetivo
    
def f2(x) -> float:
        x_sorted = [x[p_name] for p_name in param_names]
        return float(problem(torch.tensor(x_sorted, **tkwargs).clamp(0., 1.))[1]) # Evalúa los parámetros en el segundo objetivo

metric_a = GenericNoisyFunctionMetric("a", f=f1, noise_sd=0.0, lower_is_better=True)
metric_b = GenericNoisyFunctionMetric("b", f=f2, noise_sd=0.0, lower_is_better=True)

# %%
search_space = SearchSpace(
    parameters=[
        RangeParameter(name=param_name, lower=0, upper=1, parameter_type=ParameterType.FLOAT)
        for param_name in param_names
        ]
)

mo = MultiObjective(
    objectives=[Objective(metric=metric_a), Objective(metric=metric_b)],
)

objective_thresholds = [
    ObjectiveThreshold(metric=metric, bound=val, relative=False)
    for metric, val in zip(mo.metrics, problem.ref_point)
]

optimization_config = MultiObjectiveOptimizationConfig(
    objective=mo,
    objective_thresholds=objective_thresholds,
)

# %%
N_INIT = 2 * (dim + 1)
N_BATCH = 10
BATCH_SIZE = 1

def build_experiment():
    experiment = Experiment(
        name="pareto_experiment",
        search_space=search_space,
        optimization_config=optimization_config,
        runner=SyntheticRunner(),
    )
    return experiment

def initialize_experiment(experiment):
    sobol = Models.SOBOL(search_space=experiment.search_space)

    for _ in range(N_INIT):
        experiment.new_trial(sobol.gen(1)).run()

    return experiment.fetch_data()

# %%
import time

executions = 10
execution_times = []
all_df = []
all_outcomes = []

for exec in range(executions):
  start_time = time.time()

  experiment = build_experiment()
  data = initialize_experiment(experiment)

  hv_list = []
  model = None
  for i in range(N_BATCH):   
      model = Models.FULLYBAYESIANMOO(
          experiment=experiment, 
          data=data,
          num_samples=16,
          warmup_steps=32,
          torch_device=tkwargs["device"],
      )
      generator_run = model.gen(BATCH_SIZE)
      trial = experiment.new_trial(generator_run=generator_run)
      trial.run()
      data = Data.from_multiple_data([data, trial.fetch_data()])
      
      exp_df = exp_to_df(experiment)
      outcomes = np.array(exp_df[['a', 'b']], dtype=np.double)
      try:
          hv = observed_hypervolume(modelbridge=model)
      except:
          hv = 0
          print("Failed to compute hv")
      hv_list.append(hv)
      print(f"Execution: {exec + 1}, Iteration: {i + 1}, HV: {hv}")

  execution_times.append(time.time() - start_time)

  all_df.append(exp_to_df(experiment).sort_values(by=["trial_index"]))
  all_outcomes.append(np.array(exp_to_df(experiment)[['a', 'b']], dtype=np.double))
# Out:
# Sample: 100%|██████████| 48/48 [00:23,  2.01it/s, step size=4.80e-01, acc. prob=0.200]
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=2.67e-01, acc. prob=0.697]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 1, HV: 92.44763067168896
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=1.17e-01, acc. prob=0.947]
# Sample: 100%|██████████| 48/48 [00:19,  2.42it/s, step size=3.12e-01, acc. prob=0.934]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 2, HV: 92.55317471940464
# Sample: 100%|██████████| 48/48 [00:19,  2.45it/s, step size=4.40e-01, acc. prob=0.401]
# Sample: 100%|██████████| 48/48 [00:19,  2.53it/s, step size=4.01e-01, acc. prob=0.705]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 3, HV: 92.72945222783163
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=1.24e-01, acc. prob=0.932]
# Sample: 100%|██████████| 48/48 [00:20,  2.35it/s, step size=2.55e-01, acc. prob=0.926]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 4, HV: 92.72945222783163
# Sample: 100%|██████████| 48/48 [00:20,  2.33it/s, step size=4.44e-01, acc. prob=0.535]
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=2.49e-01, acc. prob=0.895]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 5, HV: 92.72945222783163
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=1.87e-01, acc. prob=0.912]
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=2.08e-01, acc. prob=0.941]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 6, HV: 92.72945222783163
# Sample: 100%|██████████| 48/48 [00:17,  2.71it/s, step size=1.89e-01, acc. prob=0.687]
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=4.60e-01, acc. prob=0.526]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 7, HV: 92.72945222783163
# Sample: 100%|██████████| 48/48 [00:20,  2.35it/s, step size=2.72e-01, acc. prob=0.647]
# Sample: 100%|██████████| 48/48 [00:15,  3.09it/s, step size=7.69e-01, acc. prob=0.046]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 8, HV: 92.75458807831525
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=2.93e-01, acc. prob=0.604]
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=3.68e-01, acc. prob=0.584]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 9, HV: 92.75458807831525
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=3.25e-01, acc. prob=0.889]
# Sample: 100%|██████████| 48/48 [00:18,  2.66it/s, step size=2.95e-01, acc. prob=0.849]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 1, Iteration: 10, HV: 92.75458807831525
# Sample: 100%|██████████| 48/48 [00:18,  2.60it/s, step size=3.73e-01, acc. prob=0.818]
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=2.67e-01, acc. prob=0.694]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 1, HV: 93.8620850546059
# Sample: 100%|██████████| 48/48 [00:19,  2.47it/s, step size=2.80e-01, acc. prob=0.414]
# Sample: 100%|██████████| 48/48 [00:20,  2.34it/s, step size=3.30e-01, acc. prob=0.825]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 2, HV: 93.9906351881553
# Sample: 100%|██████████| 48/48 [00:18,  2.59it/s, step size=3.40e-01, acc. prob=0.710]
# Sample: 100%|██████████| 48/48 [00:18,  2.62it/s, step size=4.09e-01, acc. prob=0.640]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 3, HV: 94.00233433173952
# Sample: 100%|██████████| 48/48 [00:14,  3.34it/s, step size=5.20e-01, acc. prob=0.052]
# Sample: 100%|██████████| 48/48 [00:14,  3.37it/s, step size=4.54e-01, acc. prob=0.043]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 4, HV: 94.00233433173952
# Sample: 100%|██████████| 48/48 [00:18,  2.59it/s, step size=4.14e-01, acc. prob=0.695]
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=1.55e-01, acc. prob=0.892]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 5, HV: 94.00233433173952
# Sample: 100%|██████████| 48/48 [00:20,  2.35it/s, step size=4.10e-01, acc. prob=0.433]
# Sample: 100%|██████████| 48/48 [00:17,  2.67it/s, step size=3.13e-01, acc. prob=0.812]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 6, HV: 94.00233433173952
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=2.04e-01, acc. prob=0.919]
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=1.53e-01, acc. prob=0.925]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 7, HV: 94.00233433173952
# Sample: 100%|██████████| 48/48 [00:18,  2.62it/s, step size=1.22e-01, acc. prob=0.971]
# Sample: 100%|██████████| 48/48 [00:20,  2.38it/s, step size=1.59e-01, acc. prob=0.916]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 8, HV: 94.00233433173952
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=1.83e-01, acc. prob=0.976]
# Sample: 100%|██████████| 48/48 [00:19,  2.47it/s, step size=3.70e-01, acc. prob=0.482]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 9, HV: 94.00233433173952
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=2.94e-01, acc. prob=0.641]
# Sample: 100%|██████████| 48/48 [00:19,  2.42it/s, step size=1.52e-01, acc. prob=0.942]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 2, Iteration: 10, HV: 94.16281656797878
# Sample: 100%|██████████| 48/48 [00:18,  2.65it/s, step size=3.20e-01, acc. prob=0.732]
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=3.96e-01, acc. prob=0.575]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 1, HV: 92.98980639129131
# Sample: 100%|██████████| 48/48 [00:14,  3.39it/s, step size=5.02e-01, acc. prob=0.089]
# Sample: 100%|██████████| 48/48 [00:18,  2.59it/s, step size=4.82e-01, acc. prob=0.670]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 2, HV: 93.39129665822101
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=2.51e-01, acc. prob=0.586]
# Sample: 100%|██████████| 48/48 [00:11,  4.02it/s, step size=4.28e-01, acc. prob=0.055]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 3, HV: 93.43441564248644
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=5.13e-01, acc. prob=0.513]
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=3.09e-01, acc. prob=0.659]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 4, HV: 93.43441564248644
# Sample: 100%|██████████| 48/48 [00:12,  3.84it/s, step size=7.25e-01, acc. prob=0.056]
# Sample: 100%|██████████| 48/48 [00:19,  2.40it/s, step size=3.49e-01, acc. prob=0.686]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 5, HV: 93.46793143519652
# Sample: 100%|██████████| 48/48 [00:20,  2.36it/s, step size=2.76e-01, acc. prob=0.471]
# Sample: 100%|██████████| 48/48 [00:17,  2.81it/s, step size=4.19e-01, acc. prob=0.204]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 6, HV: 93.46793143519652
# Sample: 100%|██████████| 48/48 [00:19,  2.40it/s, step size=1.30e-01, acc. prob=0.781]
# Sample: 100%|██████████| 48/48 [00:19,  2.43it/s, step size=2.76e-01, acc. prob=0.766]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 7, HV: 93.46793143519652
# Sample: 100%|██████████| 48/48 [00:19,  2.47it/s, step size=3.52e-01, acc. prob=0.855]
# Sample: 100%|██████████| 48/48 [00:15,  3.19it/s, step size=5.98e-01, acc. prob=0.135]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 8, HV: 93.46793143519652
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=3.46e-01, acc. prob=0.565]
# Sample: 100%|██████████| 48/48 [00:15,  3.13it/s, step size=3.92e-01, acc. prob=0.080]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 9, HV: 93.46793143519652
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=2.56e-01, acc. prob=0.862]
# Sample: 100%|██████████| 48/48 [00:20,  2.40it/s, step size=2.58e-01, acc. prob=0.878]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 3, Iteration: 10, HV: 93.46793143519652
# Sample: 100%|██████████| 48/48 [00:16,  2.94it/s, step size=3.76e-01, acc. prob=0.255]
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=3.02e-01, acc. prob=0.811]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 1, HV: 92.70122269000424
# Sample: 100%|██████████| 48/48 [00:20,  2.35it/s, step size=7.48e-02, acc. prob=0.957]
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=3.00e-01, acc. prob=0.894]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 2, HV: 92.82034703436359
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=2.00e-01, acc. prob=0.905]
# Sample: 100%|██████████| 48/48 [00:14,  3.41it/s, step size=5.86e-01, acc. prob=0.069]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 3, HV: 92.88485368166415
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=4.11e-01, acc. prob=0.696]
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=5.71e-01, acc. prob=0.205]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 4, HV: 92.88485368166415
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=2.34e-01, acc. prob=0.740]
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=2.72e-01, acc. prob=0.779]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 5, HV: 92.88485368166415
# Sample: 100%|██████████| 48/48 [00:19,  2.42it/s, step size=1.35e-01, acc. prob=0.941]
# Sample: 100%|██████████| 48/48 [00:19,  2.40it/s, step size=1.34e-01, acc. prob=0.921]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 6, HV: 92.88485368166415
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=2.47e-01, acc. prob=0.612]
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=2.83e-01, acc. prob=0.486]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 7, HV: 92.88485368166415
# Sample: 100%|██████████| 48/48 [00:19,  2.43it/s, step size=1.76e-01, acc. prob=0.887]
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=2.99e-01, acc. prob=0.805]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 8, HV: 92.88485368166415
# Sample: 100%|██████████| 48/48 [00:15,  3.05it/s, step size=4.98e-01, acc. prob=0.057]
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=3.07e-01, acc. prob=0.906]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 9, HV: 92.88511633481605
# Sample: 100%|██████████| 48/48 [00:19,  2.45it/s, step size=3.08e-01, acc. prob=0.850]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=1.84e-01, acc. prob=0.902]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 4, Iteration: 10, HV: 92.93481294862575
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=4.02e-01, acc. prob=0.646]
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=3.01e-01, acc. prob=0.885]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 1, HV: 92.70411285551718
# Sample: 100%|██████████| 48/48 [00:17,  2.72it/s, step size=4.41e-01, acc. prob=0.584]
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=3.01e-01, acc. prob=0.409]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 2, HV: 92.73301287642506
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=2.89e-01, acc. prob=0.847]
# Sample: 100%|██████████| 48/48 [00:17,  2.76it/s, step size=2.01e-01, acc. prob=0.068]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 3, HV: 92.74003094103468
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=3.52e-01, acc. prob=0.905]
# Sample: 100%|██████████| 48/48 [00:19,  2.47it/s, step size=3.22e-01, acc. prob=0.850]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 4, HV: 92.78189573195354
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=1.70e-01, acc. prob=0.922]
# Sample: 100%|██████████| 48/48 [00:20,  2.36it/s, step size=1.09e-01, acc. prob=0.974]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 5, HV: 92.78189573195354
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=2.29e-01, acc. prob=0.738]
# Sample: 100%|██████████| 48/48 [00:20,  2.34it/s, step size=1.58e-01, acc. prob=0.903]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 6, HV: 92.79718020654605
# Sample: 100%|██████████| 48/48 [00:19,  2.45it/s, step size=5.75e-01, acc. prob=0.493]
# Sample: 100%|██████████| 48/48 [00:19,  2.47it/s, step size=2.40e-01, acc. prob=0.884]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 7, HV: 92.79718020654605
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=6.32e-01, acc. prob=0.236]
# Sample: 100%|██████████| 48/48 [00:19,  2.42it/s, step size=4.54e-01, acc. prob=0.581]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 8, HV: 92.79718020654605
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=4.87e-01, acc. prob=0.730]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=1.61e-01, acc. prob=0.680]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 9, HV: 92.79718020654605
# Sample: 100%|██████████| 48/48 [00:18,  2.55it/s, step size=2.00e-01, acc. prob=0.959]
# Sample: 100%|██████████| 48/48 [00:14,  3.21it/s, step size=2.25e-01, acc. prob=0.127]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 5, Iteration: 10, HV: 92.79718020654605
# Sample: 100%|██████████| 48/48 [00:17,  2.70it/s, step size=1.71e-01, acc. prob=0.768]
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=2.45e-01, acc. prob=0.904]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 1, HV: 92.94265106779436
# Sample: 100%|██████████| 48/48 [00:18,  2.60it/s, step size=3.59e-01, acc. prob=0.753]
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=4.78e-01, acc. prob=0.236]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 2, HV: 92.95451893284567
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=3.09e-01, acc. prob=0.804]
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=2.70e-01, acc. prob=0.920]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 3, HV: 93.11035046475111
# Sample: 100%|██████████| 48/48 [00:18,  2.65it/s, step size=3.98e-01, acc. prob=0.329]
# Sample: 100%|██████████| 48/48 [00:20,  2.35it/s, step size=3.58e-01, acc. prob=0.720]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 4, HV: 93.11175322358831
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=4.60e-01, acc. prob=0.539]
# Sample: 100%|██████████| 48/48 [00:14,  3.40it/s, step size=5.83e-01, acc. prob=0.068]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 5, HV: 93.11175322358831
# Sample: 100%|██████████| 48/48 [00:19,  2.45it/s, step size=1.85e-01, acc. prob=0.918]
# Sample: 100%|██████████| 48/48 [00:14,  3.20it/s, step size=3.14e-01, acc. prob=0.052]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 6, HV: 93.11175322358831
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=2.50e-01, acc. prob=0.818]
# Sample: 100%|██████████| 48/48 [00:19,  2.42it/s, step size=1.99e-01, acc. prob=0.405]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 7, HV: 93.11175322358831
# Sample: 100%|██████████| 48/48 [00:20,  2.37it/s, step size=2.41e-01, acc. prob=0.878]
# Sample: 100%|██████████| 48/48 [00:18,  2.58it/s, step size=1.49e-01, acc. prob=0.920]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 8, HV: 93.11327343095937
# Sample: 100%|██████████| 48/48 [00:19,  2.42it/s, step size=3.94e-01, acc. prob=0.364]
# Sample: 100%|██████████| 48/48 [00:20,  2.32it/s, step size=3.85e-01, acc. prob=0.316]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 9, HV: 93.11327343095937
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=1.58e-01, acc. prob=0.831]
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=4.39e-01, acc. prob=0.331]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 6, Iteration: 10, HV: 93.11327343095937
# Sample: 100%|██████████| 48/48 [00:18,  2.63it/s, step size=4.50e-01, acc. prob=0.724]
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=3.78e-01, acc. prob=0.617]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 1, HV: 92.44028669094313
# Sample: 100%|██████████| 48/48 [00:18,  2.55it/s, step size=1.99e-01, acc. prob=0.811]
# Sample: 100%|██████████| 48/48 [00:13,  3.64it/s, step size=5.49e-01, acc. prob=0.089]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 2, HV: 92.56189738785507
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=4.35e-01, acc. prob=0.666]
# Sample: 100%|██████████| 48/48 [00:17,  2.69it/s, step size=2.99e-01, acc. prob=0.848]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 3, HV: 92.57133009862096
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=4.24e-01, acc. prob=0.360]
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=1.56e-01, acc. prob=0.693]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 4, HV: 92.69528809587268
# Sample: 100%|██████████| 48/48 [00:18,  2.62it/s, step size=4.81e-01, acc. prob=0.216]
# Sample: 100%|██████████| 48/48 [00:20,  2.38it/s, step size=2.39e-01, acc. prob=0.961]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 5, HV: 92.70690356546967
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=4.95e-01, acc. prob=0.234]
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=4.73e-01, acc. prob=0.300]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 6, HV: 92.70690356546967
# Sample: 100%|██████████| 48/48 [00:20,  2.37it/s, step size=3.96e-01, acc. prob=0.816]
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=3.73e-01, acc. prob=0.346]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 7, Iteration: 7, HV: 92.70690356546967
# ...
#   warnings.warn(
# Execution: 8, Iteration: 8, HV: 93.78501248550046
# Sample: 100%|██████████| 48/48 [00:15,  3.20it/s, step size=1.01e-01, acc. prob=0.307]
# Sample: 100%|██████████| 48/48 [00:20,  2.38it/s, step size=4.23e-01, acc. prob=0.432]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 9, HV: 93.78501248550046
# Sample: 100%|██████████| 48/48 [00:18,  2.57it/s, step size=3.86e-01, acc. prob=0.242]
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=3.95e-01, acc. prob=0.850]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 8, Iteration: 10, HV: 93.78501248550046
# Sample: 100%|██████████| 48/48 [00:17,  2.73it/s, step size=4.39e-01, acc. prob=0.264]
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=1.65e-01, acc. prob=0.938]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 1, HV: 93.46938915968697
# Sample: 100%|██████████| 48/48 [00:16,  2.87it/s, step size=3.95e-01, acc. prob=0.069]
# Sample: 100%|██████████| 48/48 [00:14,  3.43it/s, step size=3.07e-01, acc. prob=0.127]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 2, HV: 93.46938915968697
# Sample: 100%|██████████| 48/48 [00:19,  2.52it/s, step size=3.49e-01, acc. prob=0.289]
# Sample: 100%|██████████| 48/48 [00:18,  2.60it/s, step size=1.76e-01, acc. prob=0.933]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 3, HV: 93.71171036571609
# Sample: 100%|██████████| 48/48 [00:20,  2.39it/s, step size=3.83e-01, acc. prob=0.767]
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=1.17e-01, acc. prob=0.804]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 4, HV: 93.80783516589874
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=2.98e-01, acc. prob=0.798]
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=2.34e-01, acc. prob=0.925]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 5, HV: 93.89386420429037
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=3.33e-01, acc. prob=0.425]
# Sample: 100%|██████████| 48/48 [00:19,  2.51it/s, step size=2.53e-01, acc. prob=0.503]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 6, HV: 93.89386420429037
# Sample: 100%|██████████| 48/48 [00:19,  2.43it/s, step size=4.03e-01, acc. prob=0.839]
# Sample: 100%|██████████| 48/48 [00:19,  2.47it/s, step size=1.53e-01, acc. prob=0.903]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 7, HV: 93.89386420429037
# Sample: 100%|██████████| 48/48 [00:19,  2.43it/s, step size=3.56e-01, acc. prob=0.744]
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=2.85e-01, acc. prob=0.841]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 8, HV: 93.89386420429037
# Sample: 100%|██████████| 48/48 [00:19,  2.49it/s, step size=3.04e-01, acc. prob=0.857]
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=1.13e-01, acc. prob=0.953]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 9, HV: 93.89386420429037
# Sample: 100%|██████████| 48/48 [00:19,  2.44it/s, step size=3.36e-01, acc. prob=0.810]
# Sample: 100%|██████████| 48/48 [00:18,  2.54it/s, step size=1.98e-01, acc. prob=0.910]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 9, Iteration: 10, HV: 93.89386420429037
# Sample: 100%|██████████| 48/48 [00:18,  2.59it/s, step size=5.90e-01, acc. prob=0.541]
# Sample: 100%|██████████| 48/48 [00:18,  2.61it/s, step size=3.17e-01, acc. prob=0.845]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 1, HV: 91.63136495303496
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=2.11e-01, acc. prob=0.815]
# Sample: 100%|██████████| 48/48 [00:17,  2.75it/s, step size=4.59e-01, acc. prob=0.386]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 2, HV: 91.80336003536115
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=1.19e-01, acc. prob=0.930]
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=3.99e-01, acc. prob=0.585]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 3, HV: 91.97586518550872
# Sample: 100%|██████████| 48/48 [00:19,  2.41it/s, step size=1.18e-01, acc. prob=0.962]
# Sample: 100%|██████████| 48/48 [00:19,  2.53it/s, step size=1.63e-01, acc. prob=0.854]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 4, HV: 92.03803621659867
# Sample: 100%|██████████| 48/48 [00:18,  2.56it/s, step size=1.71e-01, acc. prob=0.954]
# Sample: 100%|██████████| 48/48 [00:19,  2.45it/s, step size=3.45e-01, acc. prob=0.515]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 5, HV: 92.06604406313807
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=4.19e-01, acc. prob=0.564]
# Sample: 100%|██████████| 48/48 [00:20,  2.35it/s, step size=2.94e-01, acc. prob=0.811]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 6, HV: 92.06604406313807
# Sample: 100%|██████████| 48/48 [00:19,  2.46it/s, step size=1.86e-01, acc. prob=0.588]
# Sample: 100%|██████████| 48/48 [00:19,  2.42it/s, step size=1.06e-01, acc. prob=0.934]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 7, HV: 92.06604406313807
# Sample: 100%|██████████| 48/48 [00:20,  2.33it/s, step size=3.21e-01, acc. prob=0.689]
# Sample: 100%|██████████| 48/48 [00:18,  2.64it/s, step size=1.46e-01, acc. prob=0.949]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 8, HV: 92.06604406313807
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=4.37e-01, acc. prob=0.502]
# Sample: 100%|██████████| 48/48 [00:20,  2.37it/s, step size=3.73e-01, acc. prob=0.706]
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(
# Execution: 10, Iteration: 9, HV: 92.06604406313807
# Sample: 100%|██████████| 48/48 [00:18,  2.53it/s, step size=2.61e-01, acc. prob=0.812]
# Sample: 100%|██████████| 48/48 [00:19,  2.50it/s, step size=3.84e-01, acc. prob=0.593]
# Execution: 10, Iteration: 10, HV: 92.06604406313807
# /usr/local/lib/python3.9/dist-packages/ax/modelbridge/modelbridge_utils.py:852: UserWarning: FYI: The default behavior of `get_pareto_frontier_and_configs` when `transform_outcomes_and_configs` is not specified has changed. Previously, the default was `transform_outcomes_and_configs=True`; now this argument is deprecated and behavior is as if `transform_outcomes_and_configs=False`. You did not specify `transform_outcomes_and_configs`, so this warning requires no action.
#   warnings.warn(

# %%
from torch import Tensor
# %matplotlib inline

for exec in range(executions):
  fig, axes = plt.subplots(1, 1, figsize=(8,6))

  cm = plt.cm.get_cmap('viridis')
  batch_number = all_df[exec].trial_index.values
  sc = axes.scatter(all_outcomes[exec][:, 0], all_outcomes[exec][:,1], c=batch_number, alpha=0.8)
  axes.set_title(f'DTLZ5 Execution #{exec + 1}')
  axes.set_xlabel("Objective 1")
  axes.set_ylabel("Objective 2")
  norm = plt.Normalize(batch_number.min(), batch_number.max())
  sm =  ScalarMappable(norm=norm, cmap=cm)
  fig.subplots_adjust(right=0.9)
  cbar_ax = fig.add_axes([0.93, 0.15, 0.01, 0.7])
  cbar = fig.colorbar(sm, cax=cbar_ax)
  cbar.ax.set_title("Trial")
# Out:
# <ipython-input-10-f8789cb13dba>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %%
# %matplotlib inline
fig, axes = plt.subplots(1, 1)
plt.xticks(np.arange(1, executions + 1))

axes.scatter(np.arange(1, executions + 1), np.array(execution_times))
axes.grid(True)
axes.set_xlabel("Execution")
axes.set_ylabel("Time")

print("Execution times:", np.array(execution_times))
print("Average execution time:", np.array(execution_times).sum()/len(execution_times))
# Out:
# Execution times: [470.00317574 473.75645542 453.2010684  461.43413544 487.79896641
#  456.5258317  486.74456167 469.69348001 452.89633536 500.6090703 ]
# Average execution time: 471.2663080453873

# %%
print(all_df)
# Out:
# [    trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  3.790251e-01
# 1             1      1_0      RUNNING             Sobol  3.561760e+00
# 2             2      2_0      RUNNING             Sobol  2.254784e+00
# 3             3      3_0      RUNNING             Sobol  2.422946e+00
# 4             4      4_0      RUNNING             Sobol  1.208040e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  6.959298e+00
# 68           68     68_0      RUNNING  FullyBayesianMOO  6.516911e+00
# 69           69     69_0      RUNNING  FullyBayesianMOO  4.165332e-16
# 70           70     70_0      RUNNING  FullyBayesianMOO  4.406008e-16
# 71           71     71_0      RUNNING  FullyBayesianMOO  7.383553e+00
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   3.474631         True  0.930829  0.055503  0.452521  ...  0.877149
# 1   0.916926         True  0.160406  0.912019  0.622770  ...  0.178136
# 2   1.202545         True  0.311915  0.274809  0.231066  ...  0.644383
# 3   2.690269         True  0.533253  0.629253  0.842081  ...  0.413586
# 4   2.782604         True  0.739249  0.478638  0.729589  ...  0.787910
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  0.344779         True  0.031514  0.000000  0.000000  ...  0.000000
# 68  0.000000         True  0.000000  0.000000  1.000000  ...  0.431466
# 69  6.802504         True  1.000000  1.000000  0.464080  ...  1.000000
# 70  7.195557         True  1.000000  1.000000  0.000000  ...  1.000000
# 71  0.000000         True  0.000000  0.825754  1.000000  ...  1.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.172849  0.057336  0.852079  0.223066  0.813018  0.297530  0.216808
# 1   0.560413  0.521209  0.409495  0.990006  0.240328  0.698092  0.618351
# 2   0.971290  0.498115  0.747903  0.396479  0.269116  0.209949  0.770505
# 3   0.359109  0.954164  0.052795  0.629219  0.661179  0.793517  0.425586
# 4   0.011954  0.347740  0.189697  0.604822  0.434154  0.023052  0.734163
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  1.000000  0.240078  0.000000  0.000000  0.000000  0.042540  0.853818
# 68  1.000000  0.000000  1.000000  0.000000  0.027957  1.000000  1.000000
# 69  1.000000  0.000000  0.231738  1.000000  0.000000  0.000000  1.000000
# 70  1.000000  1.000000  1.000000  0.227125  0.376979  1.000000  1.000000
# 71  0.000000  0.000000  1.000000  0.000000  1.000000  0.000000  0.416173
#
#          x28       x29
# 0   0.190939  0.816144
# 1   0.888538  0.024621
# 2   0.334666  0.401038
# 3   0.524334  0.687640
# 4   0.053330  0.891002
# ..       ...       ...
# 67  1.000000  0.361588
# 68  0.000000  1.000000
# 69  0.000000  0.391418
# 70  0.000000  1.000000
# 71  1.000000  0.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  7.466375e-01
# 1             1      1_0      RUNNING             Sobol  3.722591e+00
# 2             2      2_0      RUNNING             Sobol  2.771726e+00
# 3             3      3_0      RUNNING             Sobol  2.071314e+00
# 4             4      4_0      RUNNING             Sobol  1.449234e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  6.359794e+00
# 68           68     68_0      RUNNING  FullyBayesianMOO  5.696642e+00
# 69           69     69_0      RUNNING  FullyBayesianMOO  5.736117e+00
# 70           70     70_0      RUNNING  FullyBayesianMOO  2.302527e-16
# 71           71     71_0      RUNNING  FullyBayesianMOO  2.959550e-16
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   3.247116         True  0.856117  0.903786  0.459180  ...  0.646883
# 1   1.803673         True  0.287235  0.109222  0.537559  ...  0.332252
# 2   0.106185         True  0.024377  0.522305  0.079111  ...  0.954805
# 3   2.675125         True  0.580554  0.473125  0.907489  ...  0.019447
# 4   3.161291         True  0.726353  0.699195  0.633890  ...  0.540061
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  0.000000         True  0.000000  0.000000  0.041445  ...  1.000000
# 68  0.000000         True  0.000000  0.000000  0.000000  ...  0.766397
# 69  0.384937         True  0.042658  0.248456  0.269040  ...  1.000000
# 70  3.760312         True  1.000000  0.469418  0.219680  ...  0.000000
# 71  4.833312         True  1.000000  0.010417  0.780466  ...  0.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.309506  0.085386  0.239100  0.220054  0.766103  0.213414  0.681103
# 1   0.942238  0.918232  0.821811  0.723252  0.199132  0.601182  0.020013
# 2   0.632090  0.425235  0.374531  0.418730  0.452090  0.349687  0.473151
# 3   0.124480  0.570661  0.690290  0.915093  0.520892  0.963871  0.821827
# 4   0.433952  0.295260  0.585617  0.798519  0.272029  0.476173  0.140917
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  1.000000  0.000000  0.000000  0.000000  0.486646  0.000000  1.000000
# 68  1.000000  0.000000  1.000000  0.000000  1.000000  0.782833  0.788968
# 69  0.140773  0.720526  1.000000  0.000000  0.072903  0.281105  0.000000
# 70  0.000000  0.504902  0.380286  0.482058  0.000000  1.000000  0.475529
# 71  0.422997  0.137257  1.000000  0.000000  0.853967  0.683114  0.000000
#
#          x28       x29
# 0   0.227634  0.104983
# 1   0.833244  0.500502
# 2   0.384898  0.921990
# 3   0.552763  0.463978
# 4   0.022377  0.212304
# ..       ...       ...
# 67  0.307924  0.938274
# 68  0.616471  0.439710
# 69  0.059479  1.000000
# 70  0.202425  0.482021
# 71  0.842017  0.986881
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  3.279294e+00
# 1             1      1_0      RUNNING             Sobol  1.231686e+00
# 2             2      2_0      RUNNING             Sobol  2.122186e+00
# 3             3      3_0      RUNNING             Sobol  3.383198e+00
# 4             4      4_0      RUNNING             Sobol  3.201543e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  3.138203e-02
# 68           68     68_0      RUNNING  FullyBayesianMOO  4.088674e-16
# 69           69     69_0      RUNNING  FullyBayesianMOO  7.164856e+00
# 70           70     70_0      RUNNING  FullyBayesianMOO  6.178228e+00
# 71           71     71_0      RUNNING  FullyBayesianMOO  3.445335e-01
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   1.697472         True  0.304084  0.331173  0.553013  ...  0.308259
# 1   3.037706         True  0.754768  0.608140  0.465373  ...  0.833299
# 2   2.872527         True  0.594928  0.197292  0.962308  ...  0.218918
# 3   0.431540         True  0.080767  0.991844  0.050433  ...  0.639435
# 4   0.834387         True  0.162306  0.015421  0.330180  ...  0.470248
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  6.125385         True  0.996738  0.863125  0.000000  ...  0.968602
# 68  6.677311         True  1.000000  1.000000  0.598673  ...  0.194543
# 69  0.000000         True  0.000000  0.125154  0.000000  ...  0.860332
# 70  0.000000         True  0.000000  0.000000  0.495990  ...  0.000000
# 71  7.584598         True  0.971101  1.000000  0.000000  ...  1.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.546189  0.091649  0.988099  0.444422  0.079065  0.304558  0.093981
# 1   0.149886  0.717816  0.078720  0.654743  0.838084  0.613812  0.748541
# 2   0.403141  0.470831  0.722941  0.086234  0.522050  0.182781  0.925156
# 3   0.791897  0.844679  0.319362  0.751155  0.277651  0.992675  0.294804
# 4   0.705162  0.372212  0.387217  0.962246  0.717967  0.026613  0.540189
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.607384  1.000000  1.000000  0.000000  1.000000  0.587681  0.460018
# 68  1.000000  1.000000  0.000000  0.923936  1.000000  0.124384  0.432271
# 69  0.000000  1.000000  0.075308  0.229815  1.000000  1.000000  0.000000
# 70  0.486086  0.463023  0.000000  1.000000  0.000000  1.000000  1.000000
# 71  1.000000  0.238183  0.178518  1.000000  0.000000  0.989373  1.000000
#
#          x28       x29
# 0   0.608890  0.577013
# 1   0.222856  0.452192
# 2   0.930084  0.239405
# 3   0.300611  0.864202
# 4   0.643604  0.708356
# ..       ...       ...
# 67  1.000000  0.655234
# 68  1.000000  1.000000
# 69  0.166941  1.000000
# 70  0.000000  1.000000
# 71  1.000000  1.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  3.014587e-01
# 1             1      1_0      RUNNING             Sobol  3.470381e+00
# 2             2      2_0      RUNNING             Sobol  2.581084e+00
# 3             3      3_0      RUNNING             Sobol  2.387744e+00
# 4             4      4_0      RUNNING             Sobol  1.641516e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  7.030535e+00
# 68           68     68_0      RUNNING  FullyBayesianMOO  4.942156e-16
# 69           69     69_0      RUNNING  FullyBayesianMOO  4.788192e-16
# 70           70     70_0      RUNNING  FullyBayesianMOO  3.763832e-16
# 71           71     71_0      RUNNING  FullyBayesianMOO  6.938596e+00
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   3.957853         True  0.951604  0.702235  0.967763  ...  0.557614
# 1   0.659244         True  0.119510  0.034042  0.390731  ...  0.231497
# 2   1.957571         True  0.413086  0.962447  0.685377  ...  0.813061
# 3   2.531687         True  0.518622  0.301051  0.237509  ...  0.397831
# 4   2.654853         True  0.647458  0.829091  0.277944  ...  0.672768
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  0.000000         True  0.000000  0.000000  1.000000  ...  0.488727
# 68  8.071154         True  1.000000  0.000000  1.000000  ...  1.000000
# 69  7.819711         True  1.000000  0.000000  1.000000  ...  1.000000
# 70  6.146804         True  1.000000  0.011300  0.489998  ...  1.000000
# 71  0.000000         True  0.000000  0.839750  0.000000  ...  0.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.805411  0.141137  0.795510  0.239712  0.432761  0.080488  0.732374
# 1   0.451138  0.827459  0.256939  0.856165  0.617424  0.846961  0.323529
# 2   0.182183  0.480955  0.691341  0.476686  0.942832  0.497250  0.201139
# 3   0.577898  0.550446  0.228937  0.611213  0.006278  0.699271  0.854797
# 4   0.941007  0.259103  0.051427  0.640469  0.798636  0.331626  0.439120
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.000000  0.000000  0.000000  0.000000  0.483654  0.000000  0.000000
# 68  0.000000  1.000000  1.000000  1.000000  1.000000  0.000000  1.000000
# 69  1.000000  0.459089  0.000000  1.000000  1.000000  0.000000  0.000000
# 70  0.130454  0.550999  1.000000  1.000000  1.000000  0.000000  0.628288
# 71  1.000000  0.000000  0.000000  1.000000  0.000000  0.000000  0.471295
#
#          x28       x29
# 0   0.490451  0.988906
# 1   0.723516  0.474969
# 2   0.218860  0.177937
# 3   0.987080  0.660921
# 4   0.296731  0.774697
# ..       ...       ...
# 67  0.000000  0.000000
# 68  0.000000  1.000000
# 69  0.239161  1.000000
# 70  0.000000  0.699299
# 71  0.410895  0.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  1.294521e+00
# 1             1      1_0      RUNNING             Sobol  2.666448e+00
# 2             2      2_0      RUNNING             Sobol  3.279625e+00
# 3             3      3_0      RUNNING             Sobol  6.826643e-03
# 4             4      4_0      RUNNING             Sobol  9.137273e-01
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  4.770096e-16
# 68           68     68_0      RUNNING  FullyBayesianMOO  4.746204e-16
# 69           69     69_0      RUNNING  FullyBayesianMOO  1.175711e+00
# 70           70     70_0      RUNNING  FullyBayesianMOO  4.706743e-16
# 71           71     71_0      RUNNING  FullyBayesianMOO  4.454068e-16
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   2.951498         True  0.736865  0.762984  0.407478  ...  0.386950
# 1   2.469340         True  0.475579  0.405828  0.505165  ...  0.501279
# 2   1.235199         True  0.229309  0.559267  0.011443  ...  0.206606
# 3   3.531984         True  0.998770  0.170327  0.921629  ...  0.842664
# 4   3.520294         True  0.838327  0.740674  0.695357  ...  0.370805
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  7.790158         True  1.000000  1.000000  0.000000  ...  0.888624
# 68  7.751139         True  1.000000  1.000000  1.000000  ...  1.000000
# 69  7.567993         True  0.901883  0.000000  1.000000  ...  0.000000
# 70  7.686694         True  1.000000  1.000000  1.000000  ...  0.000000
# 71  7.274046         True  1.000000  1.000000  0.000000  ...  1.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.271499  0.389064  0.070252  0.367972  0.624994  0.840949  0.250458
# 1   0.710636  0.937062  0.710575  0.970225  0.289600  0.064641  0.531478
# 2   0.794685  0.137493  0.379142  0.091334  0.104430  0.712215  0.977385
# 3   0.230908  0.684695  0.769945  0.692177  0.810169  0.443718  0.195906
# 4   0.439205  0.055292  0.926379  0.527141  0.220755  0.543754  0.648457
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  1.000000  1.000000  1.000000  1.000000  0.000000  0.118287  0.000000
# 68  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 69  1.000000  1.000000  0.000000  1.000000  1.000000  0.000000  0.000000
# 70  0.000000  1.000000  1.000000  1.000000  0.329613  0.103057  1.000000
# 71  0.000000  1.000000  0.000000  1.000000  1.000000  0.000000  0.000000
#
#          x28       x29
# 0   0.016142  0.084113
# 1   0.863665  0.836846
# 2   0.484418  0.698135
# 3   0.645418  0.441574
# 4   0.146126  0.151399
# ..       ...       ...
# 67  0.837099  1.000000
# 68  0.000000  0.000000
# 69  0.000000  0.000000
# 70  1.000000  0.000000
# 71  0.191153  0.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  2.816704e+00
# 1             1      1_0      RUNNING             Sobol  3.579608e-01
# 2             2      2_0      RUNNING             Sobol  1.837177e+00
# 3             3      3_0      RUNNING             Sobol  3.430013e+00
# 4             4      4_0      RUNNING             Sobol  3.235943e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  7.465584e+00
# 68           68     68_0      RUNNING  FullyBayesianMOO  3.900282e-16
# 69           69     69_0      RUNNING  FullyBayesianMOO  3.927550e-16
# 70           70     70_0      RUNNING  FullyBayesianMOO  4.936459e-16
# 71           71     71_0      RUNNING  FullyBayesianMOO  4.562899e-16
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   1.496059         True  0.310827  0.246033  0.540629  ...  0.056149
# 1   3.052633         True  0.925687  0.749359  0.261715  ...  0.685359
# 2   3.362017         True  0.681617  0.475277  0.853647  ...  0.473523
# 3   0.275984         True  0.051113  0.970730  0.070580  ...  0.844066
# 4   1.062337         True  0.201940  0.326162  0.452424  ...  0.165034
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  0.000000         True  0.000000  0.000000  1.000000  ...  0.000000
# 68  6.369644         True  1.000000  1.000000  0.656168  ...  0.000000
# 69  6.414175         True  1.000000  0.000000  1.000000  ...  0.000000
# 70  8.061849         True  1.000000  0.000000  1.000000  ...  0.251305
# 71  7.451779         True  1.000000  0.000000  1.000000  ...  0.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.119529  0.787222  0.105040  0.964047  0.660110  0.281864  0.694179
# 1   0.924184  0.046278  0.545329  0.167937  0.432796  0.697904  0.392525
# 2   0.581657  0.690828  0.372106  0.606525  0.018515  0.170758  0.036925
# 3   0.401998  0.447352  0.805589  0.279100  0.759919  0.817249  0.862225
# 4   0.132469  0.564040  0.941499  0.470587  0.130890  0.036295  0.272075
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  1.000000  0.000000  1.000000  1.000000  0.000000  1.000000  0.817623
# 68  0.395648  1.000000  1.000000  1.000000  0.000000  1.000000  1.000000
# 69  0.520853  0.128624  0.524616  1.000000  0.000000  1.000000  0.000000
# 70  1.000000  0.000000  0.000000  1.000000  1.000000  0.000000  0.000000
# 71  1.000000  0.809466  0.080189  1.000000  0.000000  1.000000  0.000000
#
#          x28       x29
# 0   0.459841  0.308598
# 1   0.903096  0.930884
# 2   0.149553  0.582947
# 3   0.706061  0.204867
# 4   0.339979  0.418053
# ..       ...       ...
# 67  1.000000  1.000000
# 68  0.263530  1.000000
# 69  1.000000  0.000000
# 70  1.000000  1.000000
# 71  0.731883  0.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  8.309914e-01
# 1             1      1_0      RUNNING             Sobol  2.140104e+00
# 2             2      2_0      RUNNING             Sobol  3.861105e+00
# 3             3      3_0      RUNNING             Sobol  1.582897e+00
# 4             4      4_0      RUNNING             Sobol  2.415974e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  4.523203e-16
# 68           68     68_0      RUNNING  FullyBayesianMOO  4.603059e-16
# 69           69     69_0      RUNNING  FullyBayesianMOO  7.788010e-01
# 70           70     70_0      RUNNING  FullyBayesianMOO  4.659044e-16
# 71           71     71_0      RUNNING  FullyBayesianMOO  7.288846e+00
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   3.172334         True  0.836902  0.816869  0.249410  ...  0.696050
# 1   1.967944         True  0.473336  0.489867  0.763722  ...  0.375602
# 2   0.037950         True  0.006257  0.696121  0.390743  ...  0.910085
# 3   2.898542         True  0.681789  0.118358  0.595181  ...  0.230171
# 4   3.035278         True  0.572016  0.532082  0.950598  ...  0.509426
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  7.386951         True  1.000000  1.000000  0.840515  ...  0.000000
# 68  7.517365         True  1.000000  1.000000  0.205971  ...  1.000000
# 69  8.168136         True  0.939484  1.000000  0.952968  ...  1.000000
# 70  7.608796         True  1.000000  1.000000  1.000000  ...  1.000000
# 71  0.000000         True  0.000000  1.000000  0.695946  ...  1.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.755973  0.258465  0.630902  0.895628  0.314016  0.226134  0.767989
# 1   0.361582  0.708481  0.386553  0.044727  0.849061  0.753360  0.204900
# 2   0.112242  0.023099  0.867731  0.695971  0.517800  0.372640  0.252599
# 3   0.506534  0.947694  0.114568  0.359859  0.053494  0.649819  0.688552
# 4   0.956088  0.149995  0.213908  0.390493  0.676617  0.437645  0.054882
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.594574  1.000000  1.000000  0.000000  1.000000  1.000000  1.000000
# 68  1.000000  0.000000  1.000000  1.000000  0.000000  1.000000  1.000000
# 69  1.000000  0.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 70  1.000000  0.000000  0.000000  0.000000  0.000000  1.000000  1.000000
# 71  1.000000  0.000000  1.000000  0.000000  0.000000  0.000000  0.000000
#
#          x28       x29
# 0   0.260920  0.223128
# 1   0.505331  0.876898
# 2   0.120248  0.618607
# 3   0.864722  0.278316
# 4   0.407790  0.098867
# ..       ...       ...
# 67  1.000000  1.000000
# 68  1.000000  1.000000
# 69  0.000000  1.000000
# 70  1.000000  0.576466
# 71  0.000000  1.000000
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  3.197380e+00
# 1             1      1_0      RUNNING             Sobol  1.417096e+00
# 2             2      2_0      RUNNING             Sobol  1.033656e+00
# 3             3      3_0      RUNNING             Sobol  3.398199e+00
# 4             4      4_0      RUNNING             Sobol  3.965347e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  4.650692e-16
# 68           68     68_0      RUNNING  FullyBayesianMOO  3.976742e-16
# 69           69     69_0      RUNNING  FullyBayesianMOO  4.786450e-16
# 70           70     70_0      RUNNING  FullyBayesianMOO  6.797761e+00
# 71           71     71_0      RUNNING  FullyBayesianMOO  6.468254e+00
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   1.631798         True  0.300419  0.605388  0.885314  ...  0.111401
# 1   2.795571         True  0.701325  0.491141  0.003891  ...  0.874194
# 2   3.849604         True  0.833000  0.946682  0.513122  ...  0.364195
# 3   0.903835         True  0.165493  0.082398  0.379013  ...  0.618958
# 4   0.190686         True  0.030590  0.777794  0.141556  ...  0.133647
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  7.595157         True  1.000000  0.792789  1.000000  ...  0.000000
# 68  6.494513         True  1.000000  0.241417  0.000000  ...  0.895119
# 69  7.816866         True  1.000000  0.000000  1.000000  ...  1.000000
# 70  0.000000         True  0.000000  0.000000  1.000000  ...  0.160339
# 71  0.000000         True  0.000000  0.350052  0.068523  ...  0.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.487170  0.633238  0.322168  0.432696  0.919435  0.718743  0.053407
# 1   0.789252  0.245410  0.938234  0.512619  0.476865  0.113825  0.694144
# 2   0.690890  0.885169  0.006117  0.021097  0.188896  0.793092  0.947704
# 3   0.024986  0.493450  0.640036  0.908589  0.629527  0.382142  0.306698
# 4   0.365727  0.830591  0.538689  0.862239  0.056270  0.967860  0.543769
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  1.000000  1.000000  1.000000  1.000000  1.000000  0.000000  0.000000
# 68  0.000000  0.003272  1.000000  1.000000  0.413129  0.000000  0.000000
# 69  0.000000  0.000000  1.000000  1.000000  0.000000  0.481216  0.000000
# 70  1.000000  1.000000  0.000000  1.000000  0.000000  1.000000  1.000000
# 71  0.310197  1.000000  0.000000  0.000000  0.768776  1.000000  0.000000
#
#          x28       x29
# 0   0.732774  0.088075
# 1   0.349326  0.623794
# 2   0.887053  0.778385
# 3   0.007561  0.306532
# 4   0.509532  0.179072
# ..       ...       ...
# 67  0.403123  1.000000
# 68  1.000000  1.000000
# 69  1.000000  1.000000
# 70  0.748481  0.257705
# 71  0.426367  0.269795
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  3.298993e-01
# 1             1      1_0      RUNNING             Sobol  3.390509e+00
# 2             2      2_0      RUNNING             Sobol  3.510082e+00
# 3             3      3_0      RUNNING             Sobol  1.256840e+00
# 4             4      4_0      RUNNING             Sobol  2.185824e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  5.790809e+00
# 68           68     68_0      RUNNING  FullyBayesianMOO  5.663785e+00
# 69           69     69_0      RUNNING  FullyBayesianMOO  6.708424e+00
# 70           70     70_0      RUNNING  FullyBayesianMOO  3.802784e-16
# 71           71     71_0      RUNNING  FullyBayesianMOO  4.049064e-16
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   3.357458         True  0.937647  0.594924  0.935165  ...  0.933716
# 1   1.886925         True  0.323303  0.463060  0.007155  ...  0.185298
# 2   0.688302         True  0.123272  0.818643  0.681937  ...  0.613596
# 3   2.895753         True  0.739309  0.247398  0.250511  ...  0.365185
# 4   3.079122         True  0.606996  0.973093  0.232444  ...  0.793475
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  0.000000         True  0.000000  0.000000  1.000000  ...  0.000000
# 68  0.000000         True  0.000000  0.115559  0.575080  ...  0.638600
# 69  0.136612         True  0.012963  0.000000  0.935317  ...  0.931648
# 70  6.210417         True  1.000000  0.000000  0.000000  ...  0.586413
# 71  6.612623         True  1.000000  1.000000  0.000000  ...  0.187889
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.484845  0.398168  0.959880  0.589923  0.804308  0.695247  0.912109
# 1   0.945559  0.935174  0.139543  0.087009  0.411358  0.240683  0.223730
# 2   0.550515  0.065718  0.614084  0.983100  0.023053  0.752126  0.317037
# 3   0.011238  0.602955  0.293811  0.480216  0.630113  0.300499  0.504166
# 4   0.358568  0.173486  0.462165  0.343240  0.201713  0.912316  0.034131
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  1.000000  0.000000  0.427927  0.021616  0.000000  0.458163  1.000000
# 68  1.000000  0.475003  0.405697  1.000000  0.000000  0.000000  1.000000
# 69  0.031764  1.000000  0.000000  1.000000  0.000000  1.000000  0.789342
# 70  1.000000  0.356332  0.449590  1.000000  0.770289  1.000000  0.357840
# 71  1.000000  0.915318  0.000000  1.000000  0.916489  0.000000  0.047930
#
#          x28       x29
# 0   0.318798  0.883044
# 1   0.743083  0.340422
# 2   0.197191  0.048832
# 3   0.866661  0.725259
# 4   0.495463  0.821553
# ..       ...       ...
# 67  0.000000  0.427028
# 68  0.000000  0.578080
# 69  0.108854  0.000000
# 70  0.000000  0.000000
# 71  0.000000  0.490998
#
# [72 rows x 37 columns],     trial_index arm_name trial_status generation_method             a  \
# 0             0      0_0      RUNNING             Sobol  2.665034e+00
# 1             1      1_0      RUNNING             Sobol  1.673453e+00
# 2             2      2_0      RUNNING             Sobol  1.187625e-01
# 3             3      3_0      RUNNING             Sobol  3.789484e+00
# 4             4      4_0      RUNNING             Sobol  3.706030e+00
# ..          ...      ...          ...               ...           ...
# 67           67     67_0      RUNNING  FullyBayesianMOO  7.721697e+00
# 68           68     68_0      RUNNING  FullyBayesianMOO  4.752760e-16
# 69           69     69_0      RUNNING  FullyBayesianMOO  4.898845e-01
# 70           70     70_0      RUNNING  FullyBayesianMOO  7.576993e+00
# 71           71     71_0      RUNNING  FullyBayesianMOO  7.838858e+00
#
#            b  is_feasible        x0        x1        x2  ...       x20  \
# 0   1.453883         True  0.317936  0.539818  0.606582  ...  0.385046
# 1   3.286492         True  0.700169  0.456645  0.294342  ...  0.690267
# 2   2.925181         True  0.974167  0.815002  0.892016  ...  0.017884
# 3   0.638976         True  0.106345  0.181470  0.204257  ...  0.838672
# 4   1.020636         True  0.171083  0.918572  0.408071  ...  0.358558
# ..       ...          ...       ...       ...       ...  ...       ...
# 67  0.000000         True  0.000000  0.000000  1.000000  ...  1.000000
# 68  7.761846         True  1.000000  0.000000  1.000000  ...  0.000000
# 69  7.765729         True  0.959893  0.000000  1.000000  ...  1.000000
# 70  0.000000         True  0.000000  1.000000  0.000000  ...  0.000000
# 71  0.000000         True  0.000000  1.000000  1.000000  ...  1.000000
#
#          x21       x22       x23       x24       x25       x26       x27  \
# 0   0.666193  0.616240  0.660035  0.348619  0.184525  0.733814  0.455447
# 1   0.107640  0.132516  0.025212  0.738954  0.876224  0.274064  0.799944
# 2   0.322867  0.762787  0.781188  0.203741  0.596745  0.864027  0.688160
# 3   0.889202  0.497733  0.411982  0.813407  0.342430  0.127975  0.033115
# 4   0.580760  0.949938  0.296452  0.994763  0.736023  0.888187  0.939532
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  1.000000  0.000000  0.033587  0.000000  1.000000  0.000000  1.000000
# 68  0.000000  0.000000  1.000000  0.000000  1.000000  0.000000  1.000000
# 69  0.000000  0.675047  0.000000  1.000000  0.000000  0.000000  1.000000
# 70  0.000000  1.000000  1.000000  0.000000  0.000000  0.000000  1.000000
# 71  0.000000  0.000000  0.000000  0.535338  0.204012  0.000000  1.000000
#
#          x28       x29
# 0   0.603757  0.386580
# 1   0.401937  0.854102
# 2   0.807222  0.611223
# 3   0.198434  0.141260
# 4   0.699880  0.345875
# ..       ...       ...
# 67  1.000000  1.000000
# 68  0.000000  1.000000
# 69  0.000000  1.000000
# 70  0.000000  0.847421
# 71  0.000000  0.000000
#
# [72 rows x 37 columns]]
